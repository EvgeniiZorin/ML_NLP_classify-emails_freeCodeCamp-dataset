# %% [markdown]
# # Import libraries, initialise variables

# %%
import os
import re

from collections import Counter

import nltk
import requests
import urlextract
# import libraries
# try:
#   # %tensorflow_version only exists in Colab.
#   !pip install tf-nightly
# except Exception:
#   pass
import tensorflow as tf
import pandas as pd
from tensorflow import keras
# !pip install tensorflow-datasets
# import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_score, recall_score

print(tf.__version__)
# Out:
# 2.16.0-dev20231022

# %%
DATE = "asdf"

DATADIR = 'data'
if not os.path.exists(DATADIR):
    os.makedirs(DATADIR)

stemmer = nltk.PorterStemmer()

# %% [markdown]
# # Files download and read

# %%
urls = [
    "https://cdn.freecodecamp.org/project-data/sms/train-data.tsv",
    "https://cdn.freecodecamp.org/project-data/sms/valid-data.tsv"
]

for i in urls:
    filename = os.path.basename(i)
    filename_dir = os.path.join( DATADIR, filename )
    if os.path.exists(filename_dir):
        print(f'[INFO] Path {filename_dir} already exists! Skipping download.')
    else:
        r = requests.get(i)
        with open(filename_dir, 'wb') as f:
            f.write(r.content)
        print(f'[INFO] Downloaded from web to path {filename_dir}')

train_file_path = "data/train-data.tsv"
test_file_path = "data/valid-data.tsv"
# Out:
# [INFO] Path data\train-data.tsv already exists! Skipping download.
# [INFO] Path data\valid-data.tsv already exists! Skipping download.

# %%
def read_tsv(path):
    """
    # component 1
    
    reads tsv from the path
    """
    df = pd.read_csv(
        path, 
        sep = '\t', 
        # header=None
        names = ['label', 'text']
    )
    print(f"[INFO] Data points = {len(df)}")
    return df

df_train = read_tsv(train_file_path)
df_train
# Out:
# [INFO] Data points = 4179
#      label                                               text
# 0      ham  ahhhh...just woken up!had a bad dream about u ...
# 1      ham                           you can never do nothing
# 2      ham  now u sound like manky scouse boy steve,like! ...
# 3      ham  mum say we wan to go then go... then she can s...
# 4      ham  never y lei... i v lazy... got wat? dat day ü ...
# ...    ...                                                ...
# 4174   ham  just woke up. yeesh its late. but i didn't fal...
# 4175   ham  what do u reckon as need 2 arrange transport i...
# 4176  spam  free entry into our £250 weekly competition ju...
# 4177  spam  -pls stop bootydelious (32/f) is inviting you ...
# 4178   ham  tell my  bad character which u dnt lik in me. ...
#
# [4179 rows x 2 columns]

# %% [markdown]
# # Data clean

# %%
df_train.isna().sum()
# no missing data points, so let's move on
# Out:
# label    0
# text     0
# dtype: int64

# %% [markdown]
# # Data preprocessing

# %%
df_train['text-proc'] = df_train['text']

# %%
### Replace multiple newline characters with one
df_train['text-proc'] = df_train['text-proc'].str.replace(r'\n+', '\n', regex=True)

df_train
# Out:
#      label                                               text  \
# 0      ham  ahhhh...just woken up!had a bad dream about u ...
# 1      ham                           you can never do nothing
# 2      ham  now u sound like manky scouse boy steve,like! ...
# 3      ham  mum say we wan to go then go... then she can s...
# 4      ham  never y lei... i v lazy... got wat? dat day ü ...
# ...    ...                                                ...
# 4174   ham  just woke up. yeesh its late. but i didn't fal...
# 4175   ham  what do u reckon as need 2 arrange transport i...
# 4176  spam  free entry into our £250 weekly competition ju...
# 4177  spam  -pls stop bootydelious (32/f) is inviting you ...
# 4178   ham  tell my  bad character which u dnt lik in me. ...
#
#                                               text-proc
# 0     ahhhh...just woken up!had a bad dream about u ...
# 1                              you can never do nothing
# 2     now u sound like manky scouse boy steve,like! ...
# 3     mum say we wan to go then go... then she can s...
# 4     never y lei... i v lazy... got wat? dat day ü ...
# ...                                                 ...
# 4174  just woke up. yeesh its late. but i didn't fal...
# 4175  what do u reckon as need 2 arrange transport i...
# 4176  free entry into our £250 weekly competition ju...
# 4177  -pls stop bootydelious (32/f) is inviting you ...
# 4178  tell my  bad character which u dnt lik in me. ...
#
# [4179 rows x 3 columns]

# %%
### Substitute URLs with "__URL__"
def replace_urls(string1):
    url_extractor = urlextract.URLExtract()
    url_list = url_extractor.find_urls(string1)
    for i in url_list:
        string1 = string1.replace(i, '__URL__')
    return string1

df_train['text-proc'] = df_train['text-proc'].apply( lambda x: replace_urls(x) )
### Replace all punctuation marks with whitespace
df_train['text-proc'] = df_train['text-proc'].apply( lambda x: re.sub(r'[^\w\s]', ' ', x) )

df_train
# Out:
#      label                                               text  \
# 0      ham  ahhhh...just woken up!had a bad dream about u ...
# 1      ham                           you can never do nothing
# 2      ham  now u sound like manky scouse boy steve,like! ...
# 3      ham  mum say we wan to go then go... then she can s...
# 4      ham  never y lei... i v lazy... got wat? dat day ü ...
# ...    ...                                                ...
# 4174   ham  just woke up. yeesh its late. but i didn't fal...
# 4175   ham  what do u reckon as need 2 arrange transport i...
# 4176  spam  free entry into our £250 weekly competition ju...
# 4177  spam  -pls stop bootydelious (32/f) is inviting you ...
# 4178   ham  tell my  bad character which u dnt lik in me. ...
#
#                                               text-proc
# 0     ahhhh   just woken up had a bad dream about u ...
# 1                              you can never do nothing
# 2     now u sound like manky scouse boy steve like  ...
# 3     mum say we wan to go then go    then she can s...
# 4     never y lei    i v lazy    got wat  dat day ü ...
# ...                                                 ...
# 4174  just woke up  yeesh its late  but i didn t fal...
# 4175  what do u reckon as need 2 arrange transport i...
# 4176  free entry into our  250 weekly competition ju...
# 4177   pls stop bootydelious  32 f  is inviting you ...
# 4178  tell my  bad character which u dnt lik in me  ...
#
# [4179 rows x 3 columns]

# %%
### Remove numbers
df_train['text-proc'] = df_train['text-proc'].apply( lambda x: re.sub(r'[0-9]+', '__NUMBER__', x) )
### Replace multiple whitespace characters with just one
df_train['text-proc'] = df_train['text-proc'].str.replace(r' +', ' ', regex=True)
### Convert to lowercase
df_train['text-proc'] = df_train['text-proc'].str.lower()
df_train
# Out:
#      label                                               text  \
# 0      ham  ahhhh...just woken up!had a bad dream about u ...
# 1      ham                           you can never do nothing
# 2      ham  now u sound like manky scouse boy steve,like! ...
# 3      ham  mum say we wan to go then go... then she can s...
# 4      ham  never y lei... i v lazy... got wat? dat day ü ...
# ...    ...                                                ...
# 4174   ham  just woke up. yeesh its late. but i didn't fal...
# 4175   ham  what do u reckon as need 2 arrange transport i...
# 4176  spam  free entry into our £250 weekly competition ju...
# 4177  spam  -pls stop bootydelious (32/f) is inviting you ...
# 4178   ham  tell my  bad character which u dnt lik in me. ...
#
#                                               text-proc
# 0     ahhhh just woken up had a bad dream about u th...
# 1                              you can never do nothing
# 2     now u sound like manky scouse boy steve like i...
# 3     mum say we wan to go then go then she can shun...
# 4     never y lei i v lazy got wat dat day ü send me...
# ...                                                 ...
# 4174  just woke up yeesh its late but i didn t fall ...
# 4175  what do u reckon as need __number__ arrange tr...
# 4176  free entry into our __number__ weekly competit...
# 4177   pls stop bootydelious __number__ f is invitin...
# 4178  tell my bad character which u dnt lik in me i ...
#
# [4179 rows x 3 columns]

# %%
train_labels = list(df_train['label'])

# Stemming
df_train_text = list(df_train['text-proc'])

data_processed = []
for i in df_train_text:
    i3 = i.split(' ')
    i3 = [stemmer.stem(i) for i in i3]
    word_counter = Counter(i3)
    word_counter = word_counter.most_common()
    data_processed.append(word_counter)

data_processed
# Out:
# [[('i', 3),
#   ('up', 2),
#   ('about', 2),
#   ('u', 2),
#   ('ahhhh', 1),
#   ('just', 1),
#   ('woken', 1),
#   ('had', 1),
#   ('a', 1),
#   ('bad', 1),
#   ('dream', 1),
#   ('tho', 1),
#   ('so', 1),
#   ('dont', 1),
#   ('like', 1),
#   ('right', 1),
#   ('now', 1),
#   ('didnt', 1),
#   ('know', 1),
#   ('anyth', 1),
#   ('comedi', 1),
#   ('night', 1),
#   ('but', 1),
#   ('guess', 1),
#   ('im', 1),
#   ('for', 1),
#   ('it', 1),
#   ('', 1)],
#  [('you', 1), ('can', 1), ('never', 1), ('do', 1), ('noth', 1)],
#  [('u', 2),
#   ('like', 2),
#   ('now', 1),
#   ('sound', 1),
#   ('manki', 1),
#   ('scous', 1),
#   ('boy', 1),
#   ('steve', 1),
#   ('i', 1),
#   ('is', 1),
#   ('travel', 1),
#   ('on', 1),
#   ('da', 1),
#   ('bu', 1),
#   ('home', 1),
#   ('wot', 1),
#   ('ha', 1),
#   ('inmind', 1),
#   ('__number__', 1),
#   ('recreat', 1),
#   ('di', 1),
#   ('eve', 1),
#   ('', 1)],
#  [('go', 2),
#   ('then', 2),
#   ('mum', 1),
#   ('say', 1),
#   ('we', 1),
#   ('wan', 1),
#   ('to', 1),
#   ('she', 1),
#   ('can', 1),
#   ('shun', 1),
#   ('bian', 1),
#   ('watch', 1),
#   ('da', 1),
#   ('glass', 1),
#   ('exhibit', 1),
#   ('', 1)],
#  [('never', 1),
#   ('y', 1),
#   ('lei', 1),
#   ('i', 1),
#   ('v', 1),
#   ('lazi', 1),
#   ('got', 1),
#   ('wat', 1),
#   ('dat', 1),
#   ('day', 1),
#   ('ü', 1),
#   ('send', 1),
#   ('me', 1),
#   ('da', 1),
#   ('url', 1),
#   ('cant', 1),
#   ('work', 1),
#   ('one', 1),
#   ('', 1)],
#  [('the', 2),
#   ('in', 1),
#   ('xam', 1),
#   ('hall', 1),
#   ('boy', 1),
#   ('ask', 1),
#   ('girl', 1),
#   ('tell', 1),
#   ('me', 1),
#   ('start', 1),
#   ('term', 1),
#   ('for', 1),
#   ('di', 1),
#   ('answer', 1),
#   ('i', 1),
#   ('can', 1),
#   ('den', 1),
#   ('manag', 1),
#   ('on', 1),
#   ('my', 1),
#   ('own', 1),
#   ('after', 1),
#   ('lot', 1),
#   ('of', 1),
#   ('hesit', 1),
#   ('n', 1),
#   ('lookin', 1),
#   ('around', 1),
#   ('silent', 1),
#   ('she', 1),
#   ('said', 1),
#   ('intha', 1),
#   ('ponnungal', 1),
#   ('ipaditan', 1),
#   ('', 1)],
#  [('geniu', 1),
#   ('what', 1),
#   ('s', 1),
#   ('up', 1),
#   ('how', 1),
#   ('your', 1),
#   ('brother', 1),
#   ('pl', 1),
#   ('send', 1),
#   ('hi', 1),
#   ('number', 1),
#   ('to', 1),
#   ('my', 1),
#   ('skype', 1),
#   ('', 1)],
#  [('they', 1),
#   ('final', 1),
#   ('came', 1),
#   ('to', 1),
#   ('fix', 1),
#   ('the', 1),
#   ('ceil', 1),
#   ('', 1)],
#  [('__number__', 7),
#   ('your', 2),
#   ('urgent', 1),
#   ('call', 1),
#   ('from', 1),
#   ('landlin', 1),
#   ('complimentari', 1),
#   ('ibiza', 1),
#   ('holiday', 1),
#   ('or', 1),
#   ('cash', 1),
#   ('await', 1),
#   ('collect', 1),
#   ('sae', 1),
#   ('t', 1),
#   ('cs', 1),
#   ('po', 1),
#   ('box', 1),
#   ('sk__number__', 1),
#   ('__number__wp', 1),
#   ('ppm', 1),
#   ('', 1)],
#  [('you', 3),
#   ('that', 2),
#   ('i', 2),
#   ('now', 1),
#   ('have', 1),
#   ('start', 1),
#   ('dont', 1),
#   ('stop', 1),
#   ('just', 1),
#   ('pray', 1),
#   ('for', 1),
#   ('more', 1),
#   ('good', 1),
#   ('idea', 1),
#   ('and', 1),
#   ('anyth', 1),
#   ('see', 1),
#   ('can', 1),
#   ('help', 1),
#   ('guy', 1),
#   ('ll', 1),
#   ('forward', 1),
#   ('a', 1),
#   ('link', 1),
#   ('', 1)],
#  [('finish', 2),
#   ('u', 2),
#   ('hello', 1),
#   ('darlin', 1),
#   ('ive', 1),
#   ('colleg', 1),
#   ('now', 1),
#   ('so', 1),
#   ('txt', 1),
#   ('me', 1),
#   ('when', 1),
#   ('if', 1),
#   ('can', 1),
#   ('love', 1),
#   ('kate', 1),
#   ('xxx', 1)],
#  [('ü', 4),
#   ('i', 3),
#   ('repli', 2),
#   ('aiyo', 1),
#   ('co', 1),
#   ('sm', 1),
#   ('then', 1),
#   ('neva', 1),
#   ('so', 1),
#   ('wait', 1),
#   ('__number__', 1),
#   ('to', 1),
#   ('lar', 1),
#   ('tot', 1),
#   ('havent', 1),
#   ('finish', 1),
#   ('ur', 1),
#   ('lab', 1),
#   ('wat', 1),
#   ('', 1)],
#  [('i', 2),
#   ('have', 2),
#   ('m', 1),
#   ('cool', 1),
#   ('ta', 1),
#   ('luv', 1),
#   ('but', 1),
#   ('v', 1),
#   ('tire', 1),
#   ('__number__', 1),
#   ('caus', 1),
#   ('been', 1),
#   ('doin', 1),
#   ('load', 1),
#   ('of', 1),
#   ('plan', 1),
#   ('all', 1),
#   ('wk', 1),
#   ('we', 1),
#   ('got', 1),
#   ('our', 1),
#   ('social', 1),
#   ('servic', 1),
#   ('inspect', 1),
#   ('at', 1),
#   ('the', 1),
#   ('nurseri', 1),
#   ('take', 1),
#   ('care', 1),
#   ('spk', 1),
#   ('sn', 1),
#   ('x', 1),
#   ('', 1)],
#  [('lt', 3),
#   ('gt', 3),
#   ('the', 1),
#   ('messag', 1),
#   ('sent', 1),
#   ('is', 1),
#   ('askin', 1),
#   ('for', 1),
#   ('dollar', 1),
#   ('shoul', 1),
#   ('i', 1),
#   ('pay', 1),
#   ('or', 1),
#   ('', 1)],
#  [('he', 2),
#   ('i', 2),
#   ('said', 1),
#   ('look', 1),
#   ('pretti', 1),
#   ('wif', 1),
#   ('long', 1),
#   ('hair', 1),
#   ('wat', 1),
#   ('but', 1),
#   ('thk', 1),
#   ('s', 1),
#   ('cut', 1),
#   ('quit', 1),
#   ('short', 1),
#   ('__number__', 1),
#   ('me', 1),
#   ('leh', 1),
#   ('', 1)],
#  [('you', 4),
#   ('i', 3),
#   ('are', 2),
#   ('and', 2),
#   ('to', 2),
#   ('right', 1),
#   ('though', 1),
#   ('can', 1),
#   ('t', 1),
#   ('give', 1),
#   ('the', 1),
#   ('space', 1),
#   ('want', 1),
#   ('need', 1),
#   ('thi', 1),
#   ('is', 1),
#   ('realli', 1),
#   ('start', 1),
#   ('becom', 1),
#   ('an', 1),
#   ('issu', 1),
#   ('wa', 1),
#   ('go', 1),
#   ('suggest', 1),
#   ('set', 1),
#   ('a', 1),
#   ('definit', 1),
#   ('move', 1),
#   ('out', 1),
#   ('if', 1),
#   ('m', 1),
#   ('still', 1),
#   ('there', 1),
#   ('after', 1),
#   ('greec', 1),
#   ('but', 1),
#   ('mayb', 1),
#   ('readi', 1),
#   ('should', 1),
#   ('do', 1),
#   ('it', 1),
#   ('now', 1),
#   ('', 1)],
#  [('__number__', 3),
#   ('bore', 1),
#   ('housew', 1),
#   ('chat', 1),
#   ('n', 1),
#   ('date', 1),
#   ('now', 1),
#   ('bt', 1),
#   ('nation', 1),
#   ('rate', 1),
#   ('__number__p', 1),
#   ('min', 1),
#   ('onli', 1),
#   ('from', 1),
#   ('landlin', 1),
#   ('', 1)],
#  [('well', 1),
#   ('i', 1),
#   ('know', 1),
#   ('z', 1),
#   ('will', 1),
#   ('take', 1),
#   ('care', 1),
#   ('of', 1),
#   ('me', 1),
#   ('so', 1),
#   ('no', 1),
#   ('worri', 1),
#   ('', 1)],
#  [('haha', 1),
#   ('dont', 1),
#   ('be', 1),
#   ('angri', 1),
#   ('with', 1),
#   ('yourself', 1),
#   ('take', 1),
#   ('it', 1),
#   ('as', 1),
#   ('a', 1),
#   ('practic', 1),
#   ('for', 1),
#   ('the', 1),
#   ('real', 1),
#   ('thing', 1),
#   ('', 1)],
#  [('nope', 1),
#   ('i', 1),
#   ('m', 1),
#   ('still', 1),
#   ('in', 1),
#   ('the', 1),
#   ('market', 1)],
#  [('is', 2),
#   ('messag', 1),
#   ('import', 1),
#   ('inform', 1),
#   ('for', 1),
#   ('o__number__', 1),
#   ('user', 1),
#   ('today', 1),
#   ('your', 1),
#   ('lucki', 1),
#   ('day', 1),
#   ('__number__', 1),
#   ('find', 1),
#   ('out', 1),
#   ('whi', 1),
#   ('log', 1),
#   ('onto', 1),
#   ('__url__', 1),
#   ('there', 1),
#   ('a', 1),
#   ('fantast', 1),
#   ('surpris', 1),
#   ('await', 1),
#   ('you', 1)],
#  [('am', 1),
#   ('not', 1),
#   ('interest', 1),
#   ('to', 1),
#   ('do', 1),
#   ('like', 1),
#   ('that', 1),
#   ('', 1)],
#  [('u', 2),
#   ('oh', 1),
#   ('ye', 1),
#   ('i', 1),
#   ('can', 1),
#   ('speak', 1),
#   ('txt', 1),
#   ('__number__', 1),
#   ('no', 1),
#   ('hmm', 1),
#   ('did', 1),
#   ('get', 1),
#   ('email', 1),
#   ('', 1)],
#  [('angri', 2),
#   ('n', 2),
#   ('wen', 1),
#   ('ur', 1),
#   ('lovabl', 1),
#   ('bcum', 1),
#   ('wid', 1),
#   ('u', 1),
#   ('dnt', 1),
#   ('take', 1),
#   ('it', 1),
#   ('serious', 1),
#   ('coz', 1),
#   ('be', 1),
#   ('is', 1),
#   ('d', 1),
#   ('most', 1),
#   ('childish', 1),
#   ('true', 1),
#   ('way', 1),
#   ('of', 1),
#   ('show', 1),
#   ('deep', 1),
#   ('affect', 1),
#   ('care', 1),
#   ('luv', 1),
#   ('kettoda', 1),
#   ('manda', 1),
#   ('have', 1),
#   ('nice', 1),
#   ('day', 1),
#   ('da', 1),
#   ('', 1)],
#  [('god', 2),
#   ('gift', 2),
#   ('tht', 1),
#   ('s', 1),
#   ('for', 1),
#   ('bird', 1),
#   ('as', 1),
#   ('human', 1),
#   ('hav', 1),
#   ('some', 1),
#   ('natur', 1),
#   ('frm', 1),
#   ('', 1)],
#  [('aight', 1),
#   ('i', 1),
#   ('m', 1),
#   ('chillin', 1),
#   ('in', 1),
#   ('a', 1),
#   ('friend', 1),
#   ('s', 1),
#   ('room', 1),
#   ('so', 1),
#   ('text', 1),
#   ('me', 1),
#   ('when', 1),
#   ('you', 1),
#   ('re', 1),
#   ('on', 1),
#   ('the', 1),
#   ('way', 1)],
#  [('how', 1),
#   ('long', 1),
#   ('ha', 1),
#   ('it', 1),
#   ('been', 1),
#   ('sinc', 1),
#   ('you', 1),
#   ('scream', 1),
#   ('princess', 1),
#   ('', 1)],
#  [('i', 2),
#   ('no', 1),
#   ('problem', 1),
#   ('with', 1),
#   ('the', 1),
#   ('renew', 1),
#   ('ll', 1),
#   ('do', 1),
#   ('it', 1),
#   ('right', 1),
#   ('away', 1),
#   ('but', 1),
#   ('dont', 1),
#   ('know', 1),
#   ('hi', 1),
#   ('detail', 1),
#   ('', 1)],
#  [('at', 2),
#   ('__number__', 2),
#   ('doe', 1),
#   ('cinema', 1),
#   ('plu', 1),
#   ('drink', 1),
#   ('appeal', 1),
#   ('tomo', 1),
#   ('is', 1),
#   ('a', 1),
#   ('fr', 1),
#   ('thriller', 1),
#   ('by', 1),
#   ('director', 1),
#   ('i', 1),
#   ('like', 1),
#   ('on', 1),
#   ('mac', 1),
#   ('', 1)],
#  [('i', 1),
#   ('m', 1),
#   ('come', 1),
#   ('home', 1),
#   ('__number__', 1),
#   ('dinner', 1),
#   ('', 1)],
#  [('i', 2),
#   ('__number__', 2),
#   ('are', 1),
#   ('we', 1),
#   ('do', 1),
#   ('the', 1),
#   ('norm', 1),
#   ('tomorrow', 1),
#   ('finish', 1),
#   ('just', 1),
#   ('a', 1),
#   ('co', 1),
#   ('of', 1),
#   ('st', 1),
#   ('test', 1),
#   ('need', 1),
#   ('to', 1),
#   ('sort', 1),
#   ('librari', 1),
#   ('stuff', 1),
#   ('out', 1),
#   ('at', 1),
#   ('some', 1),
#   ('point', 1),
#   ('tomo', 1),
#   ('got', 1),
#   ('letter', 1),
#   ('from', 1),
#   ('today', 1),
#   ('access', 1),
#   ('til', 1),
#   ('end', 1),
#   ('march', 1),
#   ('so', 1),
#   ('better', 1),
#   ('get', 1),
#   ('move', 1),
#   ('on', 1),
#   ('', 1)],
#  [('but', 1),
#   ('i', 1),
#   ('haf', 1),
#   ('enuff', 1),
#   ('space', 1),
#   ('got', 1),
#   ('like', 1),
#   ('__number__', 1),
#   ('mb', 1),
#   ('', 1)],
#  [('i', 1),
#   ('need', 1),
#   ('to', 1),
#   ('come', 1),
#   ('home', 1),
#   ('and', 1),
#   ('give', 1),
#   ('you', 1),
#   ('some', 1),
#   ('good', 1),
#   ('lovin', 1),
#   ('', 1)],
#  [('i', 4),
#   ('wa', 2),
#   ('in', 2),
#   ('the', 2),
#   ('lol', 1),
#   ('gonna', 1),
#   ('last', 1),
#   ('month', 1),
#   ('cash', 1),
#   ('some', 1),
#   ('but', 1),
#   ('left', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('just', 1),
#   ('case', 1),
#   ('collect', 1),
#   ('more', 1),
#   ('dure', 1),
#   ('week', 1),
#   ('caus', 1),
#   ('they', 1),
#   ('announc', 1),
#   ('it', 1),
#   ('on', 1),
#   ('blog', 1),
#   ('', 1)],
#  [('mm', 1),
#   ('not', 1),
#   ('entir', 1),
#   ('sure', 1),
#   ('i', 1),
#   ('understood', 1),
#   ('that', 1),
#   ('text', 1),
#   ('but', 1),
#   ('hey', 1),
#   ('ho', 1),
#   ('which', 1),
#   ('weekend', 1),
#   ('', 1)],
#  [('i', 4),
#   ('you', 3),
#   ('miss', 2),
#   ('sorri', 1),
#   ('babe', 1),
#   ('wa', 1),
#   ('up', 1),
#   ('late', 1),
#   ('and', 1),
#   ('slept', 1),
#   ('in', 1),
#   ('hope', 1),
#   ('enjoy', 1),
#   ('your', 1),
#   ('drive', 1),
#   ('lesson', 1),
#   ('boytoy', 1),
#   ('too', 1),
#   ('teas', 1),
#   ('kiss', 1),
#   ('', 1)],
#  [('d', 10),
#   ('boy', 4),
#   ('a', 3),
#   ('gal', 3),
#   ('n', 3),
#   ('he', 2),
#   ('bt', 2),
#   ('she', 2),
#   ('her', 2),
#   ('__number__', 2),
#   ('wa', 2),
#   ('girl', 2),
#   ('boost', 2),
#   ('of', 2),
#   ('energi', 2),
#   ('love', 1),
#   ('propsd', 1),
#   ('didnt', 1),
#   ('mind', 1),
#   ('gv', 1),
#   ('lv', 1),
#   ('lttr', 1),
#   ('frnd', 1),
#   ('threw', 1),
#   ('thm', 1),
#   ('again', 1),
#   ('decid', 1),
#   ('aproach', 1),
#   ('dt', 1),
#   ('time', 1),
#   ('truck', 1),
#   ('speed', 1),
#   ('toward', 1),
#   ('wn', 1),
#   ('it', 1),
#   ('about', 1),
#   ('hit', 1),
#   ('ran', 1),
#   ('like', 1),
#   ('hell', 1),
#   ('save', 1),
#   ('ask', 1),
#   ('hw', 1),
#   ('cn', 1),
#   ('u', 1),
#   ('run', 1),
#   ('so', 1),
#   ('fast', 1),
#   ('repli', 1),
#   ('is', 1),
#   ('secret', 1),
#   ('my', 1),
#   ('instantli', 1),
#   ('shout', 1),
#   ('our', 1),
#   ('thi', 1),
#   ('live', 1),
#   ('happili', 1),
#   ('__number__gthr', 1),
#   ('drink', 1),
#   ('evrydi', 1),
#   ('moral', 1),
#   ('stori', 1),
#   ('i', 1),
#   ('hv', 1),
#   ('free', 1),
#   ('msg', 1),
#   ('gud', 1),
#   ('ni__number__', 1)],
#  [('__number__', 4),
#   ('week', 2),
#   ('nokia', 2),
#   ('tone', 2),
#   ('ur', 2),
#   ('free', 1),
#   ('for', 1),
#   ('__number__st', 1),
#   ('no__number__', 1),
#   ('mobil', 1),
#   ('everi', 1),
#   ('just', 1),
#   ('txt', 1),
#   ('to', 1),
#   ('get', 1),
#   ('txting', 1),
#   ('and', 1),
#   ('tell', 1),
#   ('mate', 1),
#   ('__url__', 1),
#   ('pobox', 1),
#   ('w__number__wq', 1),
#   ('norm__number__p', 1)],
#  [('our', 1),
#   ('prashanthettan', 1),
#   ('s', 1),
#   ('mother', 1),
#   ('pass', 1),
#   ('away', 1),
#   ('last', 1),
#   ('night', 1),
#   ('pray', 1),
#   ('for', 1),
#   ('her', 1),
#   ('and', 1),
#   ('famili', 1),
#   ('', 1)],
#  [('__number__', 2),
#   ('you', 1),
#   ('have', 1),
#   ('new', 1),
#   ('voicemail', 1),
#   ('pleas', 1),
#   ('call', 1)],
#  [('didn', 1),
#   ('t', 1),
#   ('tri', 1),
#   ('g', 1),
#   ('and', 1),
#   ('i', 1),
#   ('decid', 1),
#   ('not', 1),
#   ('to', 1),
#   ('head', 1),
#   ('out', 1)],
#  [('give', 1),
#   ('one', 1),
#   ('miss', 1),
#   ('from', 1),
#   ('that', 1),
#   ('number', 1),
#   ('pleas', 1)],
#  [('update_now', 1),
#   ('__number__mth', 1),
#   ('half', 1),
#   ('price', 1),
#   ('orang', 1),
#   ('line', 1),
#   ('rental', 1),
#   ('__number__min', 1),
#   ('call', 1),
#   ('mobileupd__number__', 1),
#   ('on', 1),
#   ('__number__', 1),
#   ('or', 1),
#   ('call__number__optout', 1),
#   ('j__number__q', 1)],
#  [('__number__', 5),
#   ('from', 2),
#   ('new', 1),
#   ('mobil', 1),
#   ('must', 1),
#   ('go', 1),
#   ('txt', 1),
#   ('nokia', 1),
#   ('to', 1),
#   ('no', 1),
#   ('collect', 1),
#   ('your', 1),
#   ('today', 1),
#   ('onli', 1),
#   ('__url__', 1),
#   ('__number__optout', 1),
#   ('__number__gbp', 1),
#   ('mtmsg__number__', 1),
#   ('txtauction', 1)],
#  [('you', 2),
#   ('just', 2),
#   ('in', 2),
#   ('and', 2),
#   ('might', 1),
#   ('want', 1),
#   ('to', 1),
#   ('pull', 1),
#   ('out', 1),
#   ('more', 1),
#   ('case', 1),
#   ('plan', 1),
#   ('on', 1),
#   ('not', 1),
#   ('spend', 1),
#   ('it', 1),
#   ('if', 1),
#   ('can', 1),
#   ('i', 1),
#   ('don', 1),
#   ('t', 1),
#   ('have', 1),
#   ('much', 1),
#   ('confid', 1),
#   ('derek', 1),
#   ('taylor', 1),
#   ('s', 1),
#   ('money', 1),
#   ('manag', 1)],
#  [('my', 4),
#   ('life', 3),
#   ('i', 3),
#   ('becaus', 2),
#   ('love', 2),
#   ('the', 2),
#   ('world', 2),
#   ('call', 2),
#   ('them', 2),
#   ('mean', 1),
#   ('a', 1),
#   ('lot', 1),
#   ('to', 1),
#   ('me', 1),
#   ('not', 1),
#   ('but', 1),
#   ('peopl', 1),
#   ('in', 1),
#   ('friend', 1),
#   ('ge', 1),
#   ('', 1)],
#  [('i', 3),
#   ('do', 1),
#   ('thought', 1),
#   ('put', 1),
#   ('it', 1),
#   ('back', 1),
#   ('in', 1),
#   ('the', 1),
#   ('box', 1)],
#  [('rememb', 1), ('on', 1), ('that', 1), ('day', 1), ('', 1)],
#  [('sent', 1), ('me', 1), ('ur', 1), ('email', 1), ('id', 1), ('soon', 1)],
#  [('inde', 1),
#   ('and', 1),
#   ('by', 1),
#   ('the', 1),
#   ('way', 1),
#   ('it', 1),
#   ('wa', 1),
#   ('either', 1),
#   ('or', 1),
#   ('not', 1),
#   ('both', 1),
#   ('', 1)],
#  [('haha', 1), ('just', 1), ('kid', 1), ('papa', 1), ('need', 1), ('drug', 1)],
#  [('to', 2),
#   ('no', 1),
#   ('gift', 1),
#   ('you', 1),
#   ('tri', 1),
#   ('get', 1),
#   ('me', 1),
#   ('throw', 1),
#   ('myself', 1),
#   ('off', 1),
#   ('a', 1),
#   ('cliff', 1),
#   ('or', 1),
#   ('someth', 1),
#   ('', 1)],
#  [('she', 1),
#   ('went', 1),
#   ('to', 1),
#   ('attend', 1),
#   ('anoth', 1),
#   ('two', 1),
#   ('round', 1),
#   ('today', 1),
#   ('but', 1),
#   ('still', 1),
#   ('did', 1),
#   ('t', 1),
#   ('reach', 1),
#   ('home', 1),
#   ('', 1)],
#  [('haha', 1),
#   ('can', 1),
#   ('but', 1),
#   ('i', 1),
#   ('m', 1),
#   ('have', 1),
#   ('dinner', 1),
#   ('with', 1),
#   ('my', 1),
#   ('cousin', 1),
#   ('', 1)],
#  [('total', 1),
#   ('video', 1),
#   ('convert', 1),
#   ('free', 1),
#   ('download', 1),
#   ('type', 1),
#   ('thi', 1),
#   ('in', 1),
#   ('googl', 1),
#   ('search', 1),
#   ('', 1)],
#  [('yay', 1),
#   ('final', 1),
#   ('lol', 1),
#   ('i', 1),
#   ('miss', 1),
#   ('our', 1),
#   ('cinema', 1),
#   ('trip', 1),
#   ('last', 1),
#   ('week', 1),
#   ('', 1)],
#  [('to', 2),
#   ('good', 1),
#   ('morn', 1),
#   ('im', 1),
#   ('suffer', 1),
#   ('from', 1),
#   ('fever', 1),
#   ('and', 1),
#   ('dysentri', 1),
#   ('will', 1),
#   ('not', 1),
#   ('be', 1),
#   ('abl', 1),
#   ('come', 1),
#   ('offic', 1),
#   ('today', 1),
#   ('', 1)],
#  [('keep', 1),
#   ('my', 1),
#   ('payasam', 1),
#   ('there', 1),
#   ('if', 1),
#   ('rinu', 1),
#   ('bring', 1)],
#  [('we', 1),
#   ('can', 1),
#   ('go', 1),
#   ('__number__', 1),
#   ('e', 1),
#   ('normal', 1),
#   ('pilat', 1),
#   ('after', 1),
#   ('our', 1),
#   ('intro', 1),
#   ('', 1)],
#  [('lol', 1),
#   ('ok', 1),
#   ('ill', 1),
#   ('tri', 1),
#   ('to', 1),
#   ('send', 1),
#   ('be', 1),
#   ('warn', 1),
#   ('sprint', 1),
#   ('is', 1),
#   ('dead', 1),
#   ('slow', 1),
#   ('you', 1),
#   ('ll', 1),
#   ('prolli', 1),
#   ('get', 1),
#   ('it', 1),
#   ('tomorrow', 1)],
#  [('and', 2),
#   ('my', 2),
#   ('honestli', 1),
#   ('i', 1),
#   ('ve', 1),
#   ('just', 1),
#   ('made', 1),
#   ('a', 1),
#   ('love', 1),
#   ('cup', 1),
#   ('of', 1),
#   ('tea', 1),
#   ('promptli', 1),
#   ('drop', 1),
#   ('key', 1),
#   ('in', 1),
#   ('it', 1),
#   ('then', 1),
#   ('burnt', 1),
#   ('finger', 1),
#   ('get', 1),
#   ('them', 1),
#   ('out', 1),
#   ('', 1)],
#  [('hi', 3), ('pleas', 1), ('dont', 1), ('say', 1), ('like', 1), ('that', 1)],
#  [('k', 2),
#   ('pa', 1),
#   ('had', 1),
#   ('your', 1),
#   ('lunch', 1),
#   ('aha', 1),
#   ('', 1)],
#  [('i', 3),
#   ('watch', 1),
#   ('lor', 1),
#   ('saw', 1),
#   ('a', 1),
#   ('few', 1),
#   ('swatch', 1),
#   ('one', 1),
#   ('thk', 1),
#   ('quit', 1),
#   ('ok', 1),
#   ('ard', 1),
#   ('__number__', 1),
#   ('but', 1),
#   ('need', 1),
#   ('__number__nd', 1),
#   ('opinion', 1),
#   ('leh', 1),
#   ('', 1)],
#  [('i', 1),
#   ('told', 1),
#   ('that', 1),
#   ('am', 1),
#   ('come', 1),
#   ('on', 1),
#   ('wednesday', 1),
#   ('', 1)],
#  [('you', 3),
#   ('pl', 2),
#   ('all', 2),
#   ('know', 2),
#   ('about', 2),
#   ('can', 1),
#   ('send', 1),
#   ('me', 1),
#   ('a', 1),
#   ('mail', 1),
#   ('on', 1),
#   ('rel', 1),
#   ('come', 1),
#   ('to', 1),
#   ('deliv', 1),
#   ('here', 1),
#   ('cost', 1),
#   ('risk', 1),
#   ('benefit', 1),
#   ('and', 1),
#   ('anyth', 1),
#   ('els', 1),
#   ('thank', 1),
#   ('', 1)],
#  [('yup', 1),
#   ('but', 1),
#   ('not', 1),
#   ('studi', 1),
#   ('surf', 1),
#   ('lor', 1),
#   ('i', 1),
#   ('m', 1),
#   ('in', 1),
#   ('e', 1),
#   ('lazi', 1),
#   ('mode', 1),
#   ('today', 1),
#   ('', 1)],
#  [('bore', 2),
#   ('hello', 1),
#   ('how', 1),
#   ('r', 1),
#   ('u', 1),
#   ('im', 1),
#   ('inev', 1),
#   ('thought', 1),
#   ('id', 1),
#   ('get', 1),
#   ('with', 1),
#   ('the', 1),
#   ('tv', 1),
#   ('but', 1),
#   ('i', 1),
#   ('am', 1),
#   ('tell', 1),
#   ('me', 1),
#   ('someth', 1),
#   ('excit', 1),
#   ('ha', 1),
#   ('happen', 1),
#   ('there', 1),
#   ('anyth', 1),
#   ('', 1)],
#  [('been', 1),
#   ('up', 1),
#   ('to', 1),
#   ('ne', 1),
#   ('thing', 1),
#   ('interest', 1),
#   ('did', 1),
#   ('you', 1),
#   ('have', 1),
#   ('a', 1),
#   ('good', 1),
#   ('birthday', 1),
#   ('when', 1),
#   ('are', 1),
#   ('u', 1),
#   ('wrking', 1),
#   ('nxt', 1),
#   ('i', 1),
#   ('start', 1),
#   ('uni', 1),
#   ('today', 1),
#   ('', 1)],
#  [('__number__', 6),
#   ('c', 3),
#   ('warner', 2),
#   ('villag', 2),
#   ('kiosk', 2),
#   ('colin', 1),
#   ('farrel', 1),
#   ('in', 1),
#   ('swat', 1),
#   ('thi', 1),
#   ('wkend', 1),
#   ('get', 1),
#   ('free', 1),
#   ('med', 1),
#   ('popcorn', 1),
#   ('just', 1),
#   ('show', 1),
#   ('msg', 1),
#   ('ticket', 1),
#   ('valid', 1),
#   ('t', 1),
#   ('repli', 1),
#   ('soni', 1),
#   ('mre', 1),
#   ('film', 1),
#   ('offer', 1)],
#  [('doe', 1),
#   ('uncl', 1),
#   ('timi', 1),
#   ('help', 1),
#   ('in', 1),
#   ('clear', 1),
#   ('car', 1)],
#  [('ugh', 1),
#   ('gotta', 1),
#   ('drive', 1),
#   ('back', 1),
#   ('to', 1),
#   ('sd', 1),
#   ('from', 1),
#   ('la', 1),
#   ('my', 1),
#   ('butt', 1),
#   ('is', 1),
#   ('sore', 1),
#   ('', 1)],
#  [('i', 3),
#   ('but', 2),
#   ('and', 2),
#   ('same', 1),
#   ('here', 1),
#   ('consid', 1),
#   ('wall', 1),
#   ('bunker', 1),
#   ('shit', 1),
#   ('import', 1),
#   ('just', 1),
#   ('becaus', 1),
#   ('never', 1),
#   ('play', 1),
#   ('on', 1),
#   ('peac', 1),
#   ('guess', 1),
#   ('your', 1),
#   ('place', 1),
#   ('is', 1),
#   ('high', 1),
#   ('enough', 1),
#   ('that', 1),
#   ('it', 1),
#   ('don', 1),
#   ('t', 1),
#   ('matter', 1)],
#  [('under', 2),
#   ('the', 2),
#   ('sunlight', 2),
#   ('don', 2),
#   ('t', 2),
#   ('scienc', 1),
#   ('tell', 1),
#   ('that', 1),
#   ('chocol', 1),
#   ('will', 1),
#   ('melt', 1),
#   ('pleas', 1),
#   ('walk', 1),
#   ('bcoz', 1),
#   ('i', 1),
#   ('want', 1),
#   ('to', 1),
#   ('loss', 1),
#   ('a', 1),
#   ('sweet', 1),
#   ('friend', 1),
#   ('', 1)],
#  [('i', 1),
#   ('dont', 1),
#   ('know', 1),
#   ('whi', 1),
#   ('she', 1),
#   ('s', 1),
#   ('not', 1),
#   ('get', 1),
#   ('your', 1),
#   ('messag', 1)],
#  [('i', 2),
#   ('ü', 2),
#   ('dunno', 1),
#   ('lei', 1),
#   ('might', 1),
#   ('b', 1),
#   ('eatin', 1),
#   ('wif', 1),
#   ('my', 1),
#   ('fren', 1),
#   ('if', 1),
#   ('wan', 1),
#   ('to', 1),
#   ('eat', 1),
#   ('then', 1),
#   ('wait', 1),
#   ('__number__', 1),
#   ('lar', 1)],
#  [('hahaha', 1), ('use', 1), ('your', 1), ('brain', 1), ('dear', 1)],
#  [('when', 1), ('u', 1), ('wana', 1), ('see', 1), ('it', 1), ('then', 1)],
#  [('talk', 1),
#   ('to', 1),
#   ('g', 1),
#   ('and', 1),
#   ('x', 1),
#   ('about', 1),
#   ('that', 1)],
#  [('were', 1), ('somewher', 1), ('on', 1), ('fredericksburg', 1)],
#  [('just', 1),
#   ('sent', 1),
#   ('again', 1),
#   ('do', 1),
#   ('you', 1),
#   ('scream', 1),
#   ('and', 1),
#   ('moan', 1),
#   ('in', 1),
#   ('bed', 1),
#   ('princess', 1),
#   ('', 1)],
#  [('__number__', 7),
#   ('privat', 1),
#   ('your', 1),
#   ('account', 1),
#   ('statement', 1),
#   ('for', 1),
#   ('show', 1),
#   ('un', 1),
#   ('redeem', 1),
#   ('s', 1),
#   ('i', 1),
#   ('m', 1),
#   ('point', 1),
#   ('call', 1),
#   ('identifi', 1),
#   ('code', 1),
#   ('expir', 1)],
#  [('ya', 1),
#   ('veri', 1),
#   ('nice', 1),
#   ('be', 1),
#   ('readi', 1),
#   ('on', 1),
#   ('thursday', 1)],
#  [('ticket', 3),
#   ('to', 3),
#   ('on', 2),
#   ('eve', 2),
#   ('from', 2),
#   ('chennai', 2),
#   ('i', 2),
#   ('pleas', 1),
#   ('reserv', 1),
#   ('saturday', 1),
#   ('thirunelvali', 1),
#   ('and', 1),
#   ('again', 1),
#   ('tirunelvali', 1),
#   ('sunday', 1),
#   ('alreadi', 1),
#   ('see', 1),
#   ('in', 1),
#   ('net', 1),
#   ('no', 1),
#   ('avail', 1),
#   ('want', 1),
#   ('book', 1),
#   ('through', 1),
#   ('tackl', 1),
#   ('', 1)],
#  [('__number__', 3),
#   ('free', 2),
#   ('rington', 2),
#   ('to', 2),
#   ('week', 2),
#   ('top', 1),
#   ('sub', 1),
#   ('weekli', 1),
#   ('get', 1),
#   ('__number__st', 1),
#   ('send', 1),
#   ('subpoli', 1),
#   ('per', 1),
#   ('stop', 1),
#   ('sm', 1)],
#  [('i', 3),
#   ('tell', 2),
#   ('to', 2),
#   ('you', 2),
#   ('what', 1),
#   ('told', 1),
#   ('befor', 1),
#   ('stupid', 1),
#   ('hear', 1),
#   ('after', 1),
#   ('wont', 1),
#   ('anyth', 1),
#   ('dad', 1),
#   ('call', 1),
#   ('my', 1),
#   ('brother', 1),
#   ('and', 1),
#   ('spoken', 1),
#   ('not', 1),
#   ('with', 1),
#   ('me', 1),
#   ('', 1)],
#  [('up', 2),
#   ('hey', 1),
#   ('someth', 1),
#   ('came', 1),
#   ('last', 1),
#   ('min', 1),
#   ('think', 1),
#   ('i', 1),
#   ('wun', 1),
#   ('be', 1),
#   ('sign', 1),
#   ('tmr', 1),
#   ('hee', 1)],
#  [('i', 3),
#   ('an', 2),
#   ('need', 1),
#   ('__number__th', 1),
#   ('but', 1),
#   ('m', 1),
#   ('off', 1),
#   ('campu', 1),
#   ('atm', 1),
#   ('could', 1),
#   ('pick', 1),
#   ('up', 1),
#   ('in', 1),
#   ('hour', 1),
#   ('or', 1),
#   ('two', 1),
#   ('', 1)],
#  [('anyth', 1), ('lor', 1), ('u', 1), ('decid', 1), ('', 1)],
#  [('__number__', 4),
#   ('u', 2),
#   ('reveal', 2),
#   ('have', 1),
#   ('a', 1),
#   ('secret', 1),
#   ('admir', 1),
#   ('who', 1),
#   ('think', 1),
#   ('r', 1),
#   ('so', 1),
#   ('special', 1),
#   ('call', 1),
#   ('to', 1),
#   ('opt', 1),
#   ('out', 1),
#   ('repli', 1),
#   ('stop', 1),
#   ('per', 1),
#   ('msg', 1),
#   ('recd', 1),
#   ('cust', 1),
#   ('care', 1)],
#  [('sorri', 1),
#   ('man', 1),
#   ('accident', 1),
#   ('left', 1),
#   ('my', 1),
#   ('phone', 1),
#   ('on', 1),
#   ('silent', 1),
#   ('last', 1),
#   ('night', 1),
#   ('and', 1),
#   ('didn', 1),
#   ('t', 1),
#   ('check', 1),
#   ('it', 1),
#   ('til', 1),
#   ('i', 1),
#   ('got', 1),
#   ('up', 1)],
#  [('__number__', 3),
#   ('chat', 2),
#   ('hack', 1),
#   ('get', 1),
#   ('backdoor', 1),
#   ('entri', 1),
#   ('into', 1),
#   ('room', 1),
#   ('at', 1),
#   ('a', 1),
#   ('fraction', 1),
#   ('of', 1),
#   ('the', 1),
#   ('cost', 1),
#   ('repli', 1),
#   ('neo__number__', 1),
#   ('or', 1),
#   ('call', 1),
#   ('to', 1),
#   ('subscrib', 1),
#   ('__number__p', 1),
#   ('pm', 1),
#   ('dp', 1),
#   ('bcm', 1),
#   ('box', 1),
#   ('ldn', 1),
#   ('wc__number__n__number__xx', 1)],
#  [('i', 3),
#   ('you', 2),
#   ('don', 1),
#   ('t', 1),
#   ('know', 1),
#   ('jack', 1),
#   ('shit', 1),
#   ('about', 1),
#   ('anyth', 1),
#   ('or', 1),
#   ('d', 1),
#   ('say', 1),
#   ('ask', 1),
#   ('someth', 1),
#   ('help', 1),
#   ('but', 1),
#   ('if', 1),
#   ('want', 1),
#   ('can', 1),
#   ('pretend', 1),
#   ('that', 1),
#   ('did', 1),
#   ('and', 1),
#   ('just', 1),
#   ('text', 1),
#   ('me', 1),
#   ('whatev', 1),
#   ('in', 1),
#   ('respons', 1),
#   ('to', 1),
#   ('the', 1),
#   ('hypotheticalhuagauahahuagahyuhagga', 1)],
#  [('what', 1),
#   ('time', 1),
#   ('is', 1),
#   ('ur', 1),
#   ('flight', 1),
#   ('tmr', 1),
#   ('', 1)],
#  [('up', 2),
#   ('to', 2),
#   ('the', 2),
#   ('i', 2),
#   ('at', 2),
#   ('__number__', 2),
#   ('just', 1),
#   ('got', 1),
#   ('have', 1),
#   ('be', 1),
#   ('out', 1),
#   ('of', 1),
#   ('room', 1),
#   ('veri', 1),
#   ('soon', 1),
#   ('hadn', 1),
#   ('t', 1),
#   ('put', 1),
#   ('clock', 1),
#   ('back', 1),
#   ('til', 1),
#   ('shout', 1),
#   ('everyon', 1),
#   ('get', 1),
#   ('and', 1),
#   ('then', 1),
#   ('realis', 1),
#   ('it', 1),
#   ('wa', 1),
#   ('wahay', 1),
#   ('anoth', 1),
#   ('hour', 1),
#   ('in', 1),
#   ('bed', 1),
#   ('', 1)],
#  [('ok', 1), ('i', 1), ('din', 1), ('get', 1), ('ur', 1), ('msg', 1), ('', 1)],
#  [('servic', 2),
#   ('you', 2),
#   ('not', 2),
#   ('free', 1),
#   ('msg', 1),
#   ('sorri', 1),
#   ('a', 1),
#   ('order', 1),
#   ('from', 1),
#   ('__number__', 1),
#   ('could', 1),
#   ('be', 1),
#   ('deliv', 1),
#   ('as', 1),
#   ('do', 1),
#   ('have', 1),
#   ('suffici', 1),
#   ('credit', 1),
#   ('pleas', 1),
#   ('top', 1),
#   ('up', 1),
#   ('to', 1),
#   ('receiv', 1),
#   ('the', 1),
#   ('', 1)],
#  [('', 2), ('that', 1), ('s', 1), ('not', 1), ('v', 1), ('romant', 1)],
#  [('probabl', 1),
#   ('gonna', 1),
#   ('swing', 1),
#   ('by', 1),
#   ('in', 1),
#   ('a', 1),
#   ('wee', 1),
#   ('bit', 1)],
#  [('__number__', 2),
#   ('your', 2),
#   ('congrat', 1),
#   ('mobil', 1),
#   ('__number__g', 1),
#   ('videophon', 1),
#   ('r', 1),
#   ('call', 1),
#   ('now', 1),
#   ('videochat', 1),
#   ('wid', 1),
#   ('mate', 1),
#   ('play', 1),
#   ('java', 1),
#   ('game', 1),
#   ('dload', 1),
#   ('polyph', 1),
#   ('music', 1),
#   ('nolin', 1),
#   ('rentl', 1),
#   ('', 1)],
#  [('i', 1),
#   ('d', 1),
#   ('say', 1),
#   ('that', 1),
#   ('s', 1),
#   ('a', 1),
#   ('good', 1),
#   ('sign', 1),
#   ('but', 1),
#   ('well', 1),
#   ('you', 1),
#   ('know', 1),
#   ('my', 1),
#   ('track', 1),
#   ('record', 1),
#   ('at', 1),
#   ('read', 1),
#   ('women', 1)],
#  [('we', 2),
#   ('s', 1),
#   ('if', 1),
#   ('have', 1),
#   ('one', 1),
#   ('good', 1),
#   ('partnership', 1),
#   ('go', 1),
#   ('will', 1),
#   ('take', 1),
#   ('lead', 1),
#   ('', 1)],
#  [('are', 1), ('you', 1), ('drive', 1), ('or', 1), ('train', 1), ('', 1)],
#  [('msg', 1), ('me', 1), ('when', 1), ('rajini', 1), ('come', 1), ('', 1)],
#  [('and', 2),
#   ('whenev', 1),
#   ('you', 1),
#   ('i', 1),
#   ('see', 1),
#   ('we', 1),
#   ('can', 1),
#   ('still', 1),
#   ('hook', 1),
#   ('up', 1),
#   ('too', 1),
#   ('', 1)],
#  [('for', 1),
#   ('your', 1),
#   ('chanc', 1),
#   ('to', 1),
#   ('win', 1),
#   ('a', 1),
#   ('free', 1),
#   ('bluetooth', 1),
#   ('headset', 1),
#   ('then', 1),
#   ('simpli', 1),
#   ('repli', 1),
#   ('back', 1),
#   ('with', 1),
#   ('adp', 1)],
#  [('hey', 1),
#   ('i', 1),
#   ('will', 1),
#   ('be', 1),
#   ('late', 1),
#   ('ah', 1),
#   ('meet', 1),
#   ('you', 1),
#   ('at', 1),
#   ('__number__', 1),
#   ('', 1)],
#  [('me', 3),
#   ('my', 2),
#   ('i', 2),
#   ('hurt', 1),
#   ('teas', 1),
#   ('make', 1),
#   ('cri', 1),
#   ('but', 1),
#   ('in', 1),
#   ('the', 1),
#   ('end', 1),
#   ('of', 1),
#   ('life', 1),
#   ('when', 1),
#   ('die', 1),
#   ('plz', 1),
#   ('keep', 1),
#   ('one', 1),
#   ('rose', 1),
#   ('on', 1),
#   ('grave', 1),
#   ('and', 1),
#   ('say', 1),
#   ('stupid', 1),
#   ('miss', 1),
#   ('u', 1),
#   ('have', 1),
#   ('a', 1),
#   ('nice', 1),
#   ('day', 1),
#   ('bslvyl', 1)],
#  [('ani', 1),
#   ('way', 1),
#   ('where', 1),
#   ('are', 1),
#   ('you', 1),
#   ('and', 1),
#   ('what', 1),
#   ('do', 1),
#   ('', 1)],
#  [('a', 3),
#   ('spook', 2),
#   ('logo', 2),
#   ('pic', 2),
#   ('up', 1),
#   ('your', 1),
#   ('mob', 1),
#   ('with', 1),
#   ('halloween', 1),
#   ('collect', 1),
#   ('of', 1),
#   ('messag', 1),
#   ('plu', 1),
#   ('free', 1),
#   ('eeri', 1),
#   ('tone', 1),
#   ('txt', 1),
#   ('card', 1),
#   ('to', 1),
#   ('__number__', 1),
#   ('zed', 1),
#   ('__number__p', 1),
#   ('per', 1)],
#  [('s', 1),
#   ('i', 1),
#   ('think', 1),
#   ('he', 1),
#   ('is', 1),
#   ('wast', 1),
#   ('for', 1),
#   ('rr', 1),
#   ('', 1)],
#  [('__number__', 1), ('min', 1), ('later', 1), ('k', 1), ('', 1)],
#  [('am', 2),
#   ('not', 1),
#   ('work', 1),
#   ('but', 1),
#   ('up', 1),
#   ('to', 1),
#   ('eye', 1),
#   ('in', 1),
#   ('philosophi', 1),
#   ('so', 1),
#   ('will', 1),
#   ('text', 1),
#   ('u', 1),
#   ('later', 1),
#   ('when', 1),
#   ('a', 1),
#   ('bit', 1),
#   ('more', 1),
#   ('free', 1),
#   ('for', 1),
#   ('chat', 1),
#   ('', 1)],
#  [('who', 2),
#   ('you', 2),
#   ('and', 2),
#   ('don', 1),
#   ('t', 1),
#   ('forget', 1),
#   ('own', 1),
#   ('s', 1),
#   ('privat', 1),
#   ('properti', 1),
#   ('are', 1),
#   ('be', 1),
#   ('my', 1),
#   ('good', 1),
#   ('boy', 1),
#   ('alway', 1),
#   ('passion', 1),
#   ('kiss', 1),
#   ('', 1)],
#  [('work', 2),
#   ('he', 2),
#   ('mark', 1),
#   ('tomorrow', 1),
#   ('get', 1),
#   ('out', 1),
#   ('at', 1),
#   ('__number__', 1),
#   ('hi', 1),
#   ('is', 1),
#   ('by', 1),
#   ('your', 1),
#   ('hous', 1),
#   ('so', 1),
#   ('can', 1),
#   ('meet', 1),
#   ('u', 1),
#   ('afterward', 1),
#   ('', 1)],
#  [('__number__', 4),
#   ('is', 2),
#   ('the', 2),
#   ('have', 2),
#   ('u', 2),
#   ('thi', 1),
#   ('__number__nd', 1),
#   ('time', 1),
#   ('we', 1),
#   ('tri', 1),
#   ('contact', 1),
#   ('won', 1),
#   ('pound', 1),
#   ('prize', 1),
#   ('claim', 1),
#   ('easi', 1),
#   ('call', 1),
#   ('now', 1),
#   ('onli', 1),
#   ('__number__p', 1),
#   ('per', 1),
#   ('min', 1),
#   ('bt', 1),
#   ('nation', 1),
#   ('rate', 1)],
#  [('i', 3),
#   ('m', 2),
#   ('on', 2),
#   ('a', 2),
#   ('diet', 2),
#   ('but', 1),
#   ('and', 1),
#   ('ate', 1),
#   ('__number__', 1),
#   ('too', 1),
#   ('mani', 1),
#   ('slice', 1),
#   ('of', 1),
#   ('pizza', 1),
#   ('yesterday', 1),
#   ('ugh', 1),
#   ('alway', 1),
#   ('', 1)],
#  [('cramp', 1), ('stop', 1), ('go', 1), ('back', 1), ('to', 1), ('sleep', 1)],
#  [('to', 2),
#   ('he', 1),
#   ('say', 1),
#   ('hi', 1),
#   ('and', 1),
#   ('get', 1),
#   ('your', 1),
#   ('ass', 1),
#   ('back', 1),
#   ('south', 1),
#   ('tampa', 1),
#   ('prefer', 1),
#   ('at', 1),
#   ('a', 1),
#   ('kegger', 1),
#   ('', 1)],
#  [('i', 2),
#   ('can', 1),
#   ('but', 1),
#   ('it', 1),
#   ('will', 1),
#   ('tell', 1),
#   ('quit', 1),
#   ('long', 1),
#   ('co', 1),
#   ('haven', 1),
#   ('t', 1),
#   ('finish', 1),
#   ('my', 1),
#   ('film', 1),
#   ('yet', 1),
#   ('', 1)],
#  [('no', 1), ('scream', 1), ('mean', 1), ('shout', 1), ('', 1)],
#  [('tell', 1),
#   ('them', 1),
#   ('no', 1),
#   ('need', 1),
#   ('to', 1),
#   ('investig', 1),
#   ('about', 1),
#   ('me', 1),
#   ('anywher', 1),
#   ('', 1)],
#  [('realli', 1),
#   ('good', 1),
#   ('dhanush', 1),
#   ('rock', 1),
#   ('onc', 1),
#   ('again', 1),
#   ('', 1)],
#  [('ye', 1), ('he', 1), ('have', 1), ('good', 1), ('crickit', 1), ('mind', 1)],
#  [('call', 2),
#   ('him', 2),
#   ('you', 1),
#   ('now', 1),
#   ('ok', 1),
#   ('i', 1),
#   ('said', 1)],
#  [('pic', 2),
#   ('to', 2),
#   ('__number__', 2),
#   ('hottest', 1),
#   ('straight', 1),
#   ('your', 1),
#   ('phone', 1),
#   ('see', 1),
#   ('me', 1),
#   ('get', 1),
#   ('wet', 1),
#   ('and', 1),
#   ('want', 1),
#   ('just', 1),
#   ('for', 1),
#   ('you', 1),
#   ('xx', 1),
#   ('text', 1),
#   ('now', 1),
#   ('txt', 1),
#   ('cost', 1),
#   ('__number__p', 1),
#   ('textoper', 1),
#   ('g__number__ga', 1),
#   ('xxx', 1)],
#  [('erm', 1),
#   ('woodland', 1),
#   ('avenu', 1),
#   ('somewher', 1),
#   ('do', 1),
#   ('you', 1),
#   ('get', 1),
#   ('the', 1),
#   ('parish', 1),
#   ('magazin', 1),
#   ('hi', 1),
#   ('telephon', 1),
#   ('number', 1),
#   ('will', 1),
#   ('be', 1),
#   ('in', 1),
#   ('there', 1),
#   ('', 1)],
#  [('mail', 2),
#   ('check', 1),
#   ('i', 1),
#   ('have', 1),
#   ('varma', 1),
#   ('and', 1),
#   ('kept', 1),
#   ('copi', 1),
#   ('to', 1),
#   ('you', 1),
#   ('regard', 1),
#   ('membership', 1),
#   ('take', 1),
#   ('care', 1),
#   ('insha', 1),
#   ('allah', 1),
#   ('', 1)],
#  [('i', 6),
#   ('hope', 3),
#   ('you', 3),
#   ('is', 3),
#   ('have', 2),
#   ('to', 2),
#   ('my', 2),
#   ('and', 2),
#   ('it', 2),
#   ('a', 2),
#   ('could', 2),
#   ('had', 1),
#   ('been', 1),
#   ('would', 1),
#   ('not', 1),
#   ('send', 1),
#   ('thi', 1),
#   ('messag', 1),
#   ('rent', 1),
#   ('due', 1),
#   ('dont', 1),
#   ('enough', 1),
#   ('for', 1),
#   ('reserv', 1),
#   ('are', 1),
#   ('complet', 1),
#   ('gone', 1),
#   ('loan', 1),
#   ('need', 1),
#   ('wa', 1),
#   ('her', 1),
#   ('the', 1),
#   ('balanc', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('there', 1),
#   ('way', 1),
#   ('get', 1),
#   ('that', 1),
#   ('from', 1),
#   ('till', 1),
#   ('mid', 1),
#   ('march', 1),
#   ('when', 1),
#   ('pay', 1),
#   ('back', 1),
#   ('', 1)],
#  [('__number__', 4),
#   ('claim', 2),
#   ('blu', 2),
#   ('in', 2),
#   ('congratul', 1),
#   ('u', 1),
#   ('can', 1),
#   ('vip', 1),
#   ('row', 1),
#   ('a', 1),
#   ('ticket', 1),
#   ('c', 1),
#   ('concert', 1),
#   ('novemb', 1),
#   ('or', 1),
#   ('gift', 1),
#   ('guarante', 1),
#   ('call', 1),
#   ('to', 1),
#   ('ts', 1),
#   ('cs', 1),
#   ('__url__', 1),
#   ('cost', 1),
#   ('__number__max', 1)],
#  [('should', 1),
#   ('i', 1),
#   ('send', 1),
#   ('you', 1),
#   ('naughti', 1),
#   ('pix', 1),
#   ('', 1)],
#  [('i', 1),
#   ('love', 1),
#   ('ya', 1),
#   ('too', 1),
#   ('but', 1),
#   ('tri', 1),
#   ('and', 1),
#   ('budget', 1),
#   ('your', 1),
#   ('money', 1),
#   ('better', 1),
#   ('babe', 1),
#   ('gari', 1),
#   ('would', 1),
#   ('freak', 1),
#   ('on', 1),
#   ('me', 1),
#   ('if', 1),
#   ('he', 1),
#   ('knew', 1)],
#  [('pleas', 1),
#   ('call', 1),
#   ('__number__', 1),
#   ('immedi', 1),
#   ('as', 1),
#   ('there', 1),
#   ('is', 1),
#   ('an', 1),
#   ('urgent', 1),
#   ('messag', 1),
#   ('wait', 1),
#   ('for', 1),
#   ('you', 1),
#   ('', 1)],
#  [('so', 1),
#   ('dont', 1),
#   ('use', 1),
#   ('hook', 1),
#   ('up', 1),
#   ('ani', 1),
#   ('how', 1)],
#  [('never', 2),
#   ('password', 2),
#   ('pleas', 1),
#   ('protect', 1),
#   ('yourself', 1),
#   ('from', 1),
#   ('e', 1),
#   ('threat', 1),
#   ('sib', 1),
#   ('ask', 1),
#   ('for', 1),
#   ('sensit', 1),
#   ('inform', 1),
#   ('like', 1),
#   ('atm', 1),
#   ('sm', 1),
#   ('pin', 1),
#   ('thru', 1),
#   ('email', 1),
#   ('share', 1),
#   ('your', 1),
#   ('with', 1),
#   ('anybodi', 1),
#   ('', 1)],
#  [('but', 1),
#   ('i', 1),
#   ('dint', 1),
#   ('slept', 1),
#   ('in', 1),
#   ('afternoon', 1),
#   ('', 1)],
#  [('goodmorn', 1), ('sleep', 1), ('ga', 1), ('', 1)],
#  [('some', 1),
#   ('friend', 1),
#   ('want', 1),
#   ('me', 1),
#   ('to', 1),
#   ('drive', 1),
#   ('em', 1),
#   ('someplac', 1),
#   ('probabl', 1),
#   ('take', 1),
#   ('a', 1),
#   ('while', 1)],
#  [('i', 1),
#   ('ll', 1),
#   ('get', 1),
#   ('there', 1),
#   ('tomorrow', 1),
#   ('and', 1),
#   ('send', 1),
#   ('it', 1),
#   ('to', 1),
#   ('you', 1)],
#  [('da', 2),
#   ('hey', 1),
#   ('check', 1),
#   ('it', 1),
#   ('i', 1),
#   ('have', 1),
#   ('list', 1),
#   ('', 1)],
#  [('i', 4),
#   ('you', 3),
#   ('the', 3),
#   ('so', 2),
#   ('to', 2),
#   ('miss', 1),
#   ('much', 1),
#   ('m', 1),
#   ('despar', 1),
#   ('have', 1),
#   ('record', 1),
#   ('messag', 1),
#   ('left', 1),
#   ('for', 1),
#   ('me', 1),
#   ('other', 1),
#   ('day', 1),
#   ('and', 1),
#   ('listen', 1),
#   ('it', 1),
#   ('just', 1),
#   ('hear', 1),
#   ('sound', 1),
#   ('of', 1),
#   ('your', 1),
#   ('voic', 1),
#   ('love', 1)],
#  [('i', 2),
#   ('sorri', 1),
#   ('ll', 1),
#   ('call', 1),
#   ('you', 1),
#   ('later', 1),
#   ('am', 1),
#   ('in', 1),
#   ('meet', 1),
#   ('sir', 1),
#   ('', 1)],
#  [('__number__', 2),
#   ('a', 2),
#   ('b', 2),
#   ('or', 2),
#   ('c', 2),
#   ('ur', 1),
#   ('balanc', 1),
#   ('is', 1),
#   ('now', 1),
#   ('next', 1),
#   ('question', 1),
#   ('complet', 1),
#   ('the', 1),
#   ('landmark', 1),
#   ('big', 1),
#   ('bob', 1),
#   ('barri', 1),
#   ('ben', 1),
#   ('text', 1),
#   ('to', 1),
#   ('good', 1),
#   ('luck', 1),
#   ('', 1)],
#  [('__number__', 3),
#   ('you', 2),
#   ('prize', 2),
#   ('congratul', 1),
#   ('ve', 1),
#   ('won', 1),
#   ('re', 1),
#   ('a', 1),
#   ('winner', 1),
#   ('in', 1),
#   ('our', 1),
#   ('august', 1),
#   ('draw', 1),
#   ('call', 1),
#   ('now', 1),
#   ('code', 1),
#   ('', 1)],
#  [('i', 3),
#   ('oic', 1),
#   ('saw', 1),
#   ('him', 1),
#   ('too', 1),
#   ('but', 1),
#   ('tot', 1),
#   ('he', 1),
#   ('din', 1),
#   ('c', 1),
#   ('me', 1),
#   ('found', 1),
#   ('a', 1),
#   ('group', 1),
#   ('liao', 1),
#   ('', 1)],
#  [('ok', 1),
#   ('both', 1),
#   ('our', 1),
#   ('day', 1),
#   ('so', 1),
#   ('what', 1),
#   ('are', 1),
#   ('you', 1),
#   ('make', 1),
#   ('for', 1),
#   ('dinner', 1),
#   ('tonit', 1),
#   ('am', 1),
#   ('i', 1),
#   ('invit', 1),
#   ('', 1)],
#  [('movi', 2),
#   ('and', 2),
#   ('is', 1),
#   ('there', 1),
#   ('ani', 1),
#   ('theatr', 1),
#   ('i', 1),
#   ('can', 1),
#   ('go', 1),
#   ('to', 1),
#   ('watch', 1),
#   ('unlimit', 1),
#   ('just', 1),
#   ('pay', 1),
#   ('onc', 1),
#   ('', 1)],
#  [('how', 1), ('much', 1), ('you', 1), ('got', 1), ('for', 1), ('clean', 1)],
#  [('i', 2),
#   ('yeah', 1),
#   ('ll', 1),
#   ('leav', 1),
#   ('in', 1),
#   ('a', 1),
#   ('coupl', 1),
#   ('minut', 1),
#   ('amp', 1),
#   ('let', 1),
#   ('you', 1),
#   ('know', 1),
#   ('when', 1),
#   ('get', 1),
#   ('to', 1),
#   ('mu', 1)],
#  [('ye', 1),
#   ('princess', 1),
#   ('i', 1),
#   ('want', 1),
#   ('to', 1),
#   ('catch', 1),
#   ('you', 1),
#   ('with', 1),
#   ('my', 1),
#   ('big', 1),
#   ('strong', 1),
#   ('hand', 1),
#   ('', 1)],
#  [('to', 2),
#   ('hi', 2),
#   ('stop', 2),
#   ('sm', 1),
#   ('ac', 1),
#   ('sun__number__', 1),
#   ('post', 1),
#   ('hello', 1),
#   ('you', 1),
#   ('seem', 1),
#   ('cool', 1),
#   ('want', 1),
#   ('say', 1),
#   ('send', 1),
#   ('__number__', 1)],
#  [('now', 1),
#   ('what', 1),
#   ('your', 1),
#   ('hous', 1),
#   ('again', 1),
#   ('and', 1),
#   ('do', 1),
#   ('you', 1),
#   ('have', 1),
#   ('ani', 1),
#   ('beer', 1),
#   ('there', 1),
#   ('', 1)],
#  [('whi', 1), ('do', 1), ('you', 1), ('ask', 1), ('princess', 1), ('', 1)],
#  [('u', 3),
#   ('i', 2),
#   ('so', 2),
#   ('wan', 2),
#   ('__number__', 2),
#   ('ask', 2),
#   ('got', 1),
#   ('to', 1),
#   ('video', 1),
#   ('tape', 1),
#   ('pple', 1),
#   ('type', 1),
#   ('in', 1),
#   ('messag', 1),
#   ('lor', 1),
#   ('free', 1),
#   ('help', 1),
#   ('me', 1),
#   ('hee', 1),
#   ('co', 1),
#   ('noe', 1),
#   ('watch', 1),
#   ('infern', 1),
#   ('affair', 1),
#   ('along', 1),
#   ('shuhui', 1),
#   ('oso', 1),
#   ('', 1)],
#  [('xma', 4),
#   ('the', 3),
#   ('is', 3),
#   ('stori', 1),
#   ('peac', 1),
#   ('msg', 1),
#   ('love', 1),
#   ('miracl', 1),
#   ('jesu', 1),
#   ('hav', 1),
#   ('a', 1),
#   ('bless', 1),
#   ('month', 1),
#   ('ahead', 1),
#   ('amp', 1),
#   ('wish', 1),
#   ('u', 1),
#   ('merri', 1),
#   ('', 1)],
#  [('hi', 1),
#   ('it', 1),
#   ('in', 1),
#   ('durban', 1),
#   ('are', 1),
#   ('you', 1),
#   ('still', 1),
#   ('on', 1),
#   ('thi', 1),
#   ('number', 1)],
#  [('take', 1),
#   ('us', 1),
#   ('out', 1),
#   ('shop', 1),
#   ('and', 1),
#   ('mark', 1),
#   ('will', 1),
#   ('distract', 1),
#   ('isaiah', 1),
#   ('d', 1)],
#  [('__number__', 5),
#   ('a', 3),
#   ('you', 1),
#   ('are', 1),
#   ('winner', 1),
#   ('u', 1),
#   ('have', 1),
#   ('been', 1),
#   ('special', 1),
#   ('select', 1),
#   ('receiv', 1),
#   ('cash', 1),
#   ('or', 1),
#   ('holiday', 1),
#   ('flight', 1),
#   ('inc', 1),
#   ('speak', 1),
#   ('to', 1),
#   ('live', 1),
#   ('oper', 1),
#   ('claim', 1)],
#  [('have', 1),
#   ('you', 1),
#   ('been', 1),
#   ('practis', 1),
#   ('your', 1),
#   ('curtsey', 1),
#   ('', 1)],
#  [('shall', 1), ('i', 1), ('start', 1), ('from', 1), ('hear', 1), ('', 1)],
#  [('ok', 1), ('so', 1), ('april', 1), ('cant', 1), ('wait', 1)],
#  [('i', 2),
#   ('ok', 1),
#   ('vl', 1),
#   ('do', 1),
#   ('u', 1),
#   ('know', 1),
#   ('got', 1),
#   ('adsens', 1),
#   ('approv', 1),
#   ('', 1)],
#  [('in', 2),
#   ('text', 2),
#   ('talk', 1),
#   ('sexi', 1),
#   ('make', 1),
#   ('new', 1),
#   ('friend', 1),
#   ('or', 1),
#   ('fall', 1),
#   ('love', 1),
#   ('the', 1),
#   ('world', 1),
#   ('most', 1),
#   ('discreet', 1),
#   ('date', 1),
#   ('servic', 1),
#   ('just', 1),
#   ('vip', 1),
#   ('to', 1),
#   ('__number__', 1),
#   ('and', 1),
#   ('see', 1),
#   ('who', 1),
#   ('you', 1),
#   ('could', 1),
#   ('meet', 1),
#   ('', 1)],
#  [('k', 1),
#   ('i', 1),
#   ('m', 1),
#   ('leav', 1),
#   ('soon', 1),
#   ('be', 1),
#   ('there', 1),
#   ('a', 1),
#   ('littl', 1),
#   ('after', 1),
#   ('__number__', 1)],
#  [('i', 2),
#   ('ll', 1),
#   ('text', 1),
#   ('you', 1),
#   ('when', 1),
#   ('drop', 1),
#   ('x', 1),
#   ('off', 1)],
#  [('i', 1), ('m', 1), ('done', 1), ('oredi', 1), ('', 1)],
#  [('__number__', 13),
#   ('lt', 3),
#   ('gt', 3),
#   ('onli', 1),
#   ('student', 1),
#   ('solv', 1),
#   ('thi', 1),
#   ('cat', 1),
#   ('question', 1),
#   ('in', 1),
#   ('xam', 1),
#   ('then', 1),
#   ('tell', 1),
#   ('me', 1),
#   ('the', 1),
#   ('answer', 1),
#   ('if', 1),
#   ('u', 1),
#   ('r', 1),
#   ('brilliant', 1),
#   ('__number__th', 1),
#   ('i', 1),
#   ('got', 1),
#   ('d', 1),
#   ('answr', 1),
#   ('', 1)],
#  [('di', 2),
#   ('is', 2),
#   ('my', 2),
#   ('num', 2),
#   ('yiju', 1),
#   ('i', 1),
#   ('ju', 1),
#   ('saw', 1),
#   ('ur', 1),
#   ('mail', 1),
#   ('in', 1),
#   ('case', 1),
#   ('huim', 1),
#   ('havent', 1),
#   ('sent', 1),
#   ('u', 1),
#   ('', 1)],
#  [('', 2),
#   ('minut', 2),
#   ('lt', 1),
#   ('gt', 1),
#   ('ish', 1),
#   ('wa', 1),
#   ('__number__', 1),
#   ('ago', 1),
#   ('wtf', 1)],
#  [('the', 2),
#   ('__number__', 2),
#   ('later', 2),
#   ('hi', 1),
#   ('babi', 1),
#   ('im', 1),
#   ('sat', 1),
#   ('on', 1),
#   ('bloodi', 1),
#   ('bu', 1),
#   ('at', 1),
#   ('mo', 1),
#   ('and', 1),
#   ('i', 1),
#   ('wont', 1),
#   ('be', 1),
#   ('home', 1),
#   ('until', 1),
#   ('about', 1),
#   ('wanna', 1),
#   ('do', 1),
#   ('somethin', 1),
#   ('call', 1),
#   ('me', 1),
#   ('ortxt', 1),
#   ('back', 1),
#   ('jess', 1),
#   ('xx', 1)],
#  [('you', 4),
#   ('my', 3),
#   ('are', 3),
#   ('good', 2),
#   ('afternoon', 1),
#   ('boytoy', 1),
#   ('how', 1),
#   ('feel', 1),
#   ('today', 1),
#   ('better', 1),
#   ('i', 1),
#   ('hope', 1),
#   ('be', 1),
#   ('boy', 1),
#   ('obedi', 1),
#   ('slave', 1),
#   ('do', 1),
#   ('pleas', 1),
#   ('your', 1),
#   ('queen', 1),
#   ('', 1)],
#  [('wa', 1), ('the', 1), ('farm', 1), ('open', 1), ('', 1)],
#  [('__number__', 5),
#   ('u', 2),
#   ('rgent', 1),
#   ('thi', 1),
#   ('is', 1),
#   ('the', 1),
#   ('__number__nd', 1),
#   ('attempt', 1),
#   ('to', 1),
#   ('contact', 1),
#   ('have', 1),
#   ('won', 1),
#   ('call', 1),
#   ('b__number__', 1),
#   ('t', 1),
#   ('csbcm__number__wc__number__n__number__xx', 1),
#   ('callcost', 1),
#   ('__number__ppm', 1),
#   ('mobilesvari', 1),
#   ('max', 1)],
#  [('so', 1),
#   ('i', 1),
#   ('could', 1),
#   ('kiss', 1),
#   ('and', 1),
#   ('feel', 1),
#   ('you', 1),
#   ('next', 1),
#   ('to', 1),
#   ('me', 1),
#   ('', 1)],
#  [('you', 2),
#   ('the', 1),
#   ('ga', 1),
#   ('station', 1),
#   ('is', 1),
#   ('like', 1),
#   ('a', 1),
#   ('block', 1),
#   ('away', 1),
#   ('from', 1),
#   ('my', 1),
#   ('hous', 1),
#   ('ll', 1),
#   ('drive', 1),
#   ('right', 1),
#   ('by', 1),
#   ('it', 1),
#   ('sinc', 1),
#   ('armenia', 1),
#   ('end', 1),
#   ('at', 1),
#   ('swann', 1),
#   ('and', 1),
#   ('have', 1),
#   ('to', 1),
#   ('take', 1),
#   ('howard', 1)],
#  [('he', 3),
#   ('if', 1),
#   ('start', 1),
#   ('search', 1),
#   ('will', 1),
#   ('get', 1),
#   ('job', 1),
#   ('in', 1),
#   ('few', 1),
#   ('day', 1),
#   ('have', 1),
#   ('great', 1),
#   ('potenti', 1),
#   ('and', 1),
#   ('talent', 1),
#   ('', 1)],
#  [('just', 1), ('tast', 1), ('fish', 1), ('curri', 1), ('p', 1)],
#  [('did', 1),
#   ('he', 1),
#   ('just', 1),
#   ('say', 1),
#   ('somebodi', 1),
#   ('is', 1),
#   ('name', 1),
#   ('tampa', 1)],
#  [('when', 1), ('should', 1), ('i', 1), ('come', 1), ('over', 1), ('', 1)],
#  [('yup', 1),
#   ('i', 1),
#   ('ve', 1),
#   ('finish', 1),
#   ('c', 1),
#   ('ü', 1),
#   ('there', 1),
#   ('', 1)],
#  [('ye', 1), ('there', 1), ('were', 1), ('mani', 1), ('sweet', 1)],
#  [('just', 1),
#   ('do', 1),
#   ('what', 1),
#   ('ever', 1),
#   ('is', 1),
#   ('easier', 1),
#   ('for', 1),
#   ('you', 1)],
#  [('i', 2),
#   ('t', 2),
#   ('and', 1),
#   ('don', 1),
#   ('plan', 1),
#   ('on', 1),
#   ('stay', 1),
#   ('the', 1),
#   ('night', 1),
#   ('but', 1),
#   ('prolli', 1),
#   ('won', 1),
#   ('be', 1),
#   ('back', 1),
#   ('til', 1),
#   ('late', 1)],
#  [('yeah', 1),
#   ('work', 1),
#   ('is', 1),
#   ('fine', 1),
#   ('start', 1),
#   ('last', 1),
#   ('week', 1),
#   ('all', 1),
#   ('the', 1),
#   ('same', 1),
#   ('stuff', 1),
#   ('as', 1),
#   ('befor', 1),
#   ('dull', 1),
#   ('but', 1),
#   ('easi', 1),
#   ('and', 1),
#   ('guy', 1),
#   ('are', 1),
#   ('fun', 1),
#   ('', 1)],
#  [('well', 1),
#   ('i', 1),
#   ('might', 1),
#   ('not', 1),
#   ('come', 1),
#   ('then', 1),
#   ('', 1)],
#  [('that', 2),
#   ('you', 2),
#   ('same', 2),
#   ('s', 1),
#   ('the', 1),
#   ('troubl', 1),
#   ('with', 1),
#   ('class', 1),
#   ('go', 1),
#   ('well', 1),
#   ('re', 1),
#   ('due', 1),
#   ('a', 1),
#   ('dodgey', 1),
#   ('one', 1),
#   ('expect', 1),
#   ('mine', 1),
#   ('tomo', 1),
#   ('see', 1),
#   ('for', 1),
#   ('recoveri', 1),
#   ('time', 1),
#   ('place', 1)],
#  [('it', 2),
#   ('got', 1),
#   ('look', 1),
#   ('scrumptiou', 1),
#   ('daddi', 1),
#   ('want', 1),
#   ('to', 1),
#   ('eat', 1),
#   ('you', 1),
#   ('all', 1),
#   ('night', 1),
#   ('long', 1),
#   ('', 1)],
#  [('wait', 1),
#   ('i', 1),
#   ('will', 1),
#   ('come', 1),
#   ('out', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('min', 1),
#   ('', 1)],
#  [('enjoy', 1), ('ur', 1), ('life', 1), ('good', 1), ('night', 1)],
#  [('__number__', 2),
#   ('bright', 2),
#   ('light', 2),
#   ('my', 1),
#   ('slave', 1),
#   ('i', 1),
#   ('want', 1),
#   ('you', 1),
#   ('to', 1),
#   ('take', 1),
#   ('or', 1),
#   ('pictur', 1),
#   ('of', 1),
#   ('yourself', 1),
#   ('today', 1),
#   ('in', 1),
#   ('on', 1),
#   ('your', 1),
#   ('cell', 1),
#   ('phone', 1),
#   ('', 1)],
#  [('he', 3),
#   ('s', 3),
#   ('like', 2),
#   ('i', 2),
#   ('crazi', 1),
#   ('ar', 1),
#   ('marri', 1),
#   ('ü', 1),
#   ('gd', 1),
#   ('look', 1),
#   ('guy', 1),
#   ('not', 1),
#   ('me', 1),
#   ('my', 1),
#   ('fren', 1),
#   ('say', 1),
#   ('korean', 1),
#   ('leona', 1),
#   ('fave', 1),
#   ('but', 1),
#   ('dun', 1),
#   ('thk', 1),
#   ('is', 1),
#   ('aft', 1),
#   ('some', 1),
#   ('think', 1),
#   ('mayb', 1),
#   ('most', 1),
#   ('prob', 1),
#   ('ll', 1),
#   ('go', 1),
#   ('', 1)],
#  [('ü', 1),
#   ('no', 1),
#   ('home', 1),
#   ('work', 1),
#   ('to', 1),
#   ('do', 1),
#   ('meh', 1),
#   ('', 1)],
#  [('oh', 1),
#   ('wow', 1),
#   ('that', 1),
#   ('gay', 1),
#   ('will', 1),
#   ('firmwar', 1),
#   ('updat', 1),
#   ('help', 1)],
#  [('you', 2),
#   ('could', 1),
#   ('have', 1),
#   ('seen', 1),
#   ('me', 1),
#   ('i', 1),
#   ('did', 1),
#   ('t', 1),
#   ('recognis', 1),
#   ('face', 1),
#   ('', 1)],
#  [('k', 1), ('all', 1), ('the', 1), ('best', 1), ('congrat', 1), ('', 1)],
#  [('dear', 1),
#   ('good', 1),
#   ('morn', 1),
#   ('now', 1),
#   ('onli', 1),
#   ('i', 1),
#   ('am', 1),
#   ('up', 1)],
#  [('how', 1), ('s', 1), ('ur', 1), ('paper', 1), ('', 1)],
#  [('is', 1),
#   ('xy', 1),
#   ('in', 1),
#   ('ur', 1),
#   ('car', 1),
#   ('when', 1),
#   ('u', 1),
#   ('pick', 1),
#   ('me', 1),
#   ('up', 1),
#   ('', 1)],
#  [('yeah', 1),
#   ('sure', 1),
#   ('i', 1),
#   ('ll', 1),
#   ('leav', 1),
#   ('in', 1),
#   ('a', 1),
#   ('min', 1)],
#  [('with', 2),
#   ('nuther', 2),
#   ('i', 1),
#   ('know', 1),
#   ('dat', 1),
#   ('feelin', 1),
#   ('had', 1),
#   ('it', 1),
#   ('pete', 1),
#   ('wuld', 1),
#   ('get', 1),
#   ('em', 1),
#   ('place', 1),
#   ('time', 1),
#   ('mayb', 1),
#   ('', 1)],
#  [('it', 3),
#   ('feel', 2),
#   ('when', 2),
#   ('someon', 2),
#   ('beauti', 1),
#   ('truth', 1),
#   ('against', 1),
#   ('graviti', 1),
#   ('read', 1),
#   ('care', 1),
#   ('our', 1),
#   ('heart', 1),
#   ('light', 1),
#   ('is', 1),
#   ('in', 1),
#   ('but', 1),
#   ('veri', 1),
#   ('heavi', 1),
#   ('leav', 1),
#   ('good', 1),
#   ('night', 1)],
#  [('prize', 2),
#   ('draw', 2),
#   ('__number__', 2),
#   ('xma', 1),
#   ('we', 1),
#   ('are', 1),
#   ('tri', 1),
#   ('to', 1),
#   ('contact', 1),
#   ('u', 1),
#   ('today', 1),
#   ('show', 1),
#   ('that', 1),
#   ('you', 1),
#   ('have', 1),
#   ('won', 1),
#   ('a', 1),
#   ('guarante', 1),
#   ('call', 1),
#   ('from', 1),
#   ('land', 1),
#   ('line', 1),
#   ('valid', 1),
#   ('__number__hr', 1),
#   ('onli', 1)],
#  [('you', 3),
#   ('to', 3),
#   ('', 2),
#   ('i', 2),
#   ('miss', 2),
#   ('t', 2),
#   ('me', 2),
#   ('deep', 1),
#   ('sigh', 1),
#   ('am', 1),
#   ('realli', 1),
#   ('surpris', 1),
#   ('haven', 1),
#   ('gone', 1),
#   ('the', 1),
#   ('net', 1),
#   ('cafe', 1),
#   ('yet', 1),
#   ('get', 1),
#   ('don', 1)],
#  [('__number__', 5),
#   ('to', 4),
#   ('bahama', 2),
#   ('ur', 1),
#   ('go', 1),
#   ('callfreefon', 1),
#   ('and', 1),
#   ('speak', 1),
#   ('a', 1),
#   ('live', 1),
#   ('oper', 1),
#   ('claim', 1),
#   ('either', 1),
#   ('cruis', 1),
#   ('of', 1),
#   ('cash', 1),
#   ('onli', 1),
#   ('opt', 1),
#   ('out', 1),
#   ('txt', 1),
#   ('x', 1)],
#  [('__number__', 3),
#   ('call', 3),
#   ('unlimit', 2),
#   ('txt', 2),
#   ('stop', 2),
#   ('freemsg', 1),
#   ('month', 1),
#   ('free', 1),
#   ('activ', 1),
#   ('smartcal', 1),
#   ('to', 1),
#   ('no', 1),
#   ('subscriptn__number__gbp', 1),
#   ('wk', 1),
#   ('help', 1),
#   ('landlineonli', 1)],
#  [('k', 2),
#   ('how', 1),
#   ('much', 1),
#   ('doe', 1),
#   ('it', 1),
#   ('cost', 1),
#   ('', 1)],
#  [('good', 1),
#   ('morn', 1),
#   ('my', 1),
#   ('dear', 1),
#   ('have', 1),
#   ('a', 1),
#   ('great', 1),
#   ('amp', 1),
#   ('success', 1),
#   ('day', 1),
#   ('', 1)],
#  [('send', 1), ('me', 1), ('the', 1), ('new', 1), ('number', 1)],
#  [('we', 1), ('still', 1), ('on', 1), ('for', 1), ('tonight', 1), ('', 1)],
#  [('ok', 1), ('', 1)],
#  [('wit', 2),
#   ('ya', 1),
#   ('i', 1),
#   ('knw', 1),
#   ('u', 1),
#   ('vl', 1),
#   ('giv', 1),
#   ('it', 1),
#   ('ok', 1),
#   ('thank', 1),
#   ('kano', 1),
#   ('anyway', 1),
#   ('enjoy', 1),
#   ('ur', 1),
#   ('famili', 1),
#   ('__number__st', 1),
#   ('salari', 1),
#   ('', 1)],
#  [('care', 2),
#   ('about', 2),
#   ('stuff', 2),
#   ('no', 1),
#   ('i', 1),
#   ('decid', 1),
#   ('that', 1),
#   ('onli', 1),
#   ('peopl', 1),
#   ('who', 1),
#   ('vote', 1),
#   ('and', 1),
#   ('is', 1),
#   ('for', 1),
#   ('loser', 1)],
#  [('i', 1),
#   ('am', 1),
#   ('liter', 1),
#   ('in', 1),
#   ('bed', 1),
#   ('and', 1),
#   ('have', 1),
#   ('been', 1),
#   ('up', 1),
#   ('for', 1),
#   ('like', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('hour', 1)],
#  [('you', 2),
#   ('are', 1),
#   ('gorgeou', 1),
#   ('keep', 1),
#   ('those', 1),
#   ('pix', 1),
#   ('cum', 1),
#   ('thank', 1),
#   ('', 1)],
#  [('__number__', 2),
#   ('urgent', 1),
#   ('we', 1),
#   ('are', 1),
# ...
#   ('no', 1),
#   ('one', 1),
#   ('call', 1),
#   ('and', 1),
#   ('whi', 1),
#   ('come', 1),
#   ('it', 1),
#   ('make', 1),
#   ('feel', 1),
#   ('like', 1),
#   ('die', 1),
#   ('', 1)],
#  [('pl', 3),
#   ('birthday', 2),
#   ('raji', 1),
#   ('do', 1),
#   ('me', 1),
#   ('a', 1),
#   ('favour', 1),
#   ('convey', 1),
#   ('my', 1),
#   ('wish', 1),
#   ('to', 1),
#   ('nimya', 1),
#   ('today', 1),
#   ('is', 1),
#   ('her', 1),
#   ('', 1)],
#  [('i', 2),
#   ('sure', 1),
#   ('ll', 1),
#   ('see', 1),
#   ('if', 1),
#   ('can', 1),
#   ('come', 1),
#   ('by', 1),
#   ('in', 1),
#   ('a', 1),
#   ('bit', 1)],
#  [('may', 1),
#   ('b', 1),
#   ('approv', 1),
#   ('panalam', 1),
#   ('but', 1),
#   ('it', 1),
#   ('should', 1),
#   ('have', 1),
#   ('more', 1),
#   ('post', 1),
#   ('', 1)],
#  [('anyth', 1), ('lar', 1), ('', 1)],
#  [('right', 1), ('on', 1), ('brah', 1), ('see', 1), ('you', 1), ('later', 1)],
#  [('aight', 1),
#   ('we', 1),
#   ('can', 1),
#   ('pick', 1),
#   ('some', 1),
#   ('up', 1),
#   ('you', 1),
#   ('open', 1),
#   ('befor', 1),
#   ('tonight', 1),
#   ('', 1)],
#  [('you', 5),
#   ('love', 3),
#   ('i', 3),
#   ('to', 3),
#   ('my', 2),
#   ('your', 2),
#   ('and', 2),
#   ('hear', 2),
#   ('it', 2),
#   ('the', 2),
#   ('hello', 1),
#   ('how', 1),
#   ('went', 1),
#   ('day', 1),
#   ('are', 1),
#   ('alright', 1),
#   ('think', 1),
#   ('of', 1),
#   ('sweet', 1),
#   ('send', 1),
#   ('a', 1),
#   ('jolt', 1),
#   ('heart', 1),
#   ('remind', 1),
#   ('can', 1),
#   ('scream', 1),
#   ('across', 1),
#   ('sea', 1),
#   ('for', 1),
#   ('all', 1),
#   ('world', 1),
#   ('ahmad', 1),
#   ('al', 1),
#   ('hallaq', 1),
#   ('is', 1),
#   ('own', 1),
#   ('possess', 1),
#   ('passion', 1),
#   ('kiss', 1),
#   ('', 1)],
#  [('oki', 2),
#   ('food', 2),
#   ('mon', 1),
#   ('lor', 1),
#   ('haha', 1),
#   ('best', 1),
#   ('is', 1),
#   ('cheap', 1),
#   ('n', 1),
#   ('gd', 1),
#   ('la', 1),
#   ('ex', 1),
#   ('oso', 1),
#   ('depend', 1),
#   ('on', 1),
#   ('whether', 1),
#   ('wana', 1),
#   ('eat', 1),
#   ('western', 1),
#   ('or', 1),
#   ('chines', 1),
#   ('den', 1),
#   ('which', 1),
#   ('u', 1),
#   ('prefer', 1),
#   ('', 1)],
#  [('mobil', 3),
#   ('__number__', 2),
#   ('to', 2),
#   ('updat', 2),
#   ('the', 2),
#   ('free', 2),
#   ('had', 1),
#   ('your', 1),
#   ('month', 1),
#   ('or', 1),
#   ('more', 1),
#   ('u', 1),
#   ('r', 1),
#   ('entitl', 1),
#   ('latest', 1),
#   ('colour', 1),
#   ('with', 1),
#   ('camera', 1),
#   ('for', 1),
#   ('call', 1),
#   ('co', 1),
#   ('on', 1)],
#  [('a', 3),
#   ('u', 2),
#   ('slo', 2),
#   ('babe', 1),
#   ('want', 1),
#   ('me', 1),
#   ('dont', 1),
#   ('babi', 1),
#   ('im', 1),
#   ('nasti', 1),
#   ('and', 1),
#   ('have', 1),
#   ('thing', 1),
#   ('__number__', 1),
#   ('filthyguy', 1),
#   ('fanci', 1),
#   ('rude', 1),
#   ('time', 1),
#   ('with', 1),
#   ('sexi', 1),
#   ('bitch', 1),
#   ('how', 1),
#   ('about', 1),
#   ('we', 1),
#   ('go', 1),
#   ('n', 1),
#   ('hard', 1),
#   ('txt', 1),
#   ('xxx', 1),
#   ('__number__msg', 1),
#   ('', 1)],
#  [('may', 2),
#   ('to', 2),
#   ('sweet', 1),
#   ('we', 1),
#   ('or', 1),
#   ('not', 1),
#   ('go', 1),
#   ('__number__u', 1),
#   ('meet', 1),
#   ('carlo', 1),
#   ('so', 1),
#   ('gaug', 1),
#   ('patti', 1),
#   ('s', 1),
#   ('interest', 1),
#   ('in', 1),
#   ('that', 1)],
#  [('__number__', 4),
#   ('a', 2),
#   ('promot', 1),
#   ('number', 1),
#   ('ur', 1),
#   ('award', 1),
#   ('citi', 1),
#   ('break', 1),
#   ('and', 1),
#   ('could', 1),
#   ('win', 1),
#   ('summer', 1),
#   ('shop', 1),
#   ('spree', 1),
#   ('everi', 1),
#   ('wk', 1),
#   ('txt', 1),
#   ('store', 1),
#   ('to', 1),
#   ('skilgm', 1),
#   ('tscs__number__winawk', 1),
#   ('age__number__', 1),
#   ('__number__perwksub', 1)],
#  [('i', 2),
#   ('oh', 1),
#   ('ok', 1),
#   ('didnt', 1),
#   ('know', 1),
#   ('what', 1),
#   ('you', 1),
#   ('meant', 1),
#   ('yep', 1),
#   ('am', 1),
#   ('babi', 1),
#   ('jontin', 1)],
#  [('u', 2),
#   ('appt', 1),
#   ('is', 1),
#   ('at', 1),
#   ('lt', 1),
#   ('time', 1),
#   ('gt', 1),
#   ('am', 1),
#   ('not', 1),
#   ('my', 1),
#   ('fault', 1),
#   ('don', 1),
#   ('t', 1),
#   ('listen', 1),
#   ('i', 1),
#   ('told', 1),
#   ('twice', 1)],
#  [('ok', 1)],
#  [('to', 2),
#   ('you', 2),
#   ('sorri', 1),
#   ('i', 1),
#   ('will', 1),
#   ('be', 1),
#   ('abl', 1),
#   ('get', 1),
#   ('see', 1),
#   ('in', 1),
#   ('the', 1),
#   ('morn', 1),
#   ('', 1)],
#  [('a', 2),
#   ('answer', 2),
#   ('is', 2),
#   ('awesom', 1),
#   ('question', 1),
#   ('with', 1),
#   ('cute', 1),
#   ('someon', 1),
#   ('ask', 1),
#   ('boy', 1),
#   ('how', 1),
#   ('ur', 1),
#   ('life', 1),
#   ('he', 1),
#   ('smile', 1),
#   ('amp', 1),
#   ('she', 1),
#   ('fine', 1),
#   ('gudnit', 1)],
#  [('wat', 1), ('time', 1), ('ü', 1), ('wan', 1), ('today', 1), ('', 1)],
#  [('here', 1),
#   ('is', 1),
#   ('my', 1),
#   ('new', 1),
#   ('address', 1),
#   ('appl', 1),
#   ('pair', 1),
#   ('all', 1),
#   ('that', 1),
#   ('malarki', 1)],
#  [('mm', 1),
#   ('i', 1),
#   ('had', 1),
#   ('my', 1),
#   ('food', 1),
#   ('da', 1),
#   ('from', 1),
#   ('out', 1)],
#  [('i', 3),
#   ('and', 2),
#   ('to', 2),
#   ('happi', 1),
#   ('valentin', 1),
#   ('day', 1),
#   ('know', 1),
#   ('it', 1),
#   ('earli', 1),
#   ('but', 1),
#   ('have', 1),
#   ('hundr', 1),
#   ('of', 1),
#   ('handsom', 1),
#   ('beauti', 1),
#   ('wish', 1),
#   ('so', 1),
#   ('thought', 1),
#   ('finish', 1),
#   ('off', 1),
#   ('aunti', 1),
#   ('uncl', 1),
#   ('__number__st', 1),
#   ('', 1)],
#  [('thank', 1),
#   ('for', 1),
#   ('thi', 1),
#   ('hope', 1),
#   ('you', 1),
#   ('had', 1),
#   ('a', 1),
#   ('good', 1),
#   ('day', 1),
#   ('today', 1)],
#  [('he', 3),
#   ('if', 1),
#   ('start', 1),
#   ('search', 1),
#   ('will', 1),
#   ('get', 1),
#   ('job', 1),
#   ('in', 1),
#   ('few', 1),
#   ('day', 1),
#   ('have', 1),
#   ('great', 1),
#   ('potenti', 1),
#   ('and', 1),
#   ('talent', 1),
#   ('', 1)],
#  [('__number__', 2),
#   ('to', 2),
#   ('day', 1),
#   ('euro__number__', 1),
#   ('kickoff', 1),
#   ('u', 1),
#   ('will', 1),
#   ('be', 1),
#   ('kept', 1),
#   ('inform', 1),
#   ('of', 1),
#   ('all', 1),
#   ('the', 1),
#   ('latest', 1),
#   ('news', 1),
#   ('and', 1),
#   ('result', 1),
#   ('daili', 1),
#   ('unsubscrib', 1),
#   ('send', 1),
#   ('get', 1),
#   ('euro', 1),
#   ('stop', 1),
#   ('', 1)],
#  [('it', 1), ('good', 1), ('to', 1), ('hear', 1), ('from', 1), ('you', 1)],
#  [('ur', 2),
#   ('ok', 1),
#   ('take', 1),
#   ('time', 1),
#   ('n', 1),
#   ('enjoy', 1),
#   ('dinner', 1),
#   ('', 1)],
#  [('i', 2),
#   ('ok', 1),
#   ('lor', 1),
#   ('soni', 1),
#   ('ericsson', 1),
#   ('salesman', 1),
#   ('ask', 1),
#   ('shuhui', 1),
#   ('then', 1),
#   ('she', 1),
#   ('say', 1),
#   ('quit', 1),
#   ('gd', 1),
#   ('__number__', 1),
#   ('use', 1),
#   ('so', 1),
#   ('consid', 1),
#   ('', 1)],
#  [('oh', 1),
#   ('ic', 1),
#   ('i', 1),
#   ('thought', 1),
#   ('you', 1),
#   ('meant', 1),
#   ('mari', 1),
#   ('jane', 1),
#   ('', 1)],
#  [('guessin', 1),
#   ('you', 1),
#   ('ain', 1),
#   ('t', 1),
#   ('gonna', 1),
#   ('be', 1),
#   ('here', 1),
#   ('befor', 1),
#   ('__number__', 1),
#   ('', 1)],
#  [('for', 2),
#   ('the', 2),
#   ('dear', 1),
#   ('friend', 1),
#   ('sorri', 1),
#   ('late', 1),
#   ('inform', 1),
#   ('today', 1),
#   ('is', 1),
#   ('birthday', 1),
#   ('of', 1),
#   ('our', 1),
#   ('love', 1),
#   ('ar', 1),
#   ('praveesh', 1),
#   ('more', 1),
#   ('detail', 1),
#   ('log', 1),
#   ('on', 1),
#   ('to', 1),
#   ('face', 1),
#   ('book', 1),
#   ('and', 1),
#   ('see', 1),
#   ('it', 1),
#   ('hi', 1),
#   ('number', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('dont', 1),
#   ('miss', 1),
#   ('a', 1),
#   ('delici', 1),
#   ('treat', 1),
#   ('', 1)],
#  [('we', 1), ('confirm', 1), ('eat', 1), ('at', 1), ('esplanad', 1), ('', 1)],
#  [('the', 2),
#   ('hiya', 1),
#   ('do', 1),
#   ('u', 1),
#   ('like', 1),
#   ('hlday', 1),
#   ('pic', 1),
#   ('look', 1),
#   ('horribl', 1),
#   ('in', 1),
#   ('them', 1),
#   ('so', 1),
#   ('took', 1),
#   ('mo', 1),
#   ('out', 1),
#   ('how', 1),
#   ('camp', 1),
#   ('amrca', 1),
#   ('thing', 1),
#   ('speak', 1),
#   ('soon', 1),
#   ('serena', 1),
#   ('', 1)],
#  [('enjoy', 1), ('urself', 1), ('tmr', 1), ('', 1)],
#  [('god', 4),
#   ('s', 4),
#   ('ha', 3),
#   ('no', 3),
#   ('love', 1),
#   ('limit', 1),
#   ('grace', 1),
#   ('measur', 1),
#   ('power', 1),
#   ('boundari', 1),
#   ('may', 1),
#   ('u', 1),
#   ('have', 1),
#   ('endless', 1),
#   ('bless', 1),
#   ('alway', 1),
#   ('in', 1),
#   ('ur', 1),
#   ('life', 1),
#   ('gud', 1),
#   ('ni__number__', 1)],
#  [('pl', 3),
#   ('birthday', 2),
#   ('raji', 1),
#   ('do', 1),
#   ('me', 1),
#   ('a', 1),
#   ('favour', 1),
#   ('convey', 1),
#   ('my', 1),
#   ('wish', 1),
#   ('to', 1),
#   ('nimya', 1),
#   ('today', 1),
#   ('is', 1),
#   ('her', 1),
#   ('', 1)],
#  [('i', 1),
#   ('just', 1),
#   ('made', 1),
#   ('some', 1),
#   ('payment', 1),
#   ('so', 1),
#   ('dont', 1),
#   ('have', 1),
#   ('that', 1),
#   ('much', 1),
#   ('sorri', 1),
#   ('would', 1),
#   ('you', 1),
#   ('want', 1),
#   ('it', 1),
#   ('fedex', 1),
#   ('or', 1),
#   ('the', 1),
#   ('other', 1),
#   ('way', 1),
#   ('', 1)],
#  [('i', 2),
#   ('ve', 2),
#   ('been', 2),
#   ('oh', 1),
#   ('ye', 1),
#   ('just', 1),
#   ('a', 1),
#   ('littl', 1),
#   ('under', 1),
#   ('the', 1),
#   ('weather', 1),
#   ('so', 1),
#   ('kind', 1),
#   ('of', 1),
#   ('coccoon', 1),
#   ('at', 1),
#   ('home', 1)],
#  [('freemsg', 1),
#   ('fav', 1),
#   ('xma', 1),
#   ('tone', 1),
#   ('repli', 1),
#   ('real', 1)],
#  [('__number__', 5),
#   ('a', 2),
#   ('love', 2),
#   ('name__number__', 2),
#   ('send', 1),
#   ('logo', 1),
#   ('ur', 1),
#   ('lover', 1),
#   ('name', 1),
#   ('join', 1),
#   ('by', 1),
#   ('heart', 1),
#   ('txt', 1),
#   ('mobno', 1),
#   ('eg', 1),
#   ('adam', 1),
#   ('eve', 1),
#   ('to', 1),
#   ('yahoo', 1),
#   ('pobox__number__w__number__wq', 1),
#   ('txtno', 1),
#   ('no', 1),
#   ('ad', 1),
#   ('__number__p', 1)],
#  [('a', 2),
#   ('__number__', 2),
#   ('you', 1),
#   ('are', 1),
#   ('guarante', 1),
#   ('the', 1),
#   ('latest', 1),
#   ('nokia', 1),
#   ('phone', 1),
#   ('__number__gb', 1),
#   ('ipod', 1),
#   ('mp__number__', 1),
#   ('player', 1),
#   ('or', 1),
#   ('prize', 1),
#   ('txt', 1),
#   ('word', 1),
#   ('collect', 1),
#   ('to', 1),
#   ('no', 1),
#   ('ibhltd', 1),
#   ('ldnw__number__h', 1),
#   ('__number__p', 1),
#   ('mtmsgrcvd__number__', 1)],
#  [('i', 3),
#   ('no', 1),
#   ('to', 1),
#   ('be', 1),
#   ('nosi', 1),
#   ('guess', 1),
#   ('idk', 1),
#   ('am', 1),
#   ('over', 1),
#   ('react', 1),
#   ('if', 1),
#   ('m', 1),
#   ('freak', 1),
#   ('', 1)],
#  [('da', 3),
#   ('pleas', 1),
#   ('call', 1),
#   ('me', 1),
#   ('ani', 1),
#   ('mistak', 1),
#   ('from', 1),
#   ('my', 1),
#   ('side', 1),
#   ('sorri', 1),
#   ('pl', 1),
#   ('goto', 1),
#   ('doctor', 1),
#   ('', 1)],
#  [('goodmorn', 1),
#   ('today', 1),
#   ('i', 1),
#   ('am', 1),
#   ('late', 1),
#   ('for', 1),
#   ('lt', 1),
#   ('decim', 1),
#   ('gt', 1),
#   ('min', 1),
#   ('', 1)],
#  [('ceri', 1),
#   ('u', 1),
#   ('rebel', 1),
#   ('sweet', 1),
#   ('dreamz', 1),
#   ('me', 1),
#   ('littl', 1),
#   ('buddi', 1),
#   ('c', 1),
#   ('ya', 1),
#   ('__number__moro', 1),
#   ('who', 1),
#   ('need', 1),
#   ('bloke', 1)],
#  [('k', 2), ('congratul', 1), ('', 1)],
#  [('so', 2),
#   ('how', 2),
#   ('are', 2),
#   ('you', 2),
#   ('realli', 1),
#   ('what', 1),
#   ('up', 1),
#   ('to', 1),
#   ('s', 1),
#   ('the', 1),
#   ('master', 1),
#   ('and', 1),
#   ('on', 1),
#   ('', 1)],
#  [('pl', 1),
#   ('speak', 1),
#   ('to', 1),
#   ('that', 1),
#   ('custom', 1),
#   ('machan', 1),
#   ('', 1)],
#  [('i', 3),
#   ('you', 3),
#   ('a', 2),
#   ('when', 2),
#   ('hope', 1),
#   ('your', 1),
#   ('alright', 1),
#   ('babe', 1),
#   ('worri', 1),
#   ('that', 1),
#   ('might', 1),
#   ('have', 1),
#   ('felt', 1),
#   ('bit', 1),
#   ('despar', 1),
#   ('learn', 1),
#   ('the', 1),
#   ('job', 1),
#   ('wa', 1),
#   ('fake', 1),
#   ('am', 1),
#   ('here', 1),
#   ('wait', 1),
#   ('come', 1),
#   ('back', 1),
#   ('my', 1),
#   ('love', 1)],
#  [('dear', 1), ('i', 1), ('have', 1), ('reach', 1), ('room', 1)],
#  [('yeah', 1),
#   ('confirm', 1),
#   ('for', 1),
#   ('you', 1),
#   ('stay', 1),
#   ('at', 1),
#   ('that', 1),
#   ('weekend', 1)],
#  [('a', 3),
#   ('dude', 2),
#   ('who', 2),
#   ('derp', 1),
#   ('which', 1),
#   ('is', 1),
#   ('wors', 1),
#   ('alway', 1),
#   ('want', 1),
#   ('to', 1),
#   ('parti', 1),
#   ('or', 1),
#   ('file', 1),
#   ('complaint', 1),
#   ('about', 1),
#   ('the', 1),
#   ('three', 1),
#   ('drug', 1),
#   ('abus', 1),
#   ('he', 1),
#   ('live', 1),
#   ('with', 1)],
#  [('k', 1), ('eng', 1), ('rock', 1), ('in', 1), ('ash', 1), ('', 1)],
#  [('okay', 1),
#   ('same', 1),
#   ('with', 1),
#   ('me', 1),
#   ('well', 1),
#   ('thank', 1),
#   ('for', 1),
#   ('the', 1),
#   ('clarif', 1)],
#  [('wat', 1),
#   ('happen', 1),
#   ('to', 1),
#   ('the', 1),
#   ('cruis', 1),
#   ('thing', 1)],
#  [('gonna', 2),
#   ('me', 2),
#   ('your', 1),
#   ('be', 1),
#   ('the', 1),
#   ('death', 1),
#   ('if', 1),
#   ('i', 1),
#   ('m', 1),
#   ('leav', 1),
#   ('a', 1),
#   ('note', 1),
#   ('that', 1),
#   ('say', 1),
#   ('it', 1),
#   ('all', 1),
#   ('rob', 1),
#   ('fault', 1),
#   ('aveng', 1),
#   ('', 1)],
#  [('miss', 6),
#   ('sent', 2),
#   ('messag', 1),
#   ('some', 1),
#   ('text', 1),
#   ('sender', 1),
#   ('name', 1),
#   ('number', 1),
#   ('date', 1),
#   ('u', 1),
#   ('a', 1),
#   ('lot', 1),
#   ('that', 1),
#   ('y', 1),
#   ('everyth', 1),
#   ('is', 1),
#   ('via', 1),
#   ('__url__', 1)],
#  [('__number__', 3),
#   ('dear', 1),
#   ('matthew', 1),
#   ('pleas', 1),
#   ('call', 1),
#   ('from', 1),
#   ('a', 1),
#   ('landlin', 1),
#   ('your', 1),
#   ('complimentari', 1),
#   ('lux', 1),
#   ('tenerif', 1),
#   ('holiday', 1),
#   ('or', 1),
#   ('cash', 1),
#   ('await', 1),
#   ('collect', 1),
#   ('ppm__number__', 1),
#   ('sae', 1),
#   ('t', 1),
#   ('cs', 1),
#   ('box__number__', 1),
#   ('sk__number__xh', 1),
#   ('', 1)],
#  [('we', 1),
#   ('live', 1),
#   ('in', 1),
#   ('the', 1),
#   ('next', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('min', 1)],
#  [('are', 1),
#   ('you', 1),
#   ('come', 1),
#   ('to', 1),
#   ('day', 1),
#   ('for', 1),
#   ('class', 1),
#   ('', 1)],
#  [('there', 1),
#   ('bold', 1),
#   ('__number__', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('is', 1),
#   ('that', 1),
#   ('your', 1)],
#  [('have', 1),
#   ('you', 1),
#   ('laid', 1),
#   ('your', 1),
#   ('airtel', 1),
#   ('line', 1),
#   ('to', 1),
#   ('rest', 1),
#   ('', 1)],
#  [('to', 2),
#   ('your', 2),
#   ('text', 1),
#   ('pass', 1),
#   ('__number__', 1),
#   ('collect', 1),
#   ('polyphon', 1),
#   ('rington', 1),
#   ('normal', 1),
#   ('gpr', 1),
#   ('charg', 1),
#   ('appli', 1),
#   ('onli', 1),
#   ('enjoy', 1),
#   ('tone', 1)],
#  [('your', 2),
#   ('hi', 1),
#   ('miss', 1),
#   ('call', 1),
#   ('and', 1),
#   ('my', 1),
#   ('mumha', 1),
#   ('beendrop', 1),
#   ('red', 1),
#   ('wine', 1),
#   ('all', 1),
#   ('over', 1),
#   ('theplac', 1),
#   ('what', 1),
#   ('is', 1),
#   ('adress', 1),
#   ('', 1)],
#  [('on', 2),
#   ('for', 2),
#   ('a', 2),
#   ('that', 2),
#   ('hi', 1),
#   ('wk', 1),
#   ('been', 1),
#   ('ok', 1),
#   ('hol', 1),
#   ('now', 1),
#   ('ye', 1),
#   ('bit', 1),
#   ('of', 1),
#   ('run', 1),
#   ('forgot', 1),
#   ('i', 1),
#   ('have', 1),
#   ('hairdress', 1),
#   ('appoint', 1),
#   ('at', 1),
#   ('four', 1),
#   ('so', 1),
#   ('need', 1),
#   ('to', 1),
#   ('get', 1),
#   ('home', 1),
#   ('n', 1),
#   ('shower', 1),
#   ('beforehand', 1),
#   ('doe', 1),
#   ('caus', 1),
#   ('prob', 1),
#   ('u', 1),
#   ('', 1)],
#  [('__number__', 2),
#   ('yup', 1),
#   ('no', 1),
#   ('need', 1),
#   ('i', 1),
#   ('ll', 1),
#   ('ju', 1),
#   ('wait', 1),
#   ('e', 1),
#   ('rain', 1),
#   ('stop', 1),
#   ('', 1)],
#  [('to', 4),
#   ('a', 2),
#   ('as', 1),
#   ('sim', 1),
#   ('subscrib', 1),
#   ('you', 1),
#   ('are', 1),
#   ('select', 1),
#   ('receiv', 1),
#   ('bonu', 1),
#   ('get', 1),
#   ('it', 1),
#   ('deliv', 1),
#   ('your', 1),
#   ('door', 1),
#   ('txt', 1),
#   ('the', 1),
#   ('word', 1),
#   ('ok', 1),
#   ('no', 1),
#   ('__number__', 1),
#   ('claim', 1),
#   ('__number__p', 1),
#   ('msg', 1),
#   ('exp', 1),
#   ('__number__apr', 1)],
#  [('__number__', 5),
#   ('hand', 2),
#   ('go', 1),
#   ('to', 1),
#   ('write', 1),
#   ('msg', 1),
#   ('put', 1),
#   ('on', 1),
#   ('dictionari', 1),
#   ('mode', 1),
#   ('cover', 1),
#   ('the', 1),
#   ('screen', 1),
#   ('with', 1),
#   ('press', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('gentli', 1),
#   ('remov', 1),
#   ('ur', 1),
#   ('it', 1),
#   ('interest', 1),
#   ('', 1)],
#  [('u', 2),
#   ('aiyar', 1),
#   ('dun', 1),
#   ('disturb', 1),
#   ('liao', 1),
#   ('thk', 1),
#   ('have', 1),
#   ('lot', 1),
#   ('__number__', 1),
#   ('do', 1),
#   ('aft', 1),
#   ('ur', 1),
#   ('cupboard', 1),
#   ('come', 1),
#   ('', 1)],
#  [('to', 3),
#   ('at', 2),
#   ('tomarrow', 1),
#   ('i', 1),
#   ('want', 1),
#   ('got', 1),
#   ('court', 1),
#   ('lt', 1),
#   ('decim', 1),
#   ('gt', 1),
#   ('so', 1),
#   ('you', 1),
#   ('come', 1),
#   ('bu', 1),
#   ('stand', 1),
#   ('__number__', 1),
#   ('', 1)],
#  [('i', 2),
#   ('vewi', 2),
#   ('ok', 1),
#   ('im', 1),
#   ('not', 1),
#   ('sure', 1),
#   ('what', 1),
#   ('time', 1),
#   ('finish', 1),
#   ('tomorrow', 1),
#   ('but', 1),
#   ('wanna', 1),
#   ('spend', 1),
#   ('the', 1),
#   ('even', 1),
#   ('with', 1),
#   ('you', 1),
#   ('co', 1),
#   ('that', 1),
#   ('would', 1),
#   ('be', 1),
#   ('lubli', 1),
#   ('love', 1),
#   ('me', 1),
#   ('xxx', 1)],
#  ...]

# %%
vocabulary = {}

for i in data_processed:
    for j in i:
        if j[0] not in vocabulary:
            vocabulary[j[0]] = j[1]
        else:
            vocabulary[j[0]] += j[1]

vocabulary = dict(sorted(vocabulary.items(), key=lambda item: item[1], reverse=True))
print(len(vocabulary))

def get_max_min(vocabulary):
    minKey, maxKey = min(vocabulary, key=vocabulary.get), max(vocabulary, key=vocabulary.get)
    print(f"""Max: "{maxKey}" = {vocabulary[maxKey]}; Min: "{minKey}" = {vocabulary[minKey]}""")
    print('-'*100)
get_max_min(vocabulary)


vocabulary_1000_keys = list(vocabulary.keys())[:1000]
vocabulary_1000 = {key:value for key, value in vocabulary.items() if key in vocabulary_1000_keys}
print(len(vocabulary_1000))
get_max_min(vocabulary_1000)
vocabulary_1000
# Out:
# 5686
# Max: "" = 2518; Min: "ahhhh" = 1
# ----------------------------------------------------------------------------------------------------
# 1000
# Max: "" = 2518; Min: "manag" = 7
# ----------------------------------------------------------------------------------------------------
# {'': 2518,
#  '__number__': 2266,
#  'i': 2233,
#  'you': 1686,
#  'to': 1681,
#  'a': 1061,
#  'the': 1007,
#  'u': 865,
#  'it': 742,
#  'and': 722,
#  'in': 684,
#  'is': 663,
#  'me': 595,
#  'my': 575,
#  'for': 542,
#  'your': 525,
#  'call': 500,
#  'of': 475,
#  'that': 458,
#  's': 445,
#  'have': 441,
#  'on': 412,
#  'do': 384,
#  'now': 377,
#  'are': 366,
#  'go': 362,
#  't': 359,
#  'can': 357,
#  'but': 348,
#  'so': 343,
#  'not': 339,
#  'm': 335,
#  'get': 333,
#  'be': 326,
#  'or': 322,
#  'at': 319,
#  'we': 306,
#  'will': 303,
#  'with': 294,
#  'if': 293,
#  'just': 289,
#  'ur': 287,
#  'no': 275,
#  'thi': 269,
#  'how': 243,
#  'gt': 243,
#  'lt': 242,
#  'up': 235,
#  'come': 235,
#  'ok': 232,
#  'what': 230,
#  'free': 220,
#  'when': 219,
#  'out': 214,
#  'day': 209,
#  'all': 206,
#  'know': 205,
#  'from': 202,
#  'like': 201,
#  'time': 199,
#  'll': 196,
#  'love': 192,
#  'then': 186,
#  'good': 185,
#  'got': 183,
#  'he': 182,
#  'want': 178,
#  'there': 171,
#  'text': 166,
#  'onli': 163,
#  'am': 163,
#  'wa': 161,
#  'send': 159,
#  'hi': 154,
#  '__url__': 152,
#  'need': 149,
#  'as': 143,
#  'one': 142,
#  'txt': 142,
#  'take': 139,
#  'she': 137,
#  'today': 136,
#  'ü': 134,
#  'by': 133,
#  'about': 131,
#  'see': 130,
#  'repli': 129,
#  'still': 127,
#  'don': 127,
#  'lor': 127,
#  'stop': 126,
#  'n': 125,
#  'r': 125,
#  'think': 124,
#  'our': 122,
#  'home': 121,
#  'tell': 121,
#  'mobil': 119,
#  'make': 119,
#  'sorri': 117,
#  'dont': 114,
#  'da': 114,
#  '__number__p': 114,
#  'pl': 112,
#  'back': 112,
#  'week': 111,
#  'k': 110,
#  'ha': 108,
#  'say': 108,
#  'd': 108,
#  'new': 108,
#  'they': 106,
#  'been': 106,
#  'miss': 106,
#  'later': 106,
#  'work': 105,
#  'her': 105,
#  'an': 101,
#  'night': 100,
#  'dear': 100,
#  'happi': 100,
#  'ask': 99,
#  'pleas': 99,
#  'ani': 98,
#  'did': 97,
#  'hope': 97,
#  'wait': 96,
#  'meet': 96,
#  'phone': 94,
#  'c': 93,
#  'much': 92,
#  'who': 92,
#  'where': 91,
#  'messag': 90,
#  'msg': 90,
#  'some': 89,
#  're': 89,
#  'here': 89,
#  'thing': 88,
#  'hey': 88,
#  'min': 87,
#  'well': 86,
#  'oh': 86,
#  'friend': 85,
#  'too': 85,
#  'wat': 83,
#  'number': 82,
#  'great': 82,
#  'give': 80,
#  'ye': 80,
#  'tri': 80,
#  'him': 79,
#  'way': 78,
#  'tomorrow': 78,
#  've': 76,
#  'had': 75,
#  'more': 75,
#  'thank': 75,
#  'claim': 74,
#  'care': 73,
#  'feel': 73,
#  'co': 70,
#  'b': 70,
#  'pick': 70,
#  'let': 69,
#  'should': 68,
#  'e': 68,
#  'amp': 68,
#  'im': 67,
#  'even': 67,
#  'realli': 66,
#  'alreadi': 66,
#  'leav': 66,
#  'after': 65,
#  'cash': 65,
#  'right': 64,
#  'start': 64,
#  'said': 64,
#  'yeah': 64,
#  'tone': 63,
#  'whi': 62,
#  'won': 62,
#  'find': 61,
#  'sure': 60,
#  'nokia': 60,
#  'morn': 60,
#  'prize': 60,
#  'wish': 60,
#  'year': 60,
#  'anyth': 59,
#  'servic': 59,
#  'life': 59,
#  'win': 59,
#  'last': 58,
#  'babe': 58,
#  'veri': 58,
#  'gud': 57,
#  'keep': 57,
#  'sleep': 57,
#  'watch': 56,
#  'use': 56,
#  'again': 55,
#  'everi': 55,
#  'look': 54,
#  'would': 54,
#  'also': 54,
#  'finish': 53,
#  'end': 53,
#  'them': 53,
#  'guy': 52,
#  'off': 52,
#  'befor': 52,
#  'contact': 51,
#  'cant': 50,
#  'show': 50,
#  'gonna': 50,
#  'special': 50,
#  'name': 50,
#  'tonight': 50,
#  'smile': 50,
#  'buy': 50,
#  'urgent': 49,
#  'collect': 49,
#  'talk': 49,
#  'us': 49,
#  'first': 49,
#  'sent': 48,
#  'nice': 48,
#  'soon': 48,
#  'place': 48,
#  'someon': 48,
#  'around': 47,
#  'lol': 47,
#  'late': 47,
#  'were': 47,
#  'next': 47,
#  'lot': 46,
#  'help': 46,
#  'which': 46,
#  'someth': 46,
#  'ya': 46,
#  'money': 45,
#  'thk': 44,
#  'alway': 44,
#  'other': 44,
#  'custom': 44,
#  'chat': 43,
#  'per': 43,
#  'check': 43,
#  'over': 43,
#  'word': 43,
#  'mean': 42,
#  'peopl': 42,
#  'told': 42,
#  'could': 42,
#  'minut': 42,
#  'may': 42,
#  'award': 42,
#  'plan': 41,
#  'haha': 41,
#  'offer': 41,
#  'same': 41,
#  'live': 40,
#  'hour': 40,
#  'dun': 40,
#  'v': 39,
#  'girl': 39,
#  'x': 39,
#  'reach': 39,
#  'mani': 39,
#  'shop': 39,
#  'best': 39,
#  'down': 39,
#  'person': 39,
#  'hello': 38,
#  'went': 38,
#  'car': 38,
#  'class': 38,
#  'holiday': 37,
#  'sm': 37,
#  'thought': 37,
#  'done': 37,
#  'wan': 36,
#  'worri': 36,
#  'month': 36,
#  'lunch': 36,
#  'happen': 36,
#  'play': 36,
#  'yet': 36,
#  'fine': 36,
#  'never': 35,
#  'rate': 35,
#  'problem': 35,
#  'stuff': 35,
#  'cost': 35,
#  'yup': 35,
#  'heart': 35,
#  'guess': 34,
#  'boy': 34,
#  'bit': 34,
#  'hous': 34,
#  'fuck': 34,
#  'dat': 33,
#  'cool': 33,
#  'date': 33,
#  'better': 33,
#  'line': 33,
#  'eat': 33,
#  'book': 33,
#  'man': 33,
#  'receiv': 33,
#  'game': 33,
#  'guarante': 33,
#  'lar': 32,
#  'god': 32,
#  'room': 32,
#  'mind': 32,
#  'didn': 32,
#  'birthday': 32,
#  'chanc': 32,
#  'y': 31,
#  'wk': 31,
#  'long': 31,
#  'quit': 31,
#  'enjoy': 31,
#  'anoth': 31,
#  'few': 31,
#  'sweet': 31,
#  'rington': 31,
#  'liao': 31,
#  'stay': 31,
#  'than': 31,
#  'yo': 31,
#  'dream': 30,
#  'cs': 30,
#  'becaus': 30,
#  'account': 30,
#  'join': 30,
#  'latest': 30,
#  'box': 29,
#  'pay': 29,
#  'bt': 29,
#  'weekend': 29,
#  '__number__st': 29,
#  'rememb': 29,
#  'video': 29,
#  'ill': 29,
#  'into': 29,
#  'select': 29,
#  'voucher': 29,
#  'noth': 28,
#  'mayb': 28,
#  'point': 28,
#  'half': 28,
#  'world': 28,
#  'hear': 28,
#  'big': 28,
#  'draw': 28,
#  'face': 28,
#  'charg': 28,
#  'appli': 28,
#  'camera': 28,
#  'thanx': 28,
#  'readi': 27,
#  'aight': 27,
#  'drive': 27,
#  'might': 27,
#  'pa': 27,
#  'ah': 27,
#  'pic': 27,
#  'question': 27,
#  'ju': 27,
#  '__number__ppm': 27,
#  'job': 27,
#  'ever': 27,
#  'network': 27,
#  'actual': 27,
#  'earli': 27,
#  'answer': 26,
#  'den': 26,
#  'landlin': 26,
#  'po': 26,
#  'xxx': 26,
#  'real': 26,
#  'speak': 26,
#  'princess': 26,
#  'kiss': 26,
#  'put': 26,
#  'tv': 26,
#  'probabl': 26,
#  'sat': 26,
#  'pain': 26,
#  'wonder': 26,
#  'sound': 25,
#  'di': 25,
#  'leh': 25,
#  'dinner': 25,
#  'two': 25,
#  'wont': 25,
#  'tmr': 25,
#  'onc': 25,
#  'sir': 25,
#  'littl': 25,
#  'chang': 25,
#  'without': 25,
#  'part': 25,
#  'bad': 24,
#  'await': 24,
#  'doe': 24,
#  'g': 24,
#  'orang': 24,
#  'bring': 24,
#  'made': 24,
#  'dunno': 24,
#  '__number__th': 24,
#  'hurt': 24,
#  'shall': 24,
#  'wanna': 24,
#  'bu': 23,
#  'final': 23,
#  'came': 23,
#  'luv': 23,
#  'though': 23,
#  'til': 23,
#  'left': 23,
#  'frnd': 23,
#  'must': 23,
#  '__number__nd': 23,
#  'shit': 23,
#  'bed': 23,
#  'code': 23,
#  'weekli': 23,
#  'easi': 23,
#  'babi': 23,
#  'those': 23,
#  'forgot': 23,
#  'poli': 23,
#  'colour': 23,
#  'smoke': 23,
#  'uk': 23,
#  'enter': 23,
#  'bore': 22,
#  'most': 22,
#  'hav': 22,
#  'sinc': 22,
#  'run': 22,
#  'mate': 22,
#  'enough': 22,
#  'dad': 22,
#  'credit': 22,
#  'read': 22,
#  'anyway': 22,
#  'okay': 22,
#  'wake': 22,
#  'school': 22,
#  'didnt': 21,
#  'gift': 21,
#  'test': 21,
#  'lesson': 21,
#  'entri': 21,
#  'while': 21,
#  'invit': 21,
#  'sexi': 21,
#  'until': 21,
#  'open': 21,
#  '__number__hr': 21,
#  'de': 21,
#  'alright': 21,
#  'lose': 21,
#  'town': 21,
#  'everyth': 21,
#  '__number__pm': 21,
#  'import': 20,
#  'true': 20,
#  'away': 20,
#  'head': 20,
#  'price': 20,
#  'trip': 20,
#  'abl': 20,
#  'offic': 20,
#  'drop': 20,
#  'saw': 20,
#  'ard': 20,
#  'mail': 20,
#  'order': 20,
#  'movi': 20,
#  'xma': 20,
#  'fun': 20,
#  'abt': 20,
#  'wot': 19,
#  'brother': 19,
#  'set': 19,
#  'wid': 19,
#  'haf': 19,
#  'walk': 19,
#  'pound': 19,
#  'listen': 19,
#  'post': 19,
#  'oso': 19,
#  'attempt': 19,
#  'beauti': 19,
#  'togeth': 19,
#  'close': 19,
#  'friendship': 19,
#  'coz': 18,
#  'top': 18,
#  'mob': 18,
#  'yesterday': 18,
#  'haven': 18,
#  'updat': 18,
#  'dude': 18,
#  'between': 18,
#  'busi': 18,
#  'juz': 18,
#  'treat': 18,
#  'touch': 18,
#  'eve': 17,
#  'havent': 17,
#  'caus': 17,
#  'wif': 17,
#  'nation': 17,
#  'inform': 17,
#  'email': 17,
#  'wen': 17,
#  'detail': 17,
#  'famili': 17,
#  'id': 17,
#  'either': 17,
#  'search': 17,
#  'studi': 17,
#  'valid': 17,
#  'expir': 17,
#  'die': 17,
#  'plz': 17,
#  'complet': 17,
#  'hand': 17,
#  'aft': 17,
#  'club': 17,
#  'nite': 17,
#  'onlin': 17,
#  'content': 17,
#  'nt': 17,
#  'fri': 17,
#  'old': 17,
#  'full': 17,
#  'hot': 17,
#  'believ': 17,
#  'doubl': 17,
#  'sae': 16,
#  'drink': 16,
#  'decid': 16,
#  'download': 16,
#  'els': 16,
#  'pm': 16,
#  'congrat': 16,
#  'music': 16,
#  'forget': 16,
#  'till': 16,
#  'afternoon': 16,
#  'food': 16,
#  'chikku': 16,
#  'address': 16,
#  'decim': 16,
#  'oki': 16,
#  'goe': 16,
#  'sch': 16,
#  'choos': 16,
#  'mum': 15,
#  'lei': 15,
#  'tot': 15,
#  'hair': 15,
#  'lucki': 15,
#  'plu': 15,
#  'pass': 15,
#  'privat': 15,
#  'statement': 15,
#  'opt': 15,
#  'train': 15,
#  'card': 15,
#  'noe': 15,
#  'unsubscrib': 15,
#  'sun': 15,
#  'player': 15,
#  'worth': 15,
#  'bonu': 15,
#  'anyon': 15,
#  'second': 15,
#  'bath': 15,
#  'joke': 15,
#  'parent': 15,
#  'song': 15,
#  'laugh': 15,
#  'yr': 15,
#  'deliveri': 15,
#  'wife': 15,
#  'valentin': 15,
#  'simpl': 15,
#  'forward': 14,
#  'angri': 14,
#  'log': 14,
#  'hit': 14,
#  'fast': 14,
#  'ni__number__': 14,
#  'both': 14,
#  'type': 14,
#  'ticket': 14,
#  'identifi': 14,
#  'saturday': 14,
#  'avail': 14,
#  'whatev': 14,
#  'winner': 14,
#  'gd': 14,
#  'prob': 14,
#  'kind': 14,
#  'parti': 14,
#  'w': 14,
#  'these': 14,
#  'pub': 14,
#  'blue': 14,
#  'awesom': 14,
#  'sister': 14,
#  'visit': 14,
#  'understand': 14,
#  'huh': 14,
#  'anytim': 14,
#  'tc': 14,
#  'o': 14,
#  'bank': 14,
#  'auction': 14,
#  'mom': 14,
#  'ring': 14,
#  'goin': 14,
#  'colleg': 13,
#  'move': 13,
#  'surpris': 13,
#  'interest': 13,
#  'tomo': 13,
#  'stori': 13,
#  'drug': 13,
#  'gone': 13,
#  'row': 13,
#  'goodmorn': 13,
#  'unlimit': 13,
#  'seem': 13,
#  'oper': 13,
#  'b__number__': 13,
#  'light': 13,
#  'hold': 13,
#  'age': 13,
#  'fone': 13,
#  'friday': 13,
#  'th': 13,
#  'match': 13,
#  'camcord': 13,
#  'smth': 13,
#  'si': 13,
#  'box__number__': 13,
#  'usual': 13,
#  'mrng': 13,
#  'took': 13,
#  'park': 13,
#  'compani': 13,
#  'doesn': 13,
#  'rite': 13,
#  'reason': 13,
#  'gr__number__': 13,
#  'remov': 13,
#  'bill': 13,
#  'follow': 13,
#  'their': 13,
#  'tho': 12,
#  'fix': 12,
#  'neva': 12,
#  'tire': 12,
#  'yourself': 12,
#  'dnt': 12,
#  'fr': 12,
#  'sort': 12,
#  'save': 12,
#  'secret': 12,
#  'mobileupd__number__': 12,
#  'reveal': 12,
#  'everyon': 12,
#  'xx': 12,
#  'ga': 12,
#  'clean': 12,
#  'mu': 12,
#  'catch': 12,
#  'oredi': 12,
#  'land': 12,
#  'freemsg': 12,
#  'jay': 12,
#  'fanci': 12,
#  'info': 12,
#  'return': 12,
#  'project': 12,
#  'ltd': 12,
#  'differ': 12,
#  'news': 12,
#  'alon': 12,
#  'carlo': 12,
#  'wrong': 12,
#  'current': 12,
#  '__number__am': 12,
#  'deal': 12,
#  'darlin': 11,
#  'pretti': 11,
#  'nope': 11,
#  'frm': 11,
#  'case': 11,
#  'gal': 11,
#  'pobox': 11,
#  'spend': 11,
#  'kid': 11,
#  'uncl': 11,
#  'gotta': 11,
#  'un': 11,
#  'redeem': 11,
#  'chennai': 11,
#  'sub': 11,
#  'stupid': 11,
#  'eye': 11,
#  'rock': 11,
#  'congratul': 11,
#  'luck': 11,
#  'found': 11,
#  'mine': 11,
#  'paper': 11,
#  'wit': 11,
#  'knw': 11,
#  'snow': 11,
#  'sad': 11,
#  'f': 11,
#  'confirm': 11,
#  'nyt': 11,
#  'almost': 11,
#  'dog': 11,
#  'area': 11,
#  'suppos': 11,
#  'ad': 11,
#  'ipod': 11,
#  'bout': 11,
#  'sit': 11,
#  'semest': 11,
#  'noon': 11,
#  'caller': 11,
#  'grin': 11,
#  'remind': 11,
#  'met': 11,
#  'stand': 11,
#  'christma': 11,
#  'regist': 11,
#  'earlier': 11,
#  'singl': 11,
#  'india': 11,
#  'sell': 11,
#  'murder': 11,
#  'pobox__number__': 11,
#  'break': 11,
#  'motorola': 11,
#  'wil': 11,
#  'term': 10,
#  'own': 10,
#  'pray': 10,
#  'cut': 10,
#  'march': 10,
#  'energi': 10,
#  '__number__mth': 10,
#  'film': 10,
#  'bslvyl': 10,
#  'ass': 10,
#  'somebodi': 10,
#  'crazi': 10,
#  'wow': 10,
#  'activ': 10,
#  'm__number__': 10,
#  'meant': 10,
#  'slowli': 10,
#  'ten': 10,
#  'side': 10,
#  'cours': 10,
#  'muz': 10,
#  'extra': 10,
#  'hmmm': 10,
#  'gym': 10,
#  'figur': 10,
#  'lover': 10,
#  'support': 10,
#  'page': 10,
#  'sea': 10,
#  'disturb': 10,
#  'reward': 10,
#  'hard': 10,
#  'yar': 10,
#  'wine': 10,
#  'each': 10,
#  'father': 10,
#  'rain': 10,
#  'askd': 10,
#  'promis': 10,
#  'small': 10,
#  'hmv': 10,
#  'shower': 10,
#  'write': 10,
#  'savamob': 10,
#  'isn': 10,
#  'gn': 10,
#  'tel': 10,
#  'silent': 9,
#  'complimentari': 9,
#  'link': 9,
#  'doin': 9,
#  'hmm': 9,
#  'lovabl': 9,
#  'serious': 9,
#  'deep': 9,
#  'tht': 9,
#  'scream': 9,
#  'mm': 9,
#  'ho': 9,
#  'hw': 9,
#  'txting': 9,
#  'rental': 9,
#  'ge': 9,
#  'total': 9,
#  'normal': 9,
#  'mode': 9,
#  'bcoz': 9,
#  'fren': 9,
#  'wana': 9,
#  'sunday': 9,
#  'through': 9,
#  'sign': 9,
#  'hee': 9,
#  'knew': 9,
#  'password': 9,
#  'em': 9,
#  'tonit': 9,
#  'merri': 9,
#  'p': 9,
#  'pete': 9,
#  'store': 9,
#  'least': 9,
#  'del': 9,
#  'comput': 9,
#  'welcom': 9,
#  'wed': 9,
#  'cover': 9,
#  'flag': 9,
#  'england': 9,
#  'rpli': 9,
#  'connect': 9,
#  'turn': 9,
#  'direct': 9,
#  'difficult': 9,
#  'possibl': 9,
#  'request': 9,
#  'mr': 9,
#  'abiola': 9,
#  'hr': 9,
#  'hungri': 9,
#  'laptop': 9,
#  'depend': 9,
#  'asap': 9,
#  'wear': 9,
#  'joy': 9,
#  'fantasi': 9,
#  'road': 9,
#  'hurri': 9,
#  'eh': 9,
#  'summer': 9,
#  'near': 9,
#  'weed': 9,
#  'press': 9,
#  'std': 9,
#  'rs': 9,
#  'correct': 9,
#  'convey': 9,
#  'ex': 9,
#  'empti': 9,
#  'suite__number__': 9,
#  '__number__land': 9,
#  'style': 9,
#  'ladi': 9,
#  'far': 9,
#  'within': 9,
#  'chariti': 9,
#  'etc': 9,
#  'travel': 8,
#  'lazi': 8,
#  'ive': 8,
#  'kate': 8,
#  'short': 8,
#  'becom': 8,
#  'definit': 8,
#  'fantast': 8,
#  'st': 8,
#  'access': 8,
#  'moral': 8,
#  'call__number__optout': 8,
#  'aha': 8,
#  'wednesday': 8,
#  'deliv': 8,
#  'med': 8,
#  'subscrib': 8,
#  'respons': 8,
#  'swing': 8,
#  '__number__g': 8,
#  'wast': 8,
#  'tampa': 8,
#  'copi': 8,
#  'rent': 8,
#  'balanc': 8,
#  'mid': 8,
#  'share': 8,
#  'list': 8,
#  'voic': 8,
#  'coupl': 8,
#  'student': 8,
#  'ago': 8,
#  'pictur': 8,
#  'marri': 8,
#  'against': 8,
#  '__number__nit': 8,
#  'valu': 8,
#  'fill': 8,
#  'sometim': 8,
#  'monday': 8,
#  'safe': 8,
#  'al': 8,
#  'app': 8,
#  'ma': 8,
#  'usf': 8,
#  'goto': 8,
#  'bag': 8,
#  'thinkin': 8,
#  'mood': 8,
#  'offici': 8,
#  'mah': 8,
#  'eg': 8,
#  'sale': 8,
#  'darren': 8,
#  'oop': 8,
#  'ntt': 8,
#  'il': 8,
#  'red': 8,
#  'respond': 8,
#  'warm': 8,
#  'forev': 8,
#  'moment': 8,
#  'door': 8,
#  'gave': 8,
#  'cheap': 8,
#  'poor': 8,
#  'especi': 8,
#  'cheer': 8,
#  'none': 8,
#  '__number__day': 8,
#  'john': 8,
#  'wkli': 8,
#  'comp': 8,
#  'www': 8,
#  'recent': 8,
#  'settl': 8,
#  'indian': 8,
#  'iam': 8,
#  'whole': 8,
#  'includ': 8,
#  'black': 8,
#  'cake': 8,
#  'ice': 8,
#  'urself': 8,
#  'felt': 8,
#  'via': 8,
#  'men': 8,
#  'member': 8,
#  'discount': 8,
#  'comin': 8,
#  'j': 8,
#  'rakhesh': 8,
#  '__number__w': 8,
#  'exam': 8,
#  'street': 8,
#  'swt': 8,
#  'outsid': 8,
#  'accept': 8,
#  'manag': 7,
#  'load': 7,
#  'issu': 7,
#  'user': 7,
#  'cinema': 7,
#  'letter': 7,
#  'boytoy': 7,
#  'hell': 7,
#  'no__number__': 7,
#  '__number__gbp': 7,
#  'myself': 7,
#  'round': 7,
#  'dead': 7,
#  'slow': 7}

# %%
def process_data_per_vocab(data):
    output = []
    for i in data:
        int_vocab = { i:0 for i in list(vocabulary_1000.keys()) }
        for j in i:
            if j[0] in int_vocab:
                int_vocab[j[0]] += j[1]
        output.append(list(int_vocab.values()))
    return np.array(output)

data_processed2 = process_data_per_vocab(data_processed)
data_processed2.shape
# Out:
# (4179, 1000)

# %% [markdown]
# # Train

# %%
log_clf = LogisticRegression(solver="lbfgs", max_iter=1000, random_state=42)
score = cross_val_score(log_clf, data_processed2, train_labels, cv=3, verbose=3)
print(score.mean())

log_clf.fit(data_processed2, train_labels)
# Out:
# [CV] END ................................ score: (test=0.985) total time=   0.1s
# [CV] END ................................ score: (test=0.980) total time=   0.1s
# [CV] END ................................ score: (test=0.983) total time=   0.1s
# 0.9825317061497967
# LogisticRegression(max_iter=1000, random_state=42)
