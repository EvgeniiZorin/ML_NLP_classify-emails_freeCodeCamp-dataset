# %% [markdown]
# # Import libraries, initialise variables

# %%
import os
import re
import pickle
from collections import Counter

import nltk
import requests
import urlextract
# import libraries
# try:
#   # %tensorflow_version only exists in Colab.
#   !pip install tf-nightly
# except Exception:
#   pass
import tensorflow as tf
import pandas as pd
from tensorflow import keras
# !pip install tensorflow-datasets
# import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_score, recall_score

print(tf.__version__)
# Out:
# 2.16.0-dev20231022

# %%
DATE = "asdf"

def create_dir_if_not_exists(path):
    if not os.path.exists(path):
        os.makedirs(path)

DATADIR = 'data'
create_dir_if_not_exists(DATADIR)

MODELDIR = 'models'
create_dir_if_not_exists(MODELDIR)

stemmer = nltk.PorterStemmer()

# %% [markdown]
# # Files download and read

# %%
urls = [
    "https://cdn.freecodecamp.org/project-data/sms/train-data.tsv",
    "https://cdn.freecodecamp.org/project-data/sms/valid-data.tsv"
]

for i in urls:
    filename = os.path.basename(i)
    filename_dir = os.path.join( DATADIR, filename )
    if os.path.exists(filename_dir):
        print(f'[INFO] Path {filename_dir} already exists! Skipping download.')
    else:
        r = requests.get(i)
        with open(filename_dir, 'wb') as f:
            f.write(r.content)
        print(f'[INFO] Downloaded from web to path {filename_dir}')

train_file_path = "data/train-data.tsv"
test_file_path = "data/valid-data.tsv"
# Out:
# [INFO] Path data\train-data.tsv already exists! Skipping download.
# [INFO] Path data\valid-data.tsv already exists! Skipping download.

# %%
def read_tsv(path):
    """
    # component 1
    
    reads tsv from the path
    """
    df = pd.read_csv(
        path, 
        sep = '\t', 
        # header=None
        names = ['label', 'text']
    )
    print(f"[INFO] Data points = {len(df)}")
    return df

df_train = read_tsv(train_file_path)
df_train
# Out:
# [INFO] Data points = 4179
#      label                                               text
# 0      ham  ahhhh...just woken up!had a bad dream about u ...
# 1      ham                           you can never do nothing
# 2      ham  now u sound like manky scouse boy steve,like! ...
# 3      ham  mum say we wan to go then go... then she can s...
# 4      ham  never y lei... i v lazy... got wat? dat day ü ...
# ...    ...                                                ...
# 4174   ham  just woke up. yeesh its late. but i didn't fal...
# 4175   ham  what do u reckon as need 2 arrange transport i...
# 4176  spam  free entry into our £250 weekly competition ju...
# 4177  spam  -pls stop bootydelious (32/f) is inviting you ...
# 4178   ham  tell my  bad character which u dnt lik in me. ...
#
# [4179 rows x 2 columns]

# %%
train_labels, train_features = list(df_train['label']), list(df_train['text'])
print(len(train_labels), train_labels[:5])
print(len(train_features), train_features[:5])
# Out:
# 4179 ['ham', 'ham', 'ham', 'ham', 'ham']
# 4179 ['ahhhh...just woken up!had a bad dream about u tho,so i dont like u right now :) i didnt know anything about comedy night but i guess im up for it.', 'you can never do nothing', 'now u sound like manky scouse boy steve,like! i is travelling on da bus home.wot has u inmind 4 recreation dis eve?', 'mum say we wan to go then go... then she can shun bian watch da glass exhibition...', 'never y lei... i v lazy... got wat? dat day ü send me da url cant work one...']

# %% [markdown]
# # Data clean

# %%
df_train.isna().sum()
# no missing data points, so let's move on
# Out:
# label    0
# text     0
# dtype: int64

# %% [markdown]
# # Data preprocessing

# %%
def preprocess(input_data: list) -> list:
    """
    Pipeline component 1
    
    process list of texts to a list of lists with stem counts.
    """
    data_processed = []
    ### initialise 'url_extractor' object
    url_extractor = urlextract.URLExtract()
    for i in input_data:
        ### Replace links with "__url__"
        url_list = url_extractor.find_urls(i)
        for j in url_list:
            i = i.replace(j, '__url__')
        ### Replace all punctuation marks with whitespace
        i = re.sub(r'[^\w\s]', ' ', i)
        ### Replace all newlines and tabs with whitespace
        i = re.sub(r'[\n]+', ' ', i)
        i = re.sub(r'[\t]+', ' ', i)
        ### Convert to lowercase
        i = i.lower()
        ### Remove numbers
        # i = re.sub(r'\d+(?:\.\d*)?(?:[eE][+-]?\d+)?', '_number_', i)
        i = re.sub(r' ([0-9]+) ', '__number__', i)
        ### Stemming
        i2 = i.split(' ')
        i2 = [stemmer.stem(j) for j in i2]
        ### Word counter
        word_counter = Counter(i2)
        word_counter = word_counter.most_common()
        ### Append the result
        data_processed.append(word_counter)
    return data_processed

# input = ['line1\nline2\n\n\tline3.,69,']
train_features2 = preprocess(train_features)
train_features2
# Out:
# [[('', 6),
#   ('i', 3),
#   ('up', 2),
#   ('about', 2),
#   ('u', 2),
#   ('ahhhh', 1),
#   ('just', 1),
#   ('woken', 1),
#   ('had', 1),
#   ('a', 1),
#   ('bad', 1),
#   ('dream', 1),
#   ('tho', 1),
#   ('so', 1),
#   ('dont', 1),
#   ('like', 1),
#   ('right', 1),
#   ('now', 1),
#   ('didnt', 1),
#   ('know', 1),
#   ('anyth', 1),
#   ('comedi', 1),
#   ('night', 1),
#   ('but', 1),
#   ('guess', 1),
#   ('im', 1),
#   ('for', 1),
#   ('it', 1)],
#  [('you', 1), ('can', 1), ('never', 1), ('do', 1), ('noth', 1)],
#  [('u', 2),
#   ('like', 2),
#   ('', 2),
#   ('now', 1),
#   ('sound', 1),
#   ('manki', 1),
#   ('scous', 1),
#   ('boy', 1),
#   ('steve', 1),
#   ('i', 1),
#   ('is', 1),
#   ('travel', 1),
#   ('on', 1),
#   ('da', 1),
#   ('bu', 1),
#   ('home', 1),
#   ('wot', 1),
#   ('ha', 1),
#   ('inmind__number__recr', 1),
#   ('di', 1),
#   ('eve', 1)],
#  [('', 6),
#   ('go', 2),
#   ('then', 2),
#   ('mum', 1),
#   ('say', 1),
#   ('we', 1),
#   ('wan', 1),
#   ('to', 1),
#   ('she', 1),
#   ('can', 1),
#   ('shun', 1),
#   ('bian', 1),
#   ('watch', 1),
#   ('da', 1),
#   ('glass', 1),
#   ('exhibit', 1)],
#  [('', 10),
#   ('never', 1),
#   ('y', 1),
#   ('lei', 1),
#   ('i', 1),
#   ('v', 1),
#   ('lazi', 1),
#   ('got', 1),
#   ('wat', 1),
#   ('dat', 1),
#   ('day', 1),
#   ('ü', 1),
#   ('send', 1),
#   ('me', 1),
#   ('da', 1),
#   ('url', 1),
#   ('cant', 1),
#   ('work', 1),
#   ('one', 1)],
#  [('', 3),
#   ('the', 2),
#   ('in', 1),
#   ('xam', 1),
#   ('hall', 1),
#   ('boy', 1),
#   ('ask', 1),
#   ('girl', 1),
#   ('tell', 1),
#   ('me', 1),
#   ('start', 1),
#   ('term', 1),
#   ('for', 1),
#   ('di', 1),
#   ('answer', 1),
#   ('i', 1),
#   ('can', 1),
#   ('den', 1),
#   ('manag', 1),
#   ('on', 1),
#   ('my', 1),
#   ('own', 1),
#   ('after', 1),
#   ('lot', 1),
#   ('of', 1),
#   ('hesit', 1),
#   ('n', 1),
#   ('lookin', 1),
#   ('around', 1),
#   ('silent', 1),
#   ('she', 1),
#   ('said', 1),
#   ('intha', 1),
#   ('ponnungal', 1),
#   ('ipaditan', 1)],
#  [('', 3),
#   ('geniu', 1),
#   ('what', 1),
#   ('s', 1),
#   ('up', 1),
#   ('how', 1),
#   ('your', 1),
#   ('brother', 1),
#   ('pl', 1),
#   ('send', 1),
#   ('hi', 1),
#   ('number', 1),
#   ('to', 1),
#   ('my', 1),
#   ('skype', 1)],
#  [('they', 1),
#   ('final', 1),
#   ('came', 1),
#   ('to', 1),
#   ('fix', 1),
#   ('the', 1),
#   ('ceil', 1),
#   ('', 1)],
#  [('', 2),
#   ('your', 2),
#   ('urgent', 1),
#   ('call__number__from', 1),
#   ('landlin', 1),
#   ('complimentary__number__', 1),
#   ('ibiza', 1),
#   ('holiday', 1),
#   ('or__number__000', 1),
#   ('cash', 1),
#   ('await', 1),
#   ('collect', 1),
#   ('sae', 1),
#   ('t', 1),
#   ('cs', 1),
#   ('po', 1),
#   ('box__number__sk3', 1),
#   ('8wp__number__ppm__number__', 1)],
#  [('you', 3),
#   ('that', 2),
#   ('', 2),
#   ('i', 2),
#   ('now', 1),
#   ('have', 1),
#   ('start', 1),
#   ('dont', 1),
#   ('stop', 1),
#   ('just', 1),
#   ('pray', 1),
#   ('for', 1),
#   ('more', 1),
#   ('good', 1),
#   ('idea', 1),
#   ('and', 1),
#   ('anyth', 1),
#   ('see', 1),
#   ('can', 1),
#   ('help', 1),
#   ('guy', 1),
#   ('ll', 1),
#   ('forward', 1),
#   ('a', 1),
#   ('link', 1)],
#  [('finish', 2),
#   ('u', 2),
#   ('hello', 1),
#   ('darlin', 1),
#   ('ive', 1),
#   ('colleg', 1),
#   ('now', 1),
#   ('so', 1),
#   ('txt', 1),
#   ('me', 1),
#   ('when', 1),
#   ('if', 1),
#   ('can', 1),
#   ('love', 1),
#   ('kate', 1),
#   ('xxx', 1)],
#  [('i', 3),
#   ('ü', 3),
#   ('repli', 2),
#   ('', 2),
#   ('aiyo', 1),
#   ('co', 1),
#   ('sm', 1),
#   ('then', 1),
#   ('neva', 1),
#   ('so', 1),
#   ('wait__number__ü', 1),
#   ('to', 1),
#   ('lar', 1),
#   ('tot', 1),
#   ('havent', 1),
#   ('finish', 1),
#   ('ur', 1),
#   ('lab', 1),
#   ('wat', 1)],
#  [('', 5),
#   ('i', 2),
#   ('have', 2),
#   ('m', 1),
#   ('cool', 1),
#   ('ta', 1),
#   ('luv', 1),
#   ('but', 1),
#   ('v', 1),
#   ('tired__number__caus', 1),
#   ('been', 1),
#   ('doin', 1),
#   ('load', 1),
#   ('of', 1),
#   ('plan', 1),
#   ('all', 1),
#   ('wk', 1),
#   ('we', 1),
#   ('got', 1),
#   ('our', 1),
#   ('social', 1),
#   ('servic', 1),
#   ('inspect', 1),
#   ('at', 1),
#   ('the', 1),
#   ('nurseri', 1),
#   ('take', 1),
#   ('care', 1),
#   ('spk', 1),
#   ('sn', 1),
#   ('x', 1)],
#  [('', 19),
#   ('lt', 3),
#   ('gt', 3),
#   ('the', 1),
#   ('messag', 1),
#   ('sent', 1),
#   ('is', 1),
#   ('askin', 1),
#   ('for', 1),
#   ('dollar', 1),
#   ('shoul', 1),
#   ('i', 1),
#   ('pay', 1),
#   ('or', 1)],
#  [('he', 2),
#   ('i', 2),
#   ('', 2),
#   ('said', 1),
#   ('look', 1),
#   ('pretti', 1),
#   ('wif', 1),
#   ('long', 1),
#   ('hair', 1),
#   ('wat', 1),
#   ('but', 1),
#   ('thk', 1),
#   ('s', 1),
#   ('cut', 1),
#   ('quit', 1),
#   ('short__number__m', 1),
#   ('leh', 1)],
#  [('', 8),
#   ('you', 4),
#   ('i', 3),
#   ('are', 2),
#   ('and', 2),
#   ('to', 2),
#   ('right', 1),
#   ('though', 1),
#   ('can', 1),
#   ('t', 1),
#   ('give', 1),
#   ('the', 1),
#   ('space', 1),
#   ('want', 1),
#   ('need', 1),
#   ('thi', 1),
#   ('is', 1),
#   ('realli', 1),
#   ('start', 1),
#   ('becom', 1),
#   ('an', 1),
#   ('issu', 1),
#   ('wa', 1),
#   ('go', 1),
#   ('suggest', 1),
#   ('set', 1),
#   ('a', 1),
#   ('definit', 1),
#   ('move', 1),
#   ('out', 1),
#   ('if', 1),
#   ('m', 1),
#   ('still', 1),
#   ('there', 1),
#   ('after', 1),
#   ('greec', 1),
#   ('but', 1),
#   ('mayb', 1),
#   ('readi', 1),
#   ('should', 1),
#   ('do', 1),
#   ('it', 1),
#   ('now', 1)],
#  [('', 2),
#   ('bore', 1),
#   ('housew', 1),
#   ('chat', 1),
#   ('n', 1),
#   ('date', 1),
#   ('now', 1),
#   ('__number__77__number__', 1),
#   ('bt', 1),
#   ('nation', 1),
#   ('rate', 1),
#   ('10p', 1),
#   ('min', 1),
#   ('onli', 1),
#   ('from', 1),
#   ('landlin', 1)],
#  [('', 2),
#   ('well', 1),
#   ('i', 1),
#   ('know', 1),
#   ('z', 1),
#   ('will', 1),
#   ('take', 1),
#   ('care', 1),
#   ('of', 1),
#   ('me', 1),
#   ('so', 1),
#   ('no', 1),
#   ('worri', 1)],
#  [('', 10),
#   ('haha', 1),
#   ('dont', 1),
#   ('be', 1),
#   ('angri', 1),
#   ('with', 1),
#   ('yourself', 1),
#   ('take', 1),
#   ('it', 1),
#   ('as', 1),
#   ('a', 1),
#   ('practic', 1),
#   ('for', 1),
#   ('the', 1),
#   ('real', 1),
#   ('thing', 1)],
#  [('nope', 1),
#   ('', 1),
#   ('i', 1),
#   ('m', 1),
#   ('still', 1),
#   ('in', 1),
#   ('the', 1),
#   ('market', 1)],
#  [('is', 2),
#   ('messag', 1),
#   ('import', 1),
#   ('inform', 1),
#   ('for', 1),
#   ('o2', 1),
#   ('user', 1),
#   ('', 1),
#   ('today', 1),
#   ('your', 1),
#   ('lucki', 1),
#   ('day', 1),
#   ('__number__find', 1),
#   ('out', 1),
#   ('whi', 1),
#   ('log', 1),
#   ('onto', 1),
#   ('__url__', 1),
#   ('there', 1),
#   ('a', 1),
#   ('fantast', 1),
#   ('surpris', 1),
#   ('await', 1),
#   ('you', 1)],
#  [('am', 1),
#   ('not', 1),
#   ('interest', 1),
#   ('to', 1),
#   ('do', 1),
#   ('like', 1),
#   ('that', 1),
#   ('', 1)],
#  [('', 4),
#   ('oh', 1),
#   ('ye', 1),
#   ('i', 1),
#   ('can', 1),
#   ('speak', 1),
#   ('txt__number__u', 1),
#   ('no', 1),
#   ('hmm', 1),
#   ('did', 1),
#   ('u', 1),
#   ('get', 1),
#   ('email', 1)],
#  [('', 11),
#   ('angri', 2),
#   ('n', 2),
#   ('wen', 1),
#   ('ur', 1),
#   ('lovabl', 1),
#   ('bcum', 1),
#   ('wid', 1),
#   ('u', 1),
#   ('dnt', 1),
#   ('take', 1),
#   ('it', 1),
#   ('serious', 1),
#   ('coz', 1),
#   ('be', 1),
#   ('is', 1),
#   ('d', 1),
#   ('most', 1),
#   ('childish', 1),
#   ('true', 1),
#   ('way', 1),
#   ('of', 1),
#   ('show', 1),
#   ('deep', 1),
#   ('affect', 1),
#   ('care', 1),
#   ('luv', 1),
#   ('kettoda', 1),
#   ('manda', 1),
#   ('have', 1),
#   ('nice', 1),
#   ('day', 1),
#   ('da', 1)],
#  [('god', 2),
#   ('gift', 2),
#   ('', 2),
#   ('tht', 1),
#   ('s', 1),
#   ('for', 1),
#   ('bird', 1),
#   ('as', 1),
#   ('human', 1),
#   ('hav', 1),
#   ('some', 1),
#   ('natur', 1),
#   ('frm', 1)],
#  [('aight', 1),
#   ('', 1),
#   ('i', 1),
#   ('m', 1),
#   ('chillin', 1),
#   ('in', 1),
#   ('a', 1),
#   ('friend', 1),
#   ('s', 1),
#   ('room', 1),
#   ('so', 1),
#   ('text', 1),
#   ('me', 1),
#   ('when', 1),
#   ('you', 1),
#   ('re', 1),
#   ('on', 1),
#   ('the', 1),
#   ('way', 1)],
#  [('', 2),
#   ('how', 1),
#   ('long', 1),
#   ('ha', 1),
#   ('it', 1),
#   ('been', 1),
#   ('sinc', 1),
#   ('you', 1),
#   ('scream', 1),
#   ('princess', 1)],
#  [('', 2),
#   ('i', 2),
#   ('no', 1),
#   ('problem', 1),
#   ('with', 1),
#   ('the', 1),
#   ('renew', 1),
#   ('ll', 1),
#   ('do', 1),
#   ('it', 1),
#   ('right', 1),
#   ('away', 1),
#   ('but', 1),
#   ('dont', 1),
#   ('know', 1),
#   ('hi', 1),
#   ('detail', 1)],
#  [('', 4),
#   ('doe', 1),
#   ('cinema', 1),
#   ('plu', 1),
#   ('drink', 1),
#   ('appeal', 1),
#   ('tomo', 1),
#   ('is', 1),
#   ('a', 1),
#   ('fr', 1),
#   ('thriller', 1),
#   ('by', 1),
#   ('director', 1),
#   ('i', 1),
#   ('like', 1),
#   ('on', 1),
#   ('at', 1),
#   ('mac', 1),
#   ('at__number__30', 1)],
#  [('i', 1), ('m', 1), ('come', 1), ('home__number__dinn', 1), ('', 1)],
#  [('', 7),
#   ('i', 2),
#   ('are', 1),
#   ('we', 1),
#   ('do', 1),
#   ('the', 1),
#   ('norm', 1),
#   ('tomorrow', 1),
#   ('finish', 1),
#   ('just', 1),
#   ('a__number__15', 1),
#   ('co', 1),
#   ('of', 1),
#   ('st', 1),
#   ('test', 1),
#   ('need', 1),
#   ('to', 1),
#   ('sort', 1),
#   ('librari', 1),
#   ('stuff', 1),
#   ('out', 1),
#   ('at', 1),
#   ('some', 1),
#   ('point', 1),
#   ('tomo', 1),
#   ('got', 1),
#   ('letter', 1),
#   ('from', 1),
#   ('today', 1),
#   ('access', 1),
#   ('til', 1),
#   ('end', 1),
#   ('march', 1),
#   ('so', 1),
#   ('better', 1),
#   ('get', 1),
#   ('move', 1),
#   ('on', 1)],
#  [('', 3),
#   ('but', 1),
#   ('i', 1),
#   ('haf', 1),
#   ('enuff', 1),
#   ('space', 1),
#   ('got', 1),
#   ('like__number__mb', 1)],
#  [('', 3),
#   ('i', 1),
#   ('need', 1),
#   ('to', 1),
#   ('come', 1),
#   ('home', 1),
#   ('and', 1),
#   ('give', 1),
#   ('you', 1),
#   ('some', 1),
#   ('good', 1),
#   ('lovin', 1)],
#  [('', 7),
#   ('i', 4),
#   ('wa', 2),
#   ('in', 2),
#   ('the', 2),
#   ('lol', 1),
#   ('gonna', 1),
#   ('last', 1),
#   ('month', 1),
#   ('cash', 1),
#   ('some', 1),
#   ('but', 1),
#   ('left', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('just', 1),
#   ('case', 1),
#   ('collect', 1),
#   ('more', 1),
#   ('dure', 1),
#   ('week', 1),
#   ('caus', 1),
#   ('they', 1),
#   ('announc', 1),
#   ('it', 1),
#   ('on', 1),
#   ('blog', 1)],
#  [('', 3),
#   ('mm', 1),
#   ('not', 1),
#   ('entir', 1),
#   ('sure', 1),
#   ('i', 1),
#   ('understood', 1),
#   ('that', 1),
#   ('text', 1),
#   ('but', 1),
#   ('hey', 1),
#   ('ho', 1),
#   ('which', 1),
#   ('weekend', 1)],
#  [('', 10),
#   ('i', 4),
#   ('you', 3),
#   ('miss', 2),
#   ('sorri', 1),
#   ('babe', 1),
#   ('wa', 1),
#   ('up', 1),
#   ('late', 1),
#   ('and', 1),
#   ('slept', 1),
#   ('in', 1),
#   ('hope', 1),
#   ('enjoy', 1),
#   ('your', 1),
#   ('drive', 1),
#   ('lesson', 1),
#   ('boytoy', 1),
#   ('too', 1),
#   ('teas', 1),
#   ('kiss', 1)],
#  [('', 16),
#   ('d', 10),
#   ('boy', 4),
#   ('a', 3),
#   ('gal', 3),
#   ('n', 3),
#   ('he', 2),
#   ('bt', 2),
#   ('she', 2),
#   ('her', 2),
#   ('wa', 2),
#   ('girl', 2),
#   ('boost', 2),
#   ('of', 2),
#   ('energi', 2),
#   ('love', 1),
#   ('propsd', 1),
#   ('didnt', 1),
#   ('mind', 1),
#   ('gv', 1),
#   ('lv', 1),
#   ('lttr', 1),
#   ('frnd', 1),
#   ('threw', 1),
#   ('thm', 1),
#   ('again', 1),
#   ('decided__number__aproach', 1),
#   ('dt', 1),
#   ('time', 1),
#   ('truck', 1),
#   ('speed', 1),
#   ('toward', 1),
#   ('wn', 1),
#   ('it', 1),
#   ('about__number__hit', 1),
#   ('ran', 1),
#   ('like', 1),
#   ('hell', 1),
#   ('save', 1),
#   ('ask', 1),
#   ('hw', 1),
#   ('cn', 1),
#   ('u', 1),
#   ('run', 1),
#   ('so', 1),
#   ('fast', 1),
#   ('repli', 1),
#   ('is', 1),
#   ('secret', 1),
#   ('my', 1),
#   ('instantli', 1),
#   ('shout', 1),
#   ('our', 1),
#   ('thi', 1),
#   ('live', 1),
#   ('happili', 1),
#   ('2gthr', 1),
#   ('drink', 1),
#   ('evrydi', 1),
#   ('moral', 1),
#   ('stori', 1),
#   ('i', 1),
#   ('hv', 1),
#   ('free', 1),
#   ('msg', 1),
#   ('gud', 1),
#   ('ni8', 1)],
#  [('week', 2),
#   ('', 2),
#   ('nokia', 2),
#   ('free', 1),
#   ('for', 1),
#   ('1st', 1),
#   ('no1', 1),
#   ('tone__number__ur', 1),
#   ('mobil', 1),
#   ('everi', 1),
#   ('just', 1),
#   ('txt', 1),
#   ('to__number__get', 1),
#   ('txting', 1),
#   ('and', 1),
#   ('tell', 1),
#   ('ur', 1),
#   ('mate', 1),
#   ('__url__', 1),
#   ('pobox__number__w45wq__number__', 1),
#   ('norm150p', 1),
#   ('tone', 1)],
#  [('', 2),
#   ('our', 1),
#   ('prashanthettan', 1),
#   ('s', 1),
#   ('mother', 1),
#   ('pass', 1),
#   ('away', 1),
#   ('last', 1),
#   ('night', 1),
#   ('pray', 1),
#   ('for', 1),
#   ('her', 1),
#   ('and', 1),
#   ('famili', 1)],
#  [('you', 1),
#   ('have__number__new', 1),
#   ('voicemail', 1),
#   ('', 1),
#   ('pleas', 1),
#   ('call', 1),
#   ('08719181503', 1)],
#  [('didn', 1),
#   ('t', 1),
#   ('tri', 1),
#   ('', 1),
#   ('g', 1),
#   ('and', 1),
#   ('i', 1),
#   ('decid', 1),
#   ('not', 1),
#   ('to', 1),
#   ('head', 1),
#   ('out', 1)],
#  [('give', 1),
#   ('one', 1),
#   ('miss', 1),
#   ('from', 1),
#   ('that', 1),
#   ('number', 1),
#   ('pleas', 1)],
#  [('', 5),
#   ('update_now', 1),
#   ('12mth', 1),
#   ('half', 1),
#   ('price', 1),
#   ('orang', 1),
#   ('line', 1),
#   ('rental', 1),
#   ('400min', 1),
#   ('call', 1),
#   ('mobileupd8', 1),
#   ('on__number__or', 1),
#   ('call2optout', 1),
#   ('j5q', 1)],
#  [('', 3),
#   ('500', 1),
#   ('new', 1),
#   ('mobil', 1),
#   ('from__number__', 1),
#   ('must', 1),
#   ('go', 1),
#   ('txt', 1),
#   ('nokia', 1),
#   ('to', 1),
#   ('no', 1),
#   ('__number__', 1),
#   ('collect', 1),
#   ('your', 1),
#   ('today', 1),
#   ('from', 1),
#   ('onli', 1),
#   ('__number____url__', 1),
#   ('2optout__number__50gbp', 1),
#   ('mtmsg18', 1),
#   ('txtauction', 1)],
#  [('you', 2),
#   ('just', 2),
#   ('in', 2),
#   ('and', 2),
#   ('might', 1),
#   ('want', 1),
#   ('to', 1),
#   ('pull', 1),
#   ('out', 1),
#   ('more', 1),
#   ('case', 1),
#   ('plan', 1),
#   ('on', 1),
#   ('not', 1),
#   ('spend', 1),
#   ('it', 1),
#   ('if', 1),
#   ('can', 1),
#   ('', 1),
#   ('i', 1),
#   ('don', 1),
#   ('t', 1),
#   ('have', 1),
#   ('much', 1),
#   ('confid', 1),
#   ('derek', 1),
#   ('taylor', 1),
#   ('s', 1),
#   ('money', 1),
#   ('manag', 1)],
#  [('', 14),
#   ('my', 4),
#   ('life', 3),
#   ('i', 3),
#   ('becaus', 2),
#   ('love', 2),
#   ('the', 2),
#   ('world', 2),
#   ('call', 2),
#   ('them', 2),
#   ('mean', 1),
#   ('a', 1),
#   ('lot', 1),
#   ('to', 1),
#   ('me', 1),
#   ('not', 1),
#   ('but', 1),
#   ('peopl', 1),
#   ('in', 1),
#   ('friend', 1),
#   ('ge', 1)],
#  [('i', 3),
#   ('do', 1),
#   ('', 1),
#   ('thought', 1),
#   ('put', 1),
#   ('it', 1),
#   ('back', 1),
#   ('in', 1),
#   ('the', 1),
#   ('box', 1)],
#  [('', 2), ('rememb', 1), ('on', 1), ('that', 1), ('day', 1)],
#  [('sent', 1), ('me', 1), ('ur', 1), ('email', 1), ('id', 1), ('soon', 1)],
#  [('', 4),
#   ('inde', 1),
#   ('and', 1),
#   ('by', 1),
#   ('the', 1),
#   ('way', 1),
#   ('it', 1),
#   ('wa', 1),
#   ('either', 1),
#   ('or', 1),
#   ('not', 1),
#   ('both', 1)],
#  [('haha', 1),
#   ('just', 1),
#   ('kid', 1),
#   ('', 1),
#   ('papa', 1),
#   ('need', 1),
#   ('drug', 1)],
#  [('', 3),
#   ('to', 2),
#   ('no', 1),
#   ('gift', 1),
#   ('you', 1),
#   ('tri', 1),
#   ('get', 1),
#   ('me', 1),
#   ('throw', 1),
#   ('myself', 1),
#   ('off', 1),
#   ('a', 1),
#   ('cliff', 1),
#   ('or', 1),
#   ('someth', 1)],
#  [('', 3),
#   ('she', 1),
#   ('went', 1),
#   ('to', 1),
#   ('attend', 1),
#   ('anoth', 1),
#   ('two', 1),
#   ('round', 1),
#   ('today', 1),
#   ('but', 1),
#   ('still', 1),
#   ('did', 1),
#   ('t', 1),
#   ('reach', 1),
#   ('home', 1)],
#  [('', 9),
#   ('haha', 1),
#   ('can', 1),
#   ('but', 1),
#   ('i', 1),
#   ('m', 1),
#   ('have', 1),
#   ('dinner', 1),
#   ('with', 1),
#   ('my', 1),
#   ('cousin', 1)],
#  [('', 2),
#   ('total', 1),
#   ('video', 1),
#   ('convert', 1),
#   ('free', 1),
#   ('download', 1),
#   ('type', 1),
#   ('thi', 1),
#   ('in', 1),
#   ('googl', 1),
#   ('search', 1)],
#  [('', 6),
#   ('yay', 1),
#   ('final', 1),
#   ('lol', 1),
#   ('i', 1),
#   ('miss', 1),
#   ('our', 1),
#   ('cinema', 1),
#   ('trip', 1),
#   ('last', 1),
#   ('week', 1)],
#  [('', 4),
#   ('to', 2),
#   ('good', 1),
#   ('morn', 1),
#   ('im', 1),
#   ('suffer', 1),
#   ('from', 1),
#   ('fever', 1),
#   ('and', 1),
#   ('dysentri', 1),
#   ('will', 1),
#   ('not', 1),
#   ('be', 1),
#   ('abl', 1),
#   ('come', 1),
#   ('offic', 1),
#   ('today', 1)],
#  [('keep', 1),
#   ('my', 1),
#   ('payasam', 1),
#   ('there', 1),
#   ('if', 1),
#   ('rinu', 1),
#   ('bring', 1)],
#  [('', 3),
#   ('we', 1),
#   ('can', 1),
#   ('go__number__', 1),
#   ('normal', 1),
#   ('pilat', 1),
#   ('after', 1),
#   ('our', 1),
#   ('intro', 1)],
#  [('', 2),
#   ('lol', 1),
#   ('ok', 1),
#   ('ill', 1),
#   ('tri', 1),
#   ('to', 1),
#   ('send', 1),
#   ('be', 1),
#   ('warn', 1),
#   ('sprint', 1),
#   ('is', 1),
#   ('dead', 1),
#   ('slow', 1),
#   ('you', 1),
#   ('ll', 1),
#   ('prolli', 1),
#   ('get', 1),
#   ('it', 1),
#   ('tomorrow', 1)],
#  [('and', 2),
#   ('my', 2),
#   ('honestli', 1),
#   ('i', 1),
#   ('ve', 1),
#   ('just', 1),
#   ('made', 1),
#   ('a', 1),
#   ('love', 1),
#   ('cup', 1),
#   ('of', 1),
#   ('tea', 1),
#   ('promptli', 1),
#   ('drop', 1),
#   ('key', 1),
#   ('in', 1),
#   ('it', 1),
#   ('then', 1),
#   ('burnt', 1),
#   ('finger', 1),
#   ('get', 1),
#   ('them', 1),
#   ('out', 1),
#   ('', 1)],
#  [('hi', 3),
#   ('pleas', 1),
#   ('dont', 1),
#   ('say', 1),
#   ('like', 1),
#   ('that', 1),
#   ('', 1)],
#  [('k', 2),
#   ('pa', 1),
#   ('had', 1),
#   ('your', 1),
#   ('lunch', 1),
#   ('aha', 1),
#   ('', 1)],
#  [('', 5),
#   ('i', 3),
#   ('watch', 1),
#   ('lor', 1),
#   ('saw', 1),
#   ('a', 1),
#   ('few', 1),
#   ('swatch', 1),
#   ('one', 1),
#   ('thk', 1),
#   ('quit', 1),
#   ('ok', 1),
#   ('ard__number__but', 1),
#   ('need', 1),
#   ('2nd', 1),
#   ('opinion', 1),
#   ('leh', 1)],
#  [('i', 1),
#   ('told', 1),
#   ('that', 1),
#   ('am', 1),
#   ('come', 1),
#   ('on', 1),
#   ('wednesday', 1),
#   ('', 1)],
#  [('', 5),
#   ('you', 3),
#   ('pl', 2),
#   ('all', 2),
#   ('know', 2),
#   ('about', 2),
#   ('can', 1),
#   ('send', 1),
#   ('me', 1),
#   ('a', 1),
#   ('mail', 1),
#   ('on', 1),
#   ('rel', 1),
#   ('come', 1),
#   ('to', 1),
#   ('deliv', 1),
#   ('here', 1),
#   ('cost', 1),
#   ('risk', 1),
#   ('benefit', 1),
#   ('and', 1),
#   ('anyth', 1),
#   ('els', 1),
#   ('thank', 1)],
#  [('', 2),
#   ('yup', 1),
#   ('but', 1),
#   ('not', 1),
#   ('studi', 1),
#   ('surf', 1),
#   ('lor', 1),
#   ('i', 1),
#   ('m', 1),
#   ('in', 1),
#   ('e', 1),
#   ('lazi', 1),
#   ('mode', 1),
#   ('today', 1)],
#  [('', 9),
#   ('bore', 2),
#   ('hello', 1),
#   ('how', 1),
#   ('r', 1),
#   ('u', 1),
#   ('im', 1),
#   ('inev', 1),
#   ('thought', 1),
#   ('id', 1),
#   ('get', 1),
#   ('with', 1),
#   ('the', 1),
#   ('tv', 1),
#   ('but', 1),
#   ('i', 1),
#   ('am', 1),
#   ('tell', 1),
#   ('me', 1),
#   ('someth', 1),
#   ('excit', 1),
#   ('ha', 1),
#   ('happen', 1),
#   ('there', 1),
#   ('anyth', 1)],
#  [('', 4),
#   ('been', 1),
#   ('up', 1),
#   ('to', 1),
#   ('ne', 1),
#   ('thing', 1),
#   ('interest', 1),
#   ('did', 1),
#   ('you', 1),
#   ('have', 1),
#   ('a', 1),
#   ('good', 1),
#   ('birthday', 1),
#   ('when', 1),
#   ('are', 1),
#   ('u', 1),
#   ('wrking', 1),
#   ('nxt', 1),
#   ('i', 1),
#   ('start', 1),
#   ('uni', 1),
#   ('today', 1)],
#  [('', 6),
#   ('warner', 2),
#   ('kiosk', 2),
#   ('c', 2),
#   ('village__number__c', 1),
#   ('colin', 1),
#   ('farrel', 1),
#   ('in', 1),
#   ('swat', 1),
#   ('thi', 1),
#   ('wkend', 1),
#   ('villag', 1),
#   ('get__number__fre', 1),
#   ('med', 1),
#   ('popcorn', 1),
#   ('just', 1),
#   ('show', 1),
#   ('msg', 1),
#   ('ticket', 1),
#   ('valid__number__7__number__', 1),
#   ('t', 1),
#   ('repli', 1),
#   ('sony__number__mr', 1),
#   ('film', 1),
#   ('offer', 1)],
#  [('doe', 1),
#   ('uncl', 1),
#   ('timi', 1),
#   ('help', 1),
#   ('in', 1),
#   ('clear', 1),
#   ('car', 1)],
#  [('', 3),
#   ('ugh', 1),
#   ('gotta', 1),
#   ('drive', 1),
#   ('back', 1),
#   ('to', 1),
#   ('sd', 1),
#   ('from', 1),
#   ('la', 1),
#   ('my', 1),
#   ('butt', 1),
#   ('is', 1),
#   ('sore', 1)],
#  [('i', 3),
#   ('but', 2),
#   ('and', 2),
#   ('same', 1),
#   ('here', 1),
#   ('', 1),
#   ('consid', 1),
#   ('wall', 1),
#   ('bunker', 1),
#   ('shit', 1),
#   ('import', 1),
#   ('just', 1),
#   ('becaus', 1),
#   ('never', 1),
#   ('play', 1),
#   ('on', 1),
#   ('peac', 1),
#   ('guess', 1),
#   ('your', 1),
#   ('place', 1),
#   ('is', 1),
#   ('high', 1),
#   ('enough', 1),
#   ('that', 1),
#   ('it', 1),
#   ('don', 1),
#   ('t', 1),
#   ('matter', 1)],
#  [('', 3),
#   ('under', 2),
#   ('the', 2),
#   ('sunlight', 2),
#   ('don', 2),
#   ('t', 2),
#   ('scienc', 1),
#   ('tell', 1),
#   ('that', 1),
#   ('chocol', 1),
#   ('will', 1),
#   ('melt', 1),
#   ('pleas', 1),
#   ('walk', 1),
#   ('bcoz', 1),
#   ('i', 1),
#   ('want', 1),
#   ('to', 1),
#   ('loss', 1),
#   ('a', 1),
#   ('sweet', 1),
#   ('friend', 1)],
#  [('i', 1),
#   ('dont', 1),
#   ('know', 1),
#   ('whi', 1),
#   ('she', 1),
#   ('s', 1),
#   ('not', 1),
#   ('get', 1),
#   ('your', 1),
#   ('messag', 1)],
#  [('', 6),
#   ('i', 2),
#   ('dunno', 1),
#   ('lei', 1),
#   ('might', 1),
#   ('b', 1),
#   ('eatin', 1),
#   ('wif', 1),
#   ('my', 1),
#   ('fren', 1),
#   ('if', 1),
#   ('ü', 1),
#   ('wan', 1),
#   ('to', 1),
#   ('eat', 1),
#   ('then', 1),
#   ('wait__number__ü', 1),
#   ('lar', 1)],
#  [('hahaha', 1), ('', 1), ('use', 1), ('your', 1), ('brain', 1), ('dear', 1)],
#  [('when', 1), ('u', 1), ('wana', 1), ('see', 1), ('it', 1), ('then', 1)],
#  [('talk', 1),
#   ('to', 1),
#   ('g', 1),
#   ('and', 1),
#   ('x', 1),
#   ('about', 1),
#   ('that', 1)],
#  [('were', 1), ('somewher', 1), ('on', 1), ('fredericksburg', 1)],
#  [('', 3),
#   ('just', 1),
#   ('sent', 1),
#   ('again', 1),
#   ('do', 1),
#   ('you', 1),
#   ('scream', 1),
#   ('and', 1),
#   ('moan', 1),
#   ('in', 1),
#   ('bed', 1),
#   ('princess', 1)],
#  [('', 3),
#   ('privat', 1),
#   ('your__number__account', 1),
#   ('statement', 1),
#   ('for', 1),
#   ('shows__number__un', 1),
#   ('redeem', 1),
#   ('s', 1),
#   ('i', 1),
#   ('m', 1),
#   ('point', 1),
#   ('call__number__identifi', 1),
#   ('code', 1),
#   ('__number__expires__number__11', 1),
#   ('04', 1)],
#  [('', 4),
#   ('ya', 1),
#   ('veri', 1),
#   ('nice', 1),
#   ('be', 1),
#   ('readi', 1),
#   ('on', 1),
#   ('thursday', 1)],
#  [('', 7),
#   ('ticket', 3),
#   ('to', 3),
#   ('on', 2),
#   ('eve', 2),
#   ('from', 2),
#   ('chennai', 2),
#   ('i', 2),
#   ('pleas', 1),
#   ('reserv', 1),
#   ('saturday', 1),
#   ('thirunelvali', 1),
#   ('and', 1),
#   ('again', 1),
#   ('tirunelvali', 1),
#   ('sunday', 1),
#   ('alreadi', 1),
#   ('see', 1),
#   ('in', 1),
#   ('net', 1),
#   ('no', 1),
#   ('avail', 1),
#   ('want', 1),
#   ('book', 1),
#   ('through', 1),
#   ('tackl', 1)],
#  [('free', 2),
#   ('rington', 2),
#   ('week', 2),
#   ('top', 1),
#   ('', 1),
#   ('sub', 1),
#   ('to', 1),
#   ('weekli', 1),
#   ('get', 1),
#   ('1st', 1),
#   ('send', 1),
#   ('subpoli', 1),
#   ('to__number____number__p', 1),
#   ('stop', 1),
#   ('sm', 1),
#   ('08718727870', 1)],
#  [('', 4),
#   ('i', 3),
#   ('tell', 2),
#   ('to', 2),
#   ('you', 2),
#   ('what', 1),
#   ('told', 1),
#   ('befor', 1),
#   ('stupid', 1),
#   ('hear', 1),
#   ('after', 1),
#   ('wont', 1),
#   ('anyth', 1),
#   ('dad', 1),
#   ('call', 1),
#   ('my', 1),
#   ('brother', 1),
#   ('and', 1),
#   ('spoken', 1),
#   ('not', 1),
#   ('with', 1),
#   ('me', 1)],
#  [('', 6),
#   ('up', 2),
#   ('hey', 1),
#   ('someth', 1),
#   ('came', 1),
#   ('last', 1),
#   ('min', 1),
#   ('think', 1),
#   ('i', 1),
#   ('wun', 1),
#   ('be', 1),
#   ('sign', 1),
#   ('tmr', 1),
#   ('hee', 1)],
#  [('i', 3),
#   ('an', 2),
#   ('', 2),
#   ('need', 1),
#   ('8th', 1),
#   ('but', 1),
#   ('m', 1),
#   ('off', 1),
#   ('campu', 1),
#   ('atm', 1),
#   ('could', 1),
#   ('pick', 1),
#   ('up', 1),
#   ('in', 1),
#   ('hour', 1),
#   ('or', 1),
#   ('two', 1)],
#  [('', 6), ('anyth', 1), ('lor', 1), ('u', 1), ('decid', 1)],
#  [('', 3),
#   ('u', 2),
#   ('reveal', 2),
#   ('have', 1),
#   ('a', 1),
#   ('secret', 1),
#   ('admir', 1),
#   ('who', 1),
#   ('think', 1),
#   ('r', 1),
#   ('so', 1),
#   ('special', 1),
#   ('call__number__', 1),
#   ('to', 1),
#   ('opt', 1),
#   ('out', 1),
#   ('repli', 1),
#   ('stop', 1),
#   ('__number__50', 1),
#   ('per', 1),
#   ('msg', 1),
#   ('recd', 1),
#   ('cust', 1),
#   ('care', 1),
#   ('07821230901', 1)],
#  [('sorri', 1),
#   ('man', 1),
#   ('', 1),
#   ('accident', 1),
#   ('left', 1),
#   ('my', 1),
#   ('phone', 1),
#   ('on', 1),
#   ('silent', 1),
#   ('last', 1),
#   ('night', 1),
#   ('and', 1),
#   ('didn', 1),
#   ('t', 1),
#   ('check', 1),
#   ('it', 1),
#   ('til', 1),
#   ('i', 1),
#   ('got', 1),
#   ('up', 1)],
#  [('', 5),
#   ('hack', 1),
#   ('chat', 1),
#   ('get', 1),
#   ('backdoor', 1),
#   ('entri', 1),
#   ('into__number__chat', 1),
#   ('room', 1),
#   ('at', 1),
#   ('a', 1),
#   ('fraction', 1),
#   ('of', 1),
#   ('the', 1),
#   ('cost', 1),
#   ('repli', 1),
#   ('neo69', 1),
#   ('or', 1),
#   ('call__number__', 1),
#   ('to', 1),
#   ('subscrib', 1),
#   ('25p', 1),
#   ('pm', 1),
#   ('dp', 1),
#   ('bcm', 1),
#   ('box__number__ldn', 1),
#   ('wc1n3xx', 1)],
#  [('i', 3),
#   ('you', 2),
#   ('don', 1),
#   ('t', 1),
#   ('know', 1),
#   ('jack', 1),
#   ('shit', 1),
#   ('about', 1),
#   ('anyth', 1),
#   ('or', 1),
#   ('d', 1),
#   ('say', 1),
#   ('ask', 1),
#   ('someth', 1),
#   ('help', 1),
#   ('but', 1),
#   ('if', 1),
#   ('want', 1),
#   ('can', 1),
#   ('pretend', 1),
#   ('that', 1),
#   ('did', 1),
#   ('and', 1),
#   ('just', 1),
#   ('text', 1),
#   ('me', 1),
#   ('whatev', 1),
#   ('in', 1),
#   ('respons', 1),
#   ('to', 1),
#   ('the', 1),
#   ('hypotheticalhuagauahahuagahyuhagga', 1)],
#  [('what', 1),
#   ('time', 1),
#   ('is', 1),
#   ('ur', 1),
#   ('flight', 1),
#   ('tmr', 1),
#   ('', 1)],
#  [('', 7),
#   ('up', 2),
#   ('to', 2),
#   ('the', 2),
#   ('just', 1),
#   ('got', 1),
#   ('have', 1),
#   ('be', 1),
#   ('out', 1),
#   ('of', 1),
#   ('room', 1),
#   ('veri', 1),
#   ('soon', 1),
#   ('i', 1),
#   ('hadn', 1),
#   ('t', 1),
#   ('put', 1),
#   ('clock', 1),
#   ('back', 1),
#   ('til', 1),
#   ('at__number__i', 1),
#   ('shout', 1),
#   ('at', 1),
#   ('everyon', 1),
#   ('get', 1),
#   ('and', 1),
#   ('then', 1),
#   ('realis', 1),
#   ('it', 1),
#   ('was__number__', 1),
#   ('wahay', 1),
#   ('anoth', 1),
#   ('hour', 1),
#   ('in', 1),
#   ('bed', 1)],
#  [('', 6), ('ok', 1), ('i', 1), ('din', 1), ('get', 1), ('ur', 1), ('msg', 1)],
#  [('', 4),
#   ('servic', 2),
#   ('you', 2),
#   ('not', 2),
#   ('free', 1),
#   ('msg', 1),
#   ('sorri', 1),
#   ('a', 1),
#   ('order', 1),
#   ('from__number__could', 1),
#   ('be', 1),
#   ('deliv', 1),
#   ('as', 1),
#   ('do', 1),
#   ('have', 1),
#   ('suffici', 1),
#   ('credit', 1),
#   ('pleas', 1),
#   ('top', 1),
#   ('up', 1),
#   ('to', 1),
#   ('receiv', 1),
#   ('the', 1)],
#  [('', 5), ('that', 1), ('s', 1), ('not', 1), ('v', 1), ('romant', 1)],
#  [('probabl', 1),
#   ('gonna', 1),
#   ('swing', 1),
#   ('by', 1),
#   ('in', 1),
#   ('a', 1),
#   ('wee', 1),
#   ('bit', 1)],
#  [('', 6),
#   ('your', 2),
#   ('congrat', 1),
#   ('__number__mobil', 1),
#   ('3g', 1),
#   ('videophon', 1),
#   ('r', 1),
#   ('call__number__now', 1),
#   ('videochat', 1),
#   ('wid', 1),
#   ('mate', 1),
#   ('play', 1),
#   ('java', 1),
#   ('game', 1),
#   ('dload', 1),
#   ('polyph', 1),
#   ('music', 1),
#   ('nolin', 1),
#   ('rentl', 1)],
#  [('', 2),
#   ('i', 1),
#   ('d', 1),
#   ('say', 1),
#   ('that', 1),
#   ('s', 1),
#   ('a', 1),
#   ('good', 1),
#   ('sign', 1),
#   ('but', 1),
#   ('well', 1),
#   ('you', 1),
#   ('know', 1),
#   ('my', 1),
#   ('track', 1),
#   ('record', 1),
#   ('at', 1),
#   ('read', 1),
#   ('women', 1)],
#  [('', 4),
#   ('we', 2),
#   ('s', 1),
#   ('if', 1),
#   ('have', 1),
#   ('one', 1),
#   ('good', 1),
#   ('partnership', 1),
#   ('go', 1),
#   ('will', 1),
#   ('take', 1),
#   ('lead', 1)],
#  [('are', 1), ('you', 1), ('drive', 1), ('or', 1), ('train', 1), ('', 1)],
#  [('msg', 1), ('me', 1), ('when', 1), ('rajini', 1), ('come', 1), ('', 1)],
#  [('and', 2),
#   ('whenev', 1),
#   ('you', 1),
#   ('i', 1),
#   ('see', 1),
#   ('we', 1),
#   ('can', 1),
#   ('still', 1),
#   ('hook', 1),
#   ('up', 1),
#   ('too', 1),
#   ('', 1)],
#  [('for', 1),
#   ('your', 1),
#   ('chanc', 1),
#   ('to', 1),
#   ('win', 1),
#   ('a', 1),
#   ('free', 1),
#   ('bluetooth', 1),
#   ('headset', 1),
#   ('then', 1),
#   ('simpli', 1),
#   ('repli', 1),
#   ('back', 1),
#   ('with', 1),
#   ('adp', 1)],
#  [('', 3),
#   ('hey', 1),
#   ('i', 1),
#   ('will', 1),
#   ('be', 1),
#   ('late', 1),
#   ('ah', 1),
#   ('meet', 1),
#   ('you', 1),
#   ('at__number__', 1)],
#  [('', 11),
#   ('me', 3),
#   ('my', 2),
#   ('i', 2),
#   ('hurt', 1),
#   ('teas', 1),
#   ('make', 1),
#   ('cri', 1),
#   ('but', 1),
#   ('in', 1),
#   ('the', 1),
#   ('end', 1),
#   ('of', 1),
#   ('life', 1),
#   ('when', 1),
#   ('die', 1),
#   ('plz', 1),
#   ('keep', 1),
#   ('one', 1),
#   ('rose', 1),
#   ('on', 1),
#   ('grave', 1),
#   ('and', 1),
#   ('say', 1),
#   ('stupid', 1),
#   ('miss', 1),
#   ('u', 1),
#   ('have', 1),
#   ('a', 1),
#   ('nice', 1),
#   ('day', 1),
#   ('bslvyl', 1)],
#  [('ani', 1),
#   ('way', 1),
#   ('where', 1),
#   ('are', 1),
#   ('you', 1),
#   ('and', 1),
#   ('what', 1),
#   ('do', 1),
#   ('', 1)],
#  [('a', 3),
#   ('', 3),
#   ('spook', 2),
#   ('logo', 2),
#   ('pic', 2),
#   ('up', 1),
#   ('your', 1),
#   ('mob', 1),
#   ('with', 1),
#   ('halloween', 1),
#   ('collect', 1),
#   ('of', 1),
#   ('messag', 1),
#   ('plu', 1),
#   ('free', 1),
#   ('eeri', 1),
#   ('tone', 1),
#   ('txt', 1),
#   ('card', 1),
#   ('to__number__z', 1),
#   ('08701417012150p', 1),
#   ('per', 1)],
#  [('', 2),
#   ('s', 1),
#   ('i', 1),
#   ('think', 1),
#   ('he', 1),
#   ('is', 1),
#   ('wast', 1),
#   ('for', 1),
#   ('rr', 1)],
#  [('', 3), ('10', 1), ('min', 1), ('later', 1), ('k', 1)],
#  [('', 3),
#   ('am', 2),
#   ('not', 1),
#   ('work', 1),
#   ('but', 1),
#   ('up', 1),
#   ('to', 1),
#   ('eye', 1),
#   ('in', 1),
#   ('philosophi', 1),
#   ('so', 1),
#   ('will', 1),
#   ('text', 1),
#   ('u', 1),
#   ('later', 1),
#   ('when', 1),
#   ('a', 1),
#   ('bit', 1),
#   ('more', 1),
#   ('free', 1),
#   ('for', 1),
#   ('chat', 1)],
#  [('', 9),
#   ('who', 2),
#   ('you', 2),
#   ('and', 2),
#   ('don', 1),
#   ('t', 1),
#   ('forget', 1),
#   ('own', 1),
#   ('s', 1),
#   ('privat', 1),
#   ('properti', 1),
#   ('are', 1),
#   ('be', 1),
#   ('my', 1),
#   ('good', 1),
#   ('boy', 1),
#   ('alway', 1),
#   ('passion', 1),
#   ('kiss', 1)],
#  [('work', 2),
#   ('', 2),
#   ('he', 2),
#   ('mark', 1),
#   ('tomorrow', 1),
#   ('get', 1),
#   ('out', 1),
#   ('at__number__', 1),
#   ('hi', 1),
#   ('is', 1),
#   ('by', 1),
#   ('your', 1),
#   ('hous', 1),
#   ('so', 1),
#   ('can', 1),
#   ('meet', 1),
#   ('u', 1),
#   ('afterward', 1)],
#  [('', 4),
#   ('is', 2),
#   ('have', 2),
#   ('u', 2),
#   ('thi', 1),
#   ('the', 1),
#   ('2nd', 1),
#   ('time', 1),
#   ('we', 1),
#   ('tried__number__contact', 1),
#   ('won', 1),
#   ('the__number__pound', 1),
#   ('prize', 1),
#   ('__number__claim', 1),
#   ('easi', 1),
#   ('call__number__now', 1),
#   ('onli', 1),
#   ('10p', 1),
#   ('per', 1),
#   ('min', 1),
#   ('bt', 1),
#   ('nation', 1),
#   ('rate', 1)],
#  [('i', 3),
#   ('', 3),
#   ('m', 2),
#   ('on', 2),
#   ('a', 2),
#   ('diet', 2),
#   ('but', 1),
#   ('and', 1),
#   ('ate__number__too', 1),
#   ('mani', 1),
#   ('slice', 1),
#   ('of', 1),
#   ('pizza', 1),
#   ('yesterday', 1),
#   ('ugh', 1),
#   ('alway', 1)],
#  [('cramp', 1),
#   ('stop', 1),
#   ('', 1),
#   ('go', 1),
#   ('back', 1),
#   ('to', 1),
#   ('sleep', 1)],
#  [('to', 2),
#   ('', 2),
#   ('he', 1),
#   ('say', 1),
#   ('hi', 1),
#   ('and', 1),
#   ('get', 1),
#   ('your', 1),
#   ('ass', 1),
#   ('back', 1),
#   ('south', 1),
#   ('tampa', 1),
#   ('prefer', 1),
#   ('at', 1),
#   ('a', 1),
#   ('kegger', 1)],
#  [('', 5),
#   ('i', 2),
#   ('can', 1),
#   ('but', 1),
#   ('it', 1),
#   ('will', 1),
#   ('tell', 1),
#   ('quit', 1),
#   ('long', 1),
#   ('co', 1),
#   ('haven', 1),
#   ('t', 1),
#   ('finish', 1),
#   ('my', 1),
#   ('film', 1),
#   ('yet', 1)],
#  [('', 2), ('no', 1), ('scream', 1), ('mean', 1), ('shout', 1)],
#  [('tell', 1),
#   ('them', 1),
#   ('no', 1),
#   ('need', 1),
#   ('to', 1),
#   ('investig', 1),
#   ('about', 1),
#   ('me', 1),
#   ('anywher', 1),
#   ('', 1)],
#  [('', 3),
#   ('realli', 1),
#   ('good', 1),
#   ('dhanush', 1),
#   ('rock', 1),
#   ('onc', 1),
#   ('again', 1)],
#  [('ye', 1), ('he', 1), ('have', 1), ('good', 1), ('crickit', 1), ('mind', 1)],
#  [('call', 2),
#   ('him', 2),
#   ('you', 1),
#   ('now', 1),
#   ('ok', 1),
#   ('i', 1),
#   ('said', 1)],
#  [('', 4),
#   ('pic', 2),
#   ('hottest', 1),
#   ('straight', 1),
#   ('to', 1),
#   ('your', 1),
#   ('phone', 1),
#   ('see', 1),
#   ('me', 1),
#   ('get', 1),
#   ('wet', 1),
#   ('and', 1),
#   ('want', 1),
#   ('just', 1),
#   ('for', 1),
#   ('you', 1),
#   ('xx', 1),
#   ('text', 1),
#   ('to__number__now', 1),
#   ('txt', 1),
#   ('cost', 1),
#   ('150p', 1),
#   ('textoper', 1),
#   ('g696ga__number__xxx', 1)],
#  [('', 6),
#   ('erm', 1),
#   ('woodland', 1),
#   ('avenu', 1),
#   ('somewher', 1),
#   ('do', 1),
#   ('you', 1),
#   ('get', 1),
#   ('the', 1),
#   ('parish', 1),
#   ('magazin', 1),
#   ('hi', 1),
#   ('telephon', 1),
#   ('number', 1),
#   ('will', 1),
#   ('be', 1),
#   ('in', 1),
#   ('there', 1)],
#  [('mail', 2),
#   ('check', 1),
#   ('i', 1),
#   ('have', 1),
#   ('varma', 1),
#   ('and', 1),
#   ('kept', 1),
#   ('copi', 1),
#   ('to', 1),
#   ('you', 1),
#   ('regard', 1),
#   ('membership', 1),
#   ('take', 1),
#   ('care', 1),
#   ('insha', 1),
#   ('allah', 1),
#   ('', 1)],
#  [('', 13),
#   ('i', 6),
#   ('hope', 3),
#   ('you', 3),
#   ('is', 3),
#   ('have', 2),
#   ('to', 2),
#   ('my', 2),
#   ('and', 2),
#   ('it', 2),
#   ('a', 2),
#   ('could', 2),
#   ('had', 1),
#   ('been', 1),
#   ('would', 1),
#   ('not', 1),
#   ('send', 1),
#   ('thi', 1),
#   ('messag', 1),
#   ('rent', 1),
#   ('due', 1),
#   ('dont', 1),
#   ('enough', 1),
#   ('for', 1),
#   ('reserv', 1),
#   ('are', 1),
#   ('complet', 1),
#   ('gone', 1),
#   ('loan', 1),
#   ('need', 1),
#   ('wa', 1),
#   ('her', 1),
#   ('the', 1),
#   ('balanc', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('there', 1),
#   ('way', 1),
#   ('get', 1),
#   ('that', 1),
#   ('from', 1),
#   ('till', 1),
#   ('mid', 1),
#   ('march', 1),
#   ('when', 1),
#   ('pay', 1),
#   ('back', 1)],
#  [('blu', 2),
#   ('in', 2),
#   ('congratul', 1),
#   ('u', 1),
#   ('can', 1),
#   ('claim__number__vip', 1),
#   ('row', 1),
#   ('a', 1),
#   ('tickets__number__c', 1),
#   ('concert', 1),
#   ('novemb', 1),
#   ('or', 1),
#   ('gift', 1),
#   ('guarante', 1),
#   ('call__number__to', 1),
#   ('claim', 1),
#   ('ts', 1),
#   ('cs', 1),
#   ('__url__', 1),
#   ('cost__number__75max', 1)],
#  [('', 4),
#   ('should', 1),
#   ('i', 1),
#   ('send', 1),
#   ('you', 1),
#   ('naughti', 1),
#   ('pix', 1)],
#  [('i', 1),
#   ('love', 1),
#   ('ya', 1),
#   ('too', 1),
#   ('but', 1),
#   ('tri', 1),
#   ('and', 1),
#   ('budget', 1),
#   ('your', 1),
#   ('money', 1),
#   ('better', 1),
#   ('babe', 1),
#   ('', 1),
#   ('gari', 1),
#   ('would', 1),
#   ('freak', 1),
#   ('on', 1),
#   ('me', 1),
#   ('if', 1),
#   ('he', 1),
#   ('knew', 1)],
#  [('pleas', 1),
#   ('call__number__immedi', 1),
#   ('as', 1),
#   ('there', 1),
#   ('is', 1),
#   ('an', 1),
#   ('urgent', 1),
#   ('messag', 1),
#   ('wait', 1),
#   ('for', 1),
#   ('you', 1),
#   ('', 1)],
#  [('so', 1),
#   ('dont', 1),
#   ('use', 1),
#   ('hook', 1),
#   ('up', 1),
#   ('ani', 1),
#   ('how', 1)],
#  [('', 3),
#   ('never', 2),
#   ('password', 2),
#   ('pleas', 1),
#   ('protect', 1),
#   ('yourself', 1),
#   ('from', 1),
#   ('e', 1),
#   ('threat', 1),
#   ('sib', 1),
#   ('ask', 1),
#   ('for', 1),
#   ('sensit', 1),
#   ('inform', 1),
#   ('like', 1),
#   ('atm', 1),
#   ('sm', 1),
#   ('pin', 1),
#   ('thru', 1),
#   ('email', 1),
#   ('share', 1),
#   ('your', 1),
#   ('with', 1),
#   ('anybodi', 1)],
#  [('but', 1),
#   ('i', 1),
#   ('dint', 1),
#   ('slept', 1),
#   ('in', 1),
#   ('afternoon', 1),
#   ('', 1)],
#  [('goodmorn', 1), ('sleep', 1), ('ga', 1), ('', 1)],
#  [('some', 1),
#   ('friend', 1),
#   ('want', 1),
#   ('me', 1),
#   ('to', 1),
#   ('drive', 1),
#   ('em', 1),
#   ('someplac', 1),
#   ('', 1),
#   ('probabl', 1),
#   ('take', 1),
#   ('a', 1),
#   ('while', 1)],
#  [('i', 1),
#   ('ll', 1),
#   ('get', 1),
#   ('there', 1),
#   ('tomorrow', 1),
#   ('and', 1),
#   ('send', 1),
#   ('it', 1),
#   ('to', 1),
#   ('you', 1)],
#  [('da', 2),
#   ('', 2),
#   ('hey', 1),
#   ('check', 1),
#   ('it', 1),
#   ('i', 1),
#   ('have', 1),
#   ('list', 1)],
#  [('i', 4),
#   ('you', 3),
#   ('the', 3),
#   ('so', 2),
#   ('to', 2),
#   ('miss', 1),
#   ('much', 1),
#   ('m', 1),
#   ('despar', 1),
#   ('have', 1),
#   ('record', 1),
#   ('messag', 1),
#   ('left', 1),
#   ('for', 1),
#   ('me', 1),
#   ('other', 1),
#   ('day', 1),
#   ('and', 1),
#   ('listen', 1),
#   ('it', 1),
#   ('just', 1),
#   ('hear', 1),
#   ('sound', 1),
#   ('of', 1),
#   ('your', 1),
#   ('voic', 1),
#   ('', 1),
#   ('love', 1)],
#  [('', 4),
#   ('i', 2),
#   ('sorri', 1),
#   ('ll', 1),
#   ('call', 1),
#   ('you', 1),
#   ('later', 1),
#   ('am', 1),
#   ('in', 1),
#   ('meet', 1),
#   ('sir', 1)],
#  [('', 12),
#   ('a', 2),
#   ('b', 2),
#   ('or', 2),
#   ('c', 2),
#   ('ur', 1),
#   ('balanc', 1),
#   ('is', 1),
#   ('now', 1),
#   ('__number__', 1),
#   ('next', 1),
#   ('question', 1),
#   ('complet', 1),
#   ('the', 1),
#   ('landmark', 1),
#   ('big', 1),
#   ('bob', 1),
#   ('barri', 1),
#   ('ben', 1),
#   ('text', 1),
#   ('to__number__', 1),
#   ('good', 1),
#   ('luck', 1)],
#  [('', 3),
#   ('you', 2),
#   ('congratul', 1),
#   ('ve', 1),
#   ('won', 1),
#   ('re', 1),
#   ('a', 1),
#   ('winner', 1),
#   ('in', 1),
#   ('our', 1),
#   ('august', 1),
#   ('__number__pr', 1),
#   ('draw', 1),
#   ('call__number__now', 1),
#   ('prize', 1),
#   ('code__number__', 1)],
#  [('', 9),
#   ('i', 3),
#   ('oic', 1),
#   ('saw', 1),
#   ('him', 1),
#   ('too', 1),
#   ('but', 1),
#   ('tot', 1),
#   ('he', 1),
#   ('din', 1),
#   ('c', 1),
#   ('me', 1),
#   ('found', 1),
#   ('a', 1),
#   ('group', 1),
#   ('liao', 1)],
#  [('', 3),
#   ('ok', 1),
#   ('both', 1),
#   ('our', 1),
#   ('day', 1),
#   ('so', 1),
#   ('what', 1),
#   ('are', 1),
#   ('you', 1),
#   ('make', 1),
#   ('for', 1),
#   ('dinner', 1),
#   ('tonit', 1),
#   ('am', 1),
#   ('i', 1),
#   ('invit', 1)],
#  [('movi', 2),
#   ('and', 2),
#   ('is', 1),
#   ('there', 1),
#   ('ani', 1),
#   ('theatr', 1),
#   ('i', 1),
#   ('can', 1),
#   ('go', 1),
#   ('to', 1),
#   ('watch', 1),
#   ('unlimit', 1),
#   ('just', 1),
#   ('pay', 1),
#   ('onc', 1),
#   ('', 1)],
#  [('how', 1), ('much', 1), ('you', 1), ('got', 1), ('for', 1), ('clean', 1)],
#  [('', 3),
#   ('i', 2),
#   ('yeah', 1),
#   ('ll', 1),
#   ('leav', 1),
#   ('in', 1),
#   ('a', 1),
#   ('coupl', 1),
#   ('minut', 1),
#   ('amp', 1),
#   ('let', 1),
#   ('you', 1),
#   ('know', 1),
#   ('when', 1),
#   ('get', 1),
#   ('to', 1),
#   ('mu', 1)],
#  [('', 4),
#   ('ye', 1),
#   ('princess', 1),
#   ('i', 1),
#   ('want', 1),
#   ('to', 1),
#   ('catch', 1),
#   ('you', 1),
#   ('with', 1),
#   ('my', 1),
#   ('big', 1),
#   ('strong', 1),
#   ('hand', 1)],
#  [('', 7),
#   ('to', 2),
#   ('hi', 2),
#   ('stop', 2),
#   ('sm', 1),
#   ('ac', 1),
#   ('sun0819', 1),
#   ('post', 1),
#   ('hello', 1),
#   ('you', 1),
#   ('seem', 1),
#   ('cool', 1),
#   ('want', 1),
#   ('say', 1),
#   ('send', 1),
#   ('62468', 1)],
#  [('', 7),
#   ('now', 1),
#   ('what', 1),
#   ('your', 1),
#   ('hous', 1),
#   ('again', 1),
#   ('and', 1),
#   ('do', 1),
#   ('you', 1),
#   ('have', 1),
#   ('ani', 1),
#   ('beer', 1),
#   ('there', 1)],
#  [('whi', 1), ('do', 1), ('you', 1), ('ask', 1), ('princess', 1), ('', 1)],
#  [('', 7),
#   ('u', 3),
#   ('i', 2),
#   ('so', 2),
#   ('ask', 2),
#   ('got', 1),
#   ('to', 1),
#   ('video', 1),
#   ('tape', 1),
#   ('pple', 1),
#   ('type', 1),
#   ('in', 1),
#   ('messag', 1),
#   ('lor', 1),
#   ('free', 1),
#   ('wan__number__help', 1),
#   ('me', 1),
#   ('hee', 1),
#   ('co', 1),
#   ('noe', 1),
#   ('wan__number__watch', 1),
#   ('infern', 1),
#   ('affair', 1),
#   ('along', 1),
#   ('shuhui', 1),
#   ('oso', 1)],
#  [('', 11),
#   ('xma', 4),
#   ('the', 3),
#   ('is', 3),
#   ('stori', 1),
#   ('peac', 1),
#   ('msg', 1),
#   ('love', 1),
#   ('miracl', 1),
#   ('jesu', 1),
#   ('hav', 1),
#   ('a', 1),
#   ('bless', 1),
#   ('month', 1),
#   ('ahead', 1),
#   ('amp', 1),
#   ('wish', 1),
#   ('u', 1),
#   ('merri', 1)],
#  [('hi', 1),
#   ('it', 1),
#   ('in', 1),
#   ('durban', 1),
#   ('are', 1),
#   ('you', 1),
#   ('still', 1),
#   ('on', 1),
#   ('thi', 1),
#   ('number', 1)],
#  [('take', 1),
#   ('us', 1),
#   ('out', 1),
#   ('shop', 1),
#   ('and', 1),
#   ('mark', 1),
#   ('will', 1),
#   ('distract', 1),
#   ('isaiah', 1),
#   ('', 1),
#   ('d', 1)],
#  [('a', 2),
#   ('', 2),
#   ('you', 1),
#   ('are', 1),
#   ('winner', 1),
#   ('u', 1),
#   ('have', 1),
#   ('been', 1),
#   ('special', 1),
#   ('selected__number__rec', 1),
#   ('__number__cash', 1),
#   ('or', 1),
#   ('a__number__', 1),
#   ('holiday', 1),
#   ('flight', 1),
#   ('inc', 1),
#   ('speak', 1),
#   ('to', 1),
#   ('live', 1),
#   ('operator__number__claim', 1),
#   ('0871277810810', 1)],
#  [('have', 1),
#   ('you', 1),
#   ('been', 1),
#   ('practis', 1),
#   ('your', 1),
#   ('curtsey', 1),
#   ('', 1)],
#  [('shall', 1), ('i', 1), ('start', 1), ('from', 1), ('hear', 1), ('', 1)],
#  [('', 2), ('ok', 1), ('so', 1), ('april', 1), ('cant', 1), ('wait', 1)],
#  [('', 3),
#   ('i', 2),
#   ('ok', 1),
#   ('vl', 1),
#   ('do', 1),
#   ('u', 1),
#   ('know', 1),
#   ('got', 1),
#   ('adsens', 1),
#   ('approv', 1)],
#  [('', 4),
#   ('in', 2),
#   ('text', 2),
#   ('talk', 1),
#   ('sexi', 1),
#   ('make', 1),
#   ('new', 1),
#   ('friend', 1),
#   ('or', 1),
#   ('fall', 1),
#   ('love', 1),
#   ('the', 1),
#   ('world', 1),
#   ('most', 1),
#   ('discreet', 1),
#   ('date', 1),
#   ('servic', 1),
#   ('just', 1),
#   ('vip', 1),
#   ('to__number__and', 1),
#   ('see', 1),
#   ('who', 1),
#   ('you', 1),
#   ('could', 1),
#   ('meet', 1)],
#  [('k', 1),
#   ('i', 1),
#   ('m', 1),
#   ('leav', 1),
#   ('soon', 1),
#   ('', 1),
#   ('be', 1),
#   ('there', 1),
#   ('a', 1),
#   ('littl', 1),
#   ('after', 1),
#   ('9', 1)],
#  [('i', 2),
#   ('ll', 1),
#   ('text', 1),
#   ('you', 1),
#   ('when', 1),
#   ('drop', 1),
#   ('x', 1),
#   ('off', 1)],
#  [('', 3), ('i', 1), ('m', 1), ('done', 1), ('oredi', 1)],
#  [('', 24),
#   ('lt', 3),
#   ('gt', 3),
#   ('only__number__', 1),
#   ('student', 1),
#   ('solv', 1),
#   ('thi', 1),
#   ('cat', 1),
#   ('question', 1),
#   ('in', 1),
#   ('xam', 1),
#   ('__number__3__number__', 1),
#   ('__number__2__number__', 1),
#   ('__number__6__number__', 1),
#   ('then__number__2__number__', 1),
#   ('tell', 1),
#   ('me', 1),
#   ('the', 1),
#   ('answer', 1),
#   ('if', 1),
#   ('u', 1),
#   ('r', 1),
#   ('brilliant', 1),
#   ('1thing', 1),
#   ('i', 1),
#   ('got', 1),
#   ('d', 1),
#   ('answr', 1)],
#  [('', 4),
#   ('di', 2),
#   ('is', 2),
#   ('my', 2),
#   ('num', 2),
#   ('yiju', 1),
#   ('i', 1),
#   ('ju', 1),
#   ('saw', 1),
#   ('ur', 1),
#   ('mail', 1),
#   ('in', 1),
#   ('case', 1),
#   ('huim', 1),
#   ('havent', 1),
#   ('sent', 1),
#   ('u', 1)],
#  [('', 6),
#   ('lt', 1),
#   ('gt', 1),
#   ('ish', 1),
#   ('minut', 1),
#   ('was__number__minut', 1),
#   ('ago', 1),
#   ('wtf', 1)],
#  [('the', 2),
#   ('later', 2),
#   ('hi', 1),
#   ('babi', 1),
#   ('im', 1),
#   ('sat', 1),
#   ('on', 1),
#   ('bloodi', 1),
#   ('bu', 1),
#   ('at', 1),
#   ('mo', 1),
#   ('and', 1),
#   ('i', 1),
#   ('wont', 1),
#   ('be', 1),
#   ('home', 1),
#   ('until', 1),
#   ('about__number__30', 1),
#   ('wanna', 1),
#   ('do', 1),
#   ('somethin', 1),
#   ('', 1),
#   ('call', 1),
#   ('me', 1),
#   ('ortxt', 1),
#   ('back', 1),
#   ('jess', 1),
#   ('xx', 1)],
#  [('', 12),
#   ('you', 4),
#   ('my', 3),
#   ('are', 3),
#   ('good', 2),
#   ('afternoon', 1),
#   ('boytoy', 1),
#   ('how', 1),
#   ('feel', 1),
#   ('today', 1),
#   ('better', 1),
#   ('i', 1),
#   ('hope', 1),
#   ('be', 1),
#   ('boy', 1),
#   ('obedi', 1),
#   ('slave', 1),
#   ('do', 1),
#   ('pleas', 1),
#   ('your', 1),
#   ('queen', 1)],
#  [('wa', 1), ('the', 1), ('farm', 1), ('open', 1), ('', 1)],
#  [('', 3),
#   ('u', 2),
#   ('rgent', 1),
#   ('thi', 1),
#   ('is', 1),
#   ('the', 1),
#   ('2nd', 1),
#   ('attempt', 1),
#   ('to', 1),
#   ('contact', 1),
#   ('have', 1),
#   ('won', 1),
#   ('__number__call__number__b4__number__t', 1),
#   ('csbcm4235wc1n3xx', 1),
#   ('callcost', 1),
#   ('150ppm', 1),
#   ('mobilesvari', 1),
#   ('max__number__', 1),
#   ('50', 1)],
#  [('', 3),
#   ('so', 1),
#   ('i', 1),
#   ('could', 1),
#   ('kiss', 1),
#   ('and', 1),
#   ('feel', 1),
#   ('you', 1),
#   ('next', 1),
#   ('to', 1),
#   ('me', 1)],
#  [('you', 2),
#   ('the', 1),
#   ('ga', 1),
#   ('station', 1),
#   ('is', 1),
#   ('like', 1),
#   ('a', 1),
#   ('block', 1),
#   ('away', 1),
#   ('from', 1),
#   ('my', 1),
#   ('hous', 1),
#   ('', 1),
#   ('ll', 1),
#   ('drive', 1),
#   ('right', 1),
#   ('by', 1),
#   ('it', 1),
#   ('sinc', 1),
#   ('armenia', 1),
#   ('end', 1),
#   ('at', 1),
#   ('swann', 1),
#   ('and', 1),
#   ('have', 1),
#   ('to', 1),
#   ('take', 1),
#   ('howard', 1)],
#  [('he', 3),
#   ('if', 1),
#   ('start', 1),
#   ('search', 1),
#   ('will', 1),
#   ('get', 1),
#   ('job', 1),
#   ('in', 1),
#   ('few', 1),
#   ('day', 1),
#   ('have', 1),
#   ('great', 1),
#   ('potenti', 1),
#   ('and', 1),
#   ('talent', 1),
#   ('', 1)],
#  [('', 2), ('just', 1), ('tast', 1), ('fish', 1), ('curri', 1), ('p', 1)],
#  [('did', 1),
#   ('he', 1),
#   ('just', 1),
#   ('say', 1),
#   ('somebodi', 1),
#   ('is', 1),
#   ('name', 1),
#   ('tampa', 1)],
#  [('when', 1), ('should', 1), ('i', 1), ('come', 1), ('over', 1), ('', 1)],
#  [('', 3),
#   ('yup', 1),
#   ('i', 1),
#   ('ve', 1),
#   ('finish', 1),
#   ('c', 1),
#   ('ü', 1),
#   ('there', 1)],
#  [('ye', 1), ('there', 1), ('were', 1), ('mani', 1), ('sweet', 1)],
#  [('just', 1),
#   ('do', 1),
#   ('what', 1),
#   ('ever', 1),
#   ('is', 1),
#   ('easier', 1),
#   ('for', 1),
#   ('you', 1)],
#  [('i', 2),
#   ('t', 2),
#   ('and', 1),
#   ('don', 1),
#   ('plan', 1),
#   ('on', 1),
#   ('stay', 1),
#   ('the', 1),
#   ('night', 1),
#   ('but', 1),
#   ('prolli', 1),
#   ('won', 1),
#   ('be', 1),
#   ('back', 1),
#   ('til', 1),
#   ('late', 1)],
#  [('', 4),
#   ('yeah', 1),
#   ('work', 1),
#   ('is', 1),
#   ('fine', 1),
#   ('start', 1),
#   ('last', 1),
#   ('week', 1),
#   ('all', 1),
#   ('the', 1),
#   ('same', 1),
#   ('stuff', 1),
#   ('as', 1),
#   ('befor', 1),
#   ('dull', 1),
#   ('but', 1),
#   ('easi', 1),
#   ('and', 1),
#   ('guy', 1),
#   ('are', 1),
#   ('fun', 1)],
#  [('', 3),
#   ('well', 1),
#   ('i', 1),
#   ('might', 1),
#   ('not', 1),
#   ('come', 1),
#   ('then', 1)],
#  [('', 7),
#   ('that', 2),
#   ('you', 2),
#   ('same', 2),
#   ('s', 1),
#   ('the', 1),
#   ('troubl', 1),
#   ('with', 1),
#   ('class', 1),
#   ('go', 1),
#   ('well', 1),
#   ('re', 1),
#   ('due', 1),
#   ('a', 1),
#   ('dodgey', 1),
#   ('one', 1),
#   ('expect', 1),
#   ('mine', 1),
#   ('tomo', 1),
#   ('see', 1),
#   ('for', 1),
#   ('recoveri', 1),
#   ('time', 1),
#   ('place', 1)],
#  [('', 5),
#   ('it', 2),
#   ('got', 1),
#   ('look', 1),
#   ('scrumptiou', 1),
#   ('daddi', 1),
#   ('want', 1),
#   ('to', 1),
#   ('eat', 1),
#   ('you', 1),
#   ('all', 1),
#   ('night', 1),
#   ('long', 1)],
#  [('', 9),
#   ('wait', 1),
#   ('i', 1),
#   ('will', 1),
#   ('come', 1),
#   ('out', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('min', 1)],
#  [('', 3), ('enjoy', 1), ('ur', 1), ('life', 1), ('good', 1), ('night', 1)],
#  [('', 3),
#   ('bright', 2),
#   ('light', 2),
#   ('my', 1),
#   ('slave', 1),
#   ('i', 1),
#   ('want', 1),
#   ('you', 1),
#   ('to', 1),
#   ('take__number__or__number__pictur', 1),
#   ('of', 1),
#   ('yourself', 1),
#   ('today', 1),
#   ('in', 1),
#   ('on', 1),
#   ('your', 1),
#   ('cell', 1),
#   ('phone', 1)],
#  [('', 4),
#   ('he', 3),
#   ('s', 3),
#   ('like', 2),
#   ('i', 2),
#   ('crazi', 1),
#   ('ar', 1),
#   ('marri', 1),
#   ('ü', 1),
#   ('gd', 1),
#   ('look', 1),
#   ('guy', 1),
#   ('not', 1),
#   ('me', 1),
#   ('my', 1),
#   ('fren', 1),
#   ('say', 1),
#   ('korean', 1),
#   ('leona', 1),
#   ('fave', 1),
#   ('but', 1),
#   ('dun', 1),
#   ('thk', 1),
#   ('is', 1),
#   ('aft', 1),
#   ('some', 1),
#   ('think', 1),
#   ('mayb', 1),
#   ('most', 1),
#   ('prob', 1),
#   ('ll', 1),
#   ('go', 1)],
#  [('', 3),
#   ('ü', 1),
#   ('no', 1),
#   ('home', 1),
#   ('work', 1),
#   ('to', 1),
#   ('do', 1),
#   ('meh', 1)],
#  [('oh', 1),
#   ('wow', 1),
#   ('that', 1),
#   ('gay', 1),
#   ('', 1),
#   ('will', 1),
#   ('firmwar', 1),
#   ('updat', 1),
#   ('help', 1)],
#  [('', 4),
#   ('you', 2),
#   ('could', 1),
#   ('have', 1),
#   ('seen', 1),
#   ('me', 1),
#   ('i', 1),
#   ('did', 1),
#   ('t', 1),
#   ('recognis', 1),
#   ('face', 1)],
#  [('', 5), ('k', 1), ('all', 1), ('the', 1), ('best', 1), ('congrat', 1)],
#  [('dear', 1),
#   ('good', 1),
#   ('morn', 1),
#   ('now', 1),
#   ('onli', 1),
#   ('i', 1),
#   ('am', 1),
#   ('up', 1)],
#  [('how', 1), ('s', 1), ('ur', 1), ('paper', 1), ('', 1)],
#  [('is', 1),
#   ('xy', 1),
#   ('in', 1),
#   ('ur', 1),
#   ('car', 1),
#   ('when', 1),
#   ('u', 1),
#   ('pick', 1),
#   ('me', 1),
#   ('up', 1),
#   ('', 1)],
#  [('yeah', 1),
#   ('sure', 1),
#   ('i', 1),
#   ('ll', 1),
#   ('leav', 1),
#   ('in', 1),
#   ('a', 1),
#   ('min', 1)],
#  [('', 4),
#   ('with', 2),
#   ('nuther', 2),
#   ('i', 1),
#   ('know', 1),
#   ('dat', 1),
#   ('feelin', 1),
#   ('had', 1),
#   ('it', 1),
#   ('pete', 1),
#   ('wuld', 1),
#   ('get', 1),
#   ('em', 1),
#   ('place', 1),
#   ('time', 1),
#   ('mayb', 1)],
#  [('', 7),
#   ('it', 3),
#   ('feel', 2),
#   ('when', 2),
#   ('someon', 2),
#   ('beauti', 1),
#   ('truth', 1),
#   ('against', 1),
#   ('graviti', 1),
#   ('read', 1),
#   ('care', 1),
#   ('our', 1),
#   ('heart', 1),
#   ('light', 1),
#   ('is', 1),
#   ('in', 1),
#   ('but', 1),
#   ('veri', 1),
#   ('heavi', 1),
#   ('leav', 1),
#   ('good', 1),
#   ('night', 1)],
#  [('', 4),
#   ('draw', 2),
#   ('xma', 1),
#   ('prize', 1),
#   ('we', 1),
#   ('are', 1),
#   ('tri', 1),
#   ('to', 1),
#   ('contact', 1),
#   ('u', 1),
#   ('today', 1),
#   ('show', 1),
#   ('that', 1),
#   ('you', 1),
#   ('have', 1),
#   ('won', 1),
#   ('a', 1),
#   ('__number__pr', 1),
#   ('guarante', 1),
#   ('call__number__from', 1),
#   ('land', 1),
#   ('line', 1),
#   ('valid', 1),
#   ('12hr', 1),
#   ('onli', 1)],
#  [('', 19),
#   ('you', 3),
#   ('to', 3),
#   ('i', 2),
#   ('miss', 2),
#   ('t', 2),
#   ('me', 2),
#   ('deep', 1),
#   ('sigh', 1),
#   ('am', 1),
#   ('realli', 1),
#   ('surpris', 1),
#   ('haven', 1),
#   ('gone', 1),
#   ('the', 1),
#   ('net', 1),
#   ('cafe', 1),
#   ('yet', 1),
#   ('get', 1),
#   ('don', 1)],
#  [('to', 4),
#   ('', 2),
#   ('ur', 1),
#   ('going__number__bahama', 1),
#   ('callfreefone__number__and', 1),
#   ('speak', 1),
#   ('a', 1),
#   ('live', 1),
#   ('oper', 1),
#   ('claim', 1),
#   ('either', 1),
#   ('bahama', 1),
#   ('cruis', 1),
#   ('of__number__cash__number__onli', 1),
#   ('opt', 1),
#   ('out', 1),
#   ('txt', 1),
#   ('x', 1),
#   ('07786200117', 1)],
#  [('call', 3),
#   ('unlimit', 2),
#   ('', 2),
#   ('txt', 2),
#   ('freemsg', 1),
#   ('__number__month', 1),
#   ('free', 1),
#   ('activ', 1),
#   ('smartcal', 1),
#   ('to', 1),
#   ('no', 1),
#   ('__number__', 1),
#   ('subscriptn3gbp', 1),
#   ('wk', 1),
#   ('help', 1),
#   ('__number__stop', 1),
#   ('stop', 1),
#   ('landlineonli', 1)],
#  [('', 3),
#   ('k', 2),
#   ('how', 1),
#   ('much', 1),
#   ('doe', 1),
#   ('it', 1),
#   ('cost', 1)],
#  [('', 14),
#   ('good', 1),
#   ('morn', 1),
#   ('my', 1),
#   ('dear', 1),
#   ('have', 1),
#   ('a', 1),
#   ('great', 1),
#   ('amp', 1),
#   ('success', 1),
#   ('day', 1)],
#  [('send', 1), ('me', 1), ('the', 1), ('new', 1), ('number', 1)],
#  [('we', 1), ('still', 1), ('on', 1), ('for', 1), ('tonight', 1), ('', 1)],
#  [('', 3), ('ok', 1)],
#  [('', 10),
#   ('wit', 2),
#   ('ya', 1),
#   ('i', 1),
#   ('knw', 1),
#   ('u', 1),
#   ('vl', 1),
#   ('giv', 1),
#   ('it', 1),
#   ('ok', 1),
#   ('thank', 1),
#   ('kano', 1),
#   ('anyway', 1),
#   ('enjoy', 1),
#   ('ur', 1),
#   ('famili', 1),
#   ('1st', 1),
#   ('salari', 1)],
#  [('care', 2),
#   ('about', 2),
#   ('stuff', 2),
#   ('no', 1),
#   ('', 1),
#   ('i', 1),
#   ('decid', 1),
#   ('that', 1),
#   ('onli', 1),
#   ('peopl', 1),
#   ('who', 1),
#   ('vote', 1),
#   ('and', 1),
#   ('is', 1),
#   ('for', 1),
#   ('loser', 1)],
#  [('', 6),
#   ('i', 1),
#   ('am', 1),
#   ('liter', 1),
#   ('in', 1),
#   ('bed', 1),
#   ('and', 1),
#   ('have', 1),
#   ('been', 1),
#   ('up', 1),
#   ('for', 1),
#   ('like', 1),
#   ('lt', 1),
#   ('gt', 1),
# ...
#   ('call', 1),
#   ('and', 1),
#   ('whi', 1),
#   ('come', 1),
#   ('it', 1),
#   ('make', 1),
#   ('feel', 1),
#   ('like', 1),
#   ('die', 1)],
#  [('', 5),
#   ('pl', 3),
#   ('birthday', 2),
#   ('raji', 1),
#   ('do', 1),
#   ('me', 1),
#   ('a', 1),
#   ('favour', 1),
#   ('convey', 1),
#   ('my', 1),
#   ('wish', 1),
#   ('to', 1),
#   ('nimya', 1),
#   ('today', 1),
#   ('is', 1),
#   ('her', 1)],
#  [('i', 2),
#   ('sure', 1),
#   ('', 1),
#   ('ll', 1),
#   ('see', 1),
#   ('if', 1),
#   ('can', 1),
#   ('come', 1),
#   ('by', 1),
#   ('in', 1),
#   ('a', 1),
#   ('bit', 1)],
#  [('', 4),
#   ('may', 1),
#   ('b', 1),
#   ('approv', 1),
#   ('panalam', 1),
#   ('but', 1),
#   ('it', 1),
#   ('should', 1),
#   ('have', 1),
#   ('more', 1),
#   ('post', 1)],
#  [('', 3), ('anyth', 1), ('lar', 1)],
#  [('right', 1),
#   ('on', 1),
#   ('brah', 1),
#   ('', 1),
#   ('see', 1),
#   ('you', 1),
#   ('later', 1)],
#  [('', 2),
#   ('aight', 1),
#   ('we', 1),
#   ('can', 1),
#   ('pick', 1),
#   ('some', 1),
#   ('up', 1),
#   ('you', 1),
#   ('open', 1),
#   ('befor', 1),
#   ('tonight', 1)],
#  [('', 22),
#   ('you', 5),
#   ('love', 3),
#   ('i', 3),
#   ('to', 3),
#   ('my', 2),
#   ('your', 2),
#   ('and', 2),
#   ('hear', 2),
#   ('it', 2),
#   ('the', 2),
#   ('hello', 1),
#   ('how', 1),
#   ('went', 1),
#   ('day', 1),
#   ('are', 1),
#   ('alright', 1),
#   ('think', 1),
#   ('of', 1),
#   ('sweet', 1),
#   ('send', 1),
#   ('a', 1),
#   ('jolt', 1),
#   ('heart', 1),
#   ('remind', 1),
#   ('can', 1),
#   ('scream', 1),
#   ('across', 1),
#   ('sea', 1),
#   ('for', 1),
#   ('all', 1),
#   ('world', 1),
#   ('ahmad', 1),
#   ('al', 1),
#   ('hallaq', 1),
#   ('is', 1),
#   ('own', 1),
#   ('possess', 1),
#   ('passion', 1),
#   ('kiss', 1)],
#  [('', 14),
#   ('oki', 2),
#   ('food', 2),
#   ('mon', 1),
#   ('lor', 1),
#   ('haha', 1),
#   ('best', 1),
#   ('is', 1),
#   ('cheap', 1),
#   ('n', 1),
#   ('gd', 1),
#   ('la', 1),
#   ('ex', 1),
#   ('oso', 1),
#   ('depend', 1),
#   ('on', 1),
#   ('whether', 1),
#   ('wana', 1),
#   ('eat', 1),
#   ('western', 1),
#   ('or', 1),
#   ('chines', 1),
#   ('den', 1),
#   ('which', 1),
#   ('u', 1),
#   ('prefer', 1)],
#  [('', 2),
#   ('to', 2),
#   ('updat', 2),
#   ('the', 2),
#   ('mobil', 2),
#   ('free', 2),
#   ('had', 1),
#   ('your', 1),
#   ('mobile__number__month', 1),
#   ('or', 1),
#   ('more', 1),
#   ('u', 1),
#   ('r', 1),
#   ('entitl', 1),
#   ('latest', 1),
#   ('colour', 1),
#   ('with', 1),
#   ('camera', 1),
#   ('for', 1),
#   ('call', 1),
#   ('co', 1),
#   ('on', 1),
#   ('08002986030', 1)],
#  [('', 6),
#   ('a', 3),
#   ('u', 2),
#   ('slo', 2),
#   ('babe', 1),
#   ('want', 1),
#   ('me', 1),
#   ('dont', 1),
#   ('babi', 1),
#   ('im', 1),
#   ('nasti', 1),
#   ('and', 1),
#   ('have', 1),
#   ('thing__number__filthyguy', 1),
#   ('fanci', 1),
#   ('rude', 1),
#   ('time', 1),
#   ('with', 1),
#   ('sexi', 1),
#   ('bitch', 1),
#   ('how', 1),
#   ('about', 1),
#   ('we', 1),
#   ('go', 1),
#   ('n', 1),
#   ('hard', 1),
#   ('txt', 1),
#   ('xxx', 1),
#   ('4msg', 1)],
#  [('may', 2),
#   ('to', 2),
#   ('sweet', 1),
#   ('', 1),
#   ('we', 1),
#   ('or', 1),
#   ('not', 1),
#   ('go', 1),
#   ('4u', 1),
#   ('meet', 1),
#   ('carlo', 1),
#   ('so', 1),
#   ('gaug', 1),
#   ('patti', 1),
#   ('s', 1),
#   ('interest', 1),
#   ('in', 1),
#   ('that', 1)],
#  [('', 4),
#   ('a', 2),
#   ('promot', 1),
#   ('number', 1),
#   ('__number__', 1),
#   ('ur', 1),
#   ('award', 1),
#   ('citi', 1),
#   ('break', 1),
#   ('and', 1),
#   ('could', 1),
#   ('win', 1),
#   ('__number__summ', 1),
#   ('shop', 1),
#   ('spree', 1),
#   ('everi', 1),
#   ('wk', 1),
#   ('txt', 1),
#   ('store', 1),
#   ('to__number__', 1),
#   ('skilgm', 1),
#   ('tscs087147403231winawk', 1),
#   ('age16', 1),
#   ('__number__50perwksub', 1)],
#  [('i', 2),
#   ('oh', 1),
#   ('ok', 1),
#   ('didnt', 1),
#   ('know', 1),
#   ('what', 1),
#   ('you', 1),
#   ('meant', 1),
#   ('', 1),
#   ('yep', 1),
#   ('am', 1),
#   ('babi', 1),
#   ('jontin', 1)],
#  [('', 4),
#   ('u', 2),
#   ('appt', 1),
#   ('is', 1),
#   ('at', 1),
#   ('lt', 1),
#   ('time', 1),
#   ('gt', 1),
#   ('am', 1),
#   ('not', 1),
#   ('my', 1),
#   ('fault', 1),
#   ('don', 1),
#   ('t', 1),
#   ('listen', 1),
#   ('i', 1),
#   ('told', 1),
#   ('twice', 1)],
#  [('ok', 1)],
#  [('', 4),
#   ('to', 2),
#   ('you', 2),
#   ('sorri', 1),
#   ('i', 1),
#   ('will', 1),
#   ('be', 1),
#   ('abl', 1),
#   ('get', 1),
#   ('see', 1),
#   ('in', 1),
#   ('the', 1),
#   ('morn', 1)],
#  [('', 14),
#   ('a', 2),
#   ('answer', 2),
#   ('is', 2),
#   ('awesom', 1),
#   ('question', 1),
#   ('with', 1),
#   ('cute', 1),
#   ('someon', 1),
#   ('ask', 1),
#   ('boy', 1),
#   ('how', 1),
#   ('ur', 1),
#   ('life', 1),
#   ('he', 1),
#   ('smile', 1),
#   ('amp', 1),
#   ('she', 1),
#   ('fine', 1),
#   ('gudnit', 1)],
#  [('wat', 1), ('time', 1), ('ü', 1), ('wan', 1), ('today', 1), ('', 1)],
#  [('here', 1),
#   ('is', 1),
#   ('my', 1),
#   ('new', 1),
#   ('address', 1),
#   ('', 1),
#   ('appl', 1),
#   ('pair', 1),
#   ('all', 1),
#   ('that', 1),
#   ('malarki', 1)],
#  [('mm', 1),
#   ('i', 1),
#   ('had', 1),
#   ('my', 1),
#   ('food', 1),
#   ('da', 1),
#   ('from', 1),
#   ('out', 1)],
#  [('', 4),
#   ('i', 3),
#   ('and', 2),
#   ('to', 2),
#   ('happi', 1),
#   ('valentin', 1),
#   ('day', 1),
#   ('know', 1),
#   ('it', 1),
#   ('earli', 1),
#   ('but', 1),
#   ('have', 1),
#   ('hundr', 1),
#   ('of', 1),
#   ('handsom', 1),
#   ('beauti', 1),
#   ('wish', 1),
#   ('so', 1),
#   ('thought', 1),
#   ('finish', 1),
#   ('off', 1),
#   ('aunti', 1),
#   ('uncl', 1),
#   ('1st', 1)],
#  [('thank', 1),
#   ('for', 1),
#   ('thi', 1),
#   ('hope', 1),
#   ('you', 1),
#   ('had', 1),
#   ('a', 1),
#   ('good', 1),
#   ('day', 1),
#   ('today', 1)],
#  [('he', 3),
#   ('if', 1),
#   ('start', 1),
#   ('search', 1),
#   ('will', 1),
#   ('get', 1),
#   ('job', 1),
#   ('in', 1),
#   ('few', 1),
#   ('day', 1),
#   ('have', 1),
#   ('great', 1),
#   ('potenti', 1),
#   ('and', 1),
#   ('talent', 1),
#   ('', 1)],
#  [('', 2),
#   ('18', 1),
#   ('day', 1),
#   ('to', 1),
#   ('euro2004', 1),
#   ('kickoff', 1),
#   ('u', 1),
#   ('will', 1),
#   ('be', 1),
#   ('kept', 1),
#   ('inform', 1),
#   ('of', 1),
#   ('all', 1),
#   ('the', 1),
#   ('latest', 1),
#   ('news', 1),
#   ('and', 1),
#   ('result', 1),
#   ('daili', 1),
#   ('unsubscrib', 1),
#   ('send', 1),
#   ('get', 1),
#   ('euro', 1),
#   ('stop', 1),
#   ('to__number__', 1)],
#  [('it', 1), ('good', 1), ('to', 1), ('hear', 1), ('from', 1), ('you', 1)],
#  [('', 6),
#   ('ur', 2),
#   ('ok', 1),
#   ('take', 1),
#   ('time', 1),
#   ('n', 1),
#   ('enjoy', 1),
#   ('dinner', 1)],
#  [('', 9),
#   ('i', 2),
#   ('ok', 1),
#   ('lor', 1),
#   ('soni', 1),
#   ('ericsson', 1),
#   ('salesman', 1),
#   ('ask', 1),
#   ('shuhui', 1),
#   ('then', 1),
#   ('she', 1),
#   ('say', 1),
#   ('quit', 1),
#   ('gd__number__us', 1),
#   ('so', 1),
#   ('consid', 1)],
#  [('', 2),
#   ('oh', 1),
#   ('ic', 1),
#   ('i', 1),
#   ('thought', 1),
#   ('you', 1),
#   ('meant', 1),
#   ('mari', 1),
#   ('jane', 1)],
#  [('guessin', 1),
#   ('you', 1),
#   ('ain', 1),
#   ('t', 1),
#   ('gonna', 1),
#   ('be', 1),
#   ('here', 1),
#   ('before__number__', 1)],
#  [('', 13),
#   ('for', 2),
#   ('the', 2),
#   ('dear', 1),
#   ('friend', 1),
#   ('sorri', 1),
#   ('late', 1),
#   ('inform', 1),
#   ('today', 1),
#   ('is', 1),
#   ('birthday', 1),
#   ('of', 1),
#   ('our', 1),
#   ('love', 1),
#   ('ar', 1),
#   ('praveesh', 1),
#   ('more', 1),
#   ('detail', 1),
#   ('log', 1),
#   ('on', 1),
#   ('to', 1),
#   ('face', 1),
#   ('book', 1),
#   ('and', 1),
#   ('see', 1),
#   ('it', 1),
#   ('hi', 1),
#   ('number', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('dont', 1),
#   ('miss', 1),
#   ('a', 1),
#   ('delici', 1),
#   ('treat', 1)],
#  [('we', 1), ('confirm', 1), ('eat', 1), ('at', 1), ('esplanad', 1), ('', 1)],
#  [('', 4),
#   ('the', 2),
#   ('hiya', 1),
#   ('do', 1),
#   ('u', 1),
#   ('like', 1),
#   ('hlday', 1),
#   ('pic', 1),
#   ('look', 1),
#   ('horribl', 1),
#   ('in', 1),
#   ('them', 1),
#   ('so', 1),
#   ('took', 1),
#   ('mo', 1),
#   ('out', 1),
#   ('how', 1),
#   ('camp', 1),
#   ('amrca', 1),
#   ('thing', 1),
#   ('speak', 1),
#   ('soon', 1),
#   ('serena', 1)],
#  [('', 3), ('enjoy', 1), ('urself', 1), ('tmr', 1)],
#  [('', 8),
#   ('god', 4),
#   ('s', 4),
#   ('ha', 3),
#   ('no', 3),
#   ('love', 1),
#   ('limit', 1),
#   ('grace', 1),
#   ('measur', 1),
#   ('power', 1),
#   ('boundari', 1),
#   ('may', 1),
#   ('u', 1),
#   ('have', 1),
#   ('endless', 1),
#   ('bless', 1),
#   ('alway', 1),
#   ('in', 1),
#   ('ur', 1),
#   ('life', 1),
#   ('gud', 1),
#   ('ni8', 1)],
#  [('', 5),
#   ('pl', 3),
#   ('birthday', 2),
#   ('raji', 1),
#   ('do', 1),
#   ('me', 1),
#   ('a', 1),
#   ('favour', 1),
#   ('convey', 1),
#   ('my', 1),
#   ('wish', 1),
#   ('to', 1),
#   ('nimya', 1),
#   ('today', 1),
#   ('is', 1),
#   ('her', 1)],
#  [('', 3),
#   ('i', 1),
#   ('just', 1),
#   ('made', 1),
#   ('some', 1),
#   ('payment', 1),
#   ('so', 1),
#   ('dont', 1),
#   ('have', 1),
#   ('that', 1),
#   ('much', 1),
#   ('sorri', 1),
#   ('would', 1),
#   ('you', 1),
#   ('want', 1),
#   ('it', 1),
#   ('fedex', 1),
#   ('or', 1),
#   ('the', 1),
#   ('other', 1),
#   ('way', 1)],
#  [('', 2),
#   ('i', 2),
#   ('ve', 2),
#   ('been', 2),
#   ('oh', 1),
#   ('ye', 1),
#   ('just', 1),
#   ('a', 1),
#   ('littl', 1),
#   ('under', 1),
#   ('the', 1),
#   ('weather', 1),
#   ('so', 1),
#   ('kind', 1),
#   ('of', 1),
#   ('coccoon', 1),
#   ('at', 1),
#   ('home', 1)],
#  [('freemsg', 1),
#   ('fav', 1),
#   ('xma', 1),
#   ('tone', 1),
#   ('repli', 1),
#   ('real', 1)],
#  [('', 3),
#   ('a', 2),
#   ('love', 2),
#   ('send', 1),
#   ('logo__number__ur', 1),
#   ('lover', 1),
#   ('__number__nam', 1),
#   ('join', 1),
#   ('by', 1),
#   ('heart', 1),
#   ('txt', 1),
#   ('name1', 1),
#   ('name2', 1),
#   ('mobno', 1),
#   ('eg', 1),
#   ('adam', 1),
#   ('eve__number__to__number__yahoo', 1),
#   ('pobox36504w45wq', 1),
#   ('txtno__number__no', 1),
#   ('ad', 1),
#   ('150p', 1)],
#  [('', 3),
#   ('a', 2),
#   ('you', 1),
#   ('are', 1),
#   ('guarante', 1),
#   ('the', 1),
#   ('latest', 1),
#   ('nokia', 1),
#   ('phone', 1),
#   ('40gb', 1),
#   ('ipod', 1),
#   ('mp3', 1),
#   ('player', 1),
#   ('or', 1),
#   ('__number__pr', 1),
#   ('txt', 1),
#   ('word', 1),
#   ('collect', 1),
#   ('to', 1),
#   ('no', 1),
#   ('__number__', 1),
#   ('ibhltd', 1),
#   ('ldnw15h', 1),
#   ('150p', 1),
#   ('mtmsgrcvd18', 1)],
#  [('', 3),
#   ('i', 3),
#   ('no', 1),
#   ('to', 1),
#   ('be', 1),
#   ('nosi', 1),
#   ('guess', 1),
#   ('idk', 1),
#   ('am', 1),
#   ('over', 1),
#   ('react', 1),
#   ('if', 1),
#   ('m', 1),
#   ('freak', 1)],
#  [('da', 3),
#   ('', 2),
#   ('pleas', 1),
#   ('call', 1),
#   ('me', 1),
#   ('ani', 1),
#   ('mistak', 1),
#   ('from', 1),
#   ('my', 1),
#   ('side', 1),
#   ('sorri', 1),
#   ('pl', 1),
#   ('goto', 1),
#   ('doctor', 1)],
#  [('', 5),
#   ('goodmorn', 1),
#   ('today', 1),
#   ('i', 1),
#   ('am', 1),
#   ('late', 1),
#   ('for', 1),
#   ('lt', 1),
#   ('decim', 1),
#   ('gt', 1),
#   ('min', 1)],
#  [('', 4),
#   ('ceri', 1),
#   ('u', 1),
#   ('rebel', 1),
#   ('sweet', 1),
#   ('dreamz', 1),
#   ('me', 1),
#   ('littl', 1),
#   ('buddi', 1),
#   ('c', 1),
#   ('ya', 1),
#   ('2moro', 1),
#   ('who', 1),
#   ('need', 1),
#   ('bloke', 1)],
#  [('', 6), ('k', 2), ('congratul', 1)],
#  [('', 4),
#   ('so', 2),
#   ('how', 2),
#   ('are', 2),
#   ('you', 2),
#   ('realli', 1),
#   ('what', 1),
#   ('up', 1),
#   ('to', 1),
#   ('s', 1),
#   ('the', 1),
#   ('master', 1),
#   ('and', 1),
#   ('on', 1)],
#  [('pl', 1),
#   ('speak', 1),
#   ('to', 1),
#   ('that', 1),
#   ('custom', 1),
#   ('machan', 1),
#   ('', 1)],
#  [('', 4),
#   ('i', 3),
#   ('you', 3),
#   ('a', 2),
#   ('when', 2),
#   ('hope', 1),
#   ('your', 1),
#   ('alright', 1),
#   ('babe', 1),
#   ('worri', 1),
#   ('that', 1),
#   ('might', 1),
#   ('have', 1),
#   ('felt', 1),
#   ('bit', 1),
#   ('despar', 1),
#   ('learn', 1),
#   ('the', 1),
#   ('job', 1),
#   ('wa', 1),
#   ('fake', 1),
#   ('am', 1),
#   ('here', 1),
#   ('wait', 1),
#   ('come', 1),
#   ('back', 1),
#   ('my', 1),
#   ('love', 1)],
#  [('dear', 1), ('i', 1), ('have', 1), ('reach', 1), ('room', 1)],
#  [('yeah', 1),
#   ('confirm', 1),
#   ('for', 1),
#   ('you', 1),
#   ('stay', 1),
#   ('at', 1),
#   ('', 1),
#   ('that', 1),
#   ('weekend', 1)],
#  [('a', 3),
#   ('', 2),
#   ('dude', 2),
#   ('who', 2),
#   ('derp', 1),
#   ('which', 1),
#   ('is', 1),
#   ('wors', 1),
#   ('alway', 1),
#   ('want', 1),
#   ('to', 1),
#   ('parti', 1),
#   ('or', 1),
#   ('file', 1),
#   ('complaint', 1),
#   ('about', 1),
#   ('the', 1),
#   ('three', 1),
#   ('drug', 1),
#   ('abus', 1),
#   ('he', 1),
#   ('live', 1),
#   ('with', 1)],
#  [('', 3), ('k', 1), ('eng', 1), ('rock', 1), ('in', 1), ('ash', 1)],
#  [('okay', 1),
#   ('same', 1),
#   ('with', 1),
#   ('me', 1),
#   ('', 1),
#   ('well', 1),
#   ('thank', 1),
#   ('for', 1),
#   ('the', 1),
#   ('clarif', 1)],
#  [('wat', 1),
#   ('happen', 1),
#   ('to', 1),
#   ('the', 1),
#   ('cruis', 1),
#   ('thing', 1)],
#  [('', 3),
#   ('gonna', 2),
#   ('me', 2),
#   ('your', 1),
#   ('be', 1),
#   ('the', 1),
#   ('death', 1),
#   ('if', 1),
#   ('i', 1),
#   ('m', 1),
#   ('leav', 1),
#   ('a', 1),
#   ('note', 1),
#   ('that', 1),
#   ('say', 1),
#   ('it', 1),
#   ('all', 1),
#   ('rob', 1),
#   ('fault', 1),
#   ('aveng', 1)],
#  [('miss', 6),
#   ('', 5),
#   ('sent', 2),
#   ('messag', 1),
#   ('some', 1),
#   ('text', 1),
#   ('sender', 1),
#   ('name', 1),
#   ('number', 1),
#   ('date', 1),
#   ('u', 1),
#   ('a', 1),
#   ('lot', 1),
#   ('that', 1),
#   ('y', 1),
#   ('everyth', 1),
#   ('is', 1),
#   ('via', 1),
#   ('__url__', 1)],
#  [('', 3),
#   ('dear', 1),
#   ('matthew', 1),
#   ('pleas', 1),
#   ('call__number__from', 1),
#   ('a', 1),
#   ('landlin', 1),
#   ('your', 1),
#   ('complimentary__number__lux', 1),
#   ('tenerif', 1),
#   ('holiday', 1),
#   ('or', 1),
#   ('__number__cash', 1),
#   ('await', 1),
#   ('collect', 1),
#   ('ppm150', 1),
#   ('sae', 1),
#   ('t', 1),
#   ('cs', 1),
#   ('box334', 1),
#   ('sk38xh', 1)],
#  [('', 5),
#   ('we', 1),
#   ('live', 1),
#   ('in', 1),
#   ('the', 1),
#   ('next', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('min', 1)],
#  [('are', 1),
#   ('you', 1),
#   ('come', 1),
#   ('to', 1),
#   ('day', 1),
#   ('for', 1),
#   ('class', 1),
#   ('', 1)],
#  [('', 6),
#   ('there', 1),
#   ('bold__number__', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('is', 1),
#   ('that', 1),
#   ('your', 1)],
#  [('have', 1),
#   ('you', 1),
#   ('laid', 1),
#   ('your', 1),
#   ('airtel', 1),
#   ('line', 1),
#   ('to', 1),
#   ('rest', 1),
#   ('', 1)],
#  [('your', 2),
#   ('', 2),
#   ('text', 1),
#   ('pass', 1),
#   ('to__number__to', 1),
#   ('collect', 1),
#   ('polyphon', 1),
#   ('rington', 1),
#   ('normal', 1),
#   ('gpr', 1),
#   ('charg', 1),
#   ('appli', 1),
#   ('onli', 1),
#   ('enjoy', 1),
#   ('tone', 1)],
#  [('your', 2),
#   ('', 2),
#   ('hi', 1),
#   ('miss', 1),
#   ('call', 1),
#   ('and', 1),
#   ('my', 1),
#   ('mumha', 1),
#   ('beendrop', 1),
#   ('red', 1),
#   ('wine', 1),
#   ('all', 1),
#   ('over', 1),
#   ('theplac', 1),
#   ('what', 1),
#   ('is', 1),
#   ('adress', 1)],
#  [('', 7),
#   ('on', 2),
#   ('for', 2),
#   ('a', 2),
#   ('that', 2),
#   ('hi', 1),
#   ('wk', 1),
#   ('been', 1),
#   ('ok', 1),
#   ('hol', 1),
#   ('now', 1),
#   ('ye', 1),
#   ('bit', 1),
#   ('of', 1),
#   ('run', 1),
#   ('forgot', 1),
#   ('i', 1),
#   ('have', 1),
#   ('hairdress', 1),
#   ('appoint', 1),
#   ('at', 1),
#   ('four', 1),
#   ('so', 1),
#   ('need', 1),
#   ('to', 1),
#   ('get', 1),
#   ('home', 1),
#   ('n', 1),
#   ('shower', 1),
#   ('beforehand', 1),
#   ('doe', 1),
#   ('caus', 1),
#   ('prob', 1),
#   ('u', 1)],
#  [('', 3),
#   ('yup', 1),
#   ('no', 1),
#   ('need', 1),
#   ('i', 1),
#   ('ll', 1),
#   ('ju', 1),
#   ('wait__number__', 1),
#   ('rain__number__stop', 1)],
#  [('', 6),
#   ('to', 3),
#   ('a', 2),
#   ('as', 1),
#   ('sim', 1),
#   ('subscrib', 1),
#   ('you', 1),
#   ('are', 1),
#   ('select', 1),
#   ('receiv', 1),
#   ('bonu', 1),
#   ('get', 1),
#   ('it', 1),
#   ('deliv', 1),
#   ('your', 1),
#   ('door', 1),
#   ('txt', 1),
#   ('the', 1),
#   ('word', 1),
#   ('ok', 1),
#   ('no', 1),
#   ('__number__to', 1),
#   ('claim', 1),
#   ('150p', 1),
#   ('msg', 1),
#   ('exp', 1),
#   ('30apr', 1)],
#  [('', 13),
#   ('hand', 2),
#   ('1', 1),
#   ('go', 1),
#   ('to', 1),
#   ('write', 1),
#   ('msg__number__', 1),
#   ('put', 1),
#   ('on', 1),
#   ('dictionari', 1),
#   ('mode__number__cov', 1),
#   ('the', 1),
#   ('screen', 1),
#   ('with', 1),
#   ('__number__press', 1),
#   ('lt', 1),
#   ('gt', 1),
#   ('__number__g', 1),
#   ('remov', 1),
#   ('ur', 1),
#   ('it', 1),
#   ('interest', 1)],
#  [('', 6),
#   ('u', 2),
#   ('aiyar', 1),
#   ('dun', 1),
#   ('disturb', 1),
#   ('liao', 1),
#   ('thk', 1),
#   ('have', 1),
#   ('lots__number__do', 1),
#   ('aft', 1),
#   ('ur', 1),
#   ('cupboard', 1),
#   ('come', 1)],
#  [('', 6),
#   ('to', 3),
#   ('tomarrow', 1),
#   ('i', 1),
#   ('want', 1),
#   ('got', 1),
#   ('court', 1),
#   ('at', 1),
#   ('lt', 1),
#   ('decim', 1),
#   ('gt', 1),
#   ('so', 1),
#   ('you', 1),
#   ('come', 1),
#   ('bu', 1),
#   ('stand', 1),
#   ('at__number__', 1)],
#  [('i', 2),
#   ('vewi', 2),
#   ('ok', 1),
#   ('im', 1),
#   ('not', 1),
#   ('sure', 1),
#   ('what', 1),
#   ('time', 1),
#   ('finish', 1),
#   ('tomorrow', 1),
#   ('but', 1),
#   ('wanna', 1),
#   ('spend', 1),
#   ('the', 1),
#   ('even', 1),
#   ('with', 1),
#   ('you', 1),
#   ('co', 1),
#   ('that', 1),
#   ('would', 1),
#   ('be', 1),
#   ('lubli', 1),
#   ('', 1),
#   ('love', 1),
#   ('me', 1),
#   ('xxx', 1)],
#  ...]

# %%
def construct_vocabulary_1000(data_processed: list) -> dict:
    vocabulary = {}

    for i in data_processed:
        for j in i:
            if j[0] not in vocabulary:
                vocabulary[j[0]] = j[1]
            else:
                vocabulary[j[0]] += j[1]

    vocabulary = dict(sorted(vocabulary.items(), key=lambda item: item[1], reverse=True))
    print(len(vocabulary))

    def get_max_min(vocabulary):
        minKey, maxKey = min(vocabulary, key=vocabulary.get), max(vocabulary, key=vocabulary.get)
        print(f"""Max: "{maxKey}" = {vocabulary[maxKey]}; Min: "{minKey}" = {vocabulary[minKey]}""")
        print('-'*100)
    get_max_min(vocabulary)


    vocabulary_1000_keys = list(vocabulary.keys())[:1000]
    vocabulary_1000 = {key:value for key, value in vocabulary.items() if key in vocabulary_1000_keys}
    print(len(vocabulary_1000))
    get_max_min(vocabulary_1000)
    vocabulary_1000
    return vocabulary_1000

vocabulary = construct_vocabulary_1000(train_features2)
vocabulary
with open(f'{MODELDIR}/manual-bow_vocabulary-dict.pkl', 'wb') as file:
    pickle.dump(vocabulary, file)
# Out:
# 6664
# Max: "" = 14645; Min: "ahhhh" = 1
# ----------------------------------------------------------------------------------------------------
# 1000
# Max: "" = 14645; Min: "silent" = 7
# ----------------------------------------------------------------------------------------------------

# %%
def process_data_per_vocab(vocabulary_path: str, data: list) -> np.array:
    """
    Pipeline component 2
    
    Creates multi-dimensional vector BoW as per specified vocabulary from a list of lists
    """
    with open(vocabulary_path, 'rb') as file:
        vocabulary = pickle.load(file)
    output = []
    for i in data:
        int_vocab = { i:0 for i in list(vocabulary.keys()) }
        for j in i:
            if j[0] in int_vocab:
                int_vocab[j[0]] += j[1]
        output.append(list(int_vocab.values()))
    return np.array(output)

train_features3 = process_data_per_vocab('models/manual-bow_vocabulary-dict.pkl', train_features2)
train_features3.shape
# Out:
# (4179, 1000)

# %%
def pipeline(vocabulary_path: str, input_data: list[str]):
    """
    Full pipeline = component 1 + component 2
    """
    input_data2 = preprocess(input_data)
    output_data = process_data_per_vocab(vocabulary_path, input_data2)
    return output_data

df_train = read_tsv(train_file_path)
train_labels, train_features_raw = list(df_train['label']), list(df_train['text'])
train_features = pipeline('models/manual-bow_vocabulary-dict.pkl', train_features_raw)
# Out:
# [INFO] Data points = 4179

# %% [markdown]
# # Train

# %%
log_clf = LogisticRegression(solver="lbfgs", max_iter=1000, random_state=42)
score = cross_val_score(log_clf, train_features, train_labels, cv=3, verbose=3)
print(score.mean())

log_clf.fit(train_features, train_labels)
# Out:
# [CV] END ................................ score: (test=0.978) total time=   0.3s
# [CV] END ................................ score: (test=0.978) total time=   0.3s
# [CV] END ................................ score: (test=0.982) total time=   0.3s
# 0.9791816223977028
# LogisticRegression(max_iter=1000, random_state=42)

# %% [markdown]
# # Test (test set)

# %%
df_test = read_tsv(test_file_path)
test_labels, test_features_raw = list(df_test['label']), list(df_test['text'])
test_features = pipeline('models/manual-bow_vocabulary-dict.pkl', test_features_raw)
# Out:
# [INFO] Data points = 1392

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

predictions = list(log_clf.predict(test_features))
print( accuracy_score(test_labels, predictions) )

predictions = list(log_clf.predict(test_features))
print( f1_score(predictions, test_labels, pos_label='spam') )
# Out:
# 0.9827586206896551
# 0.9333333333333333

# %% [markdown]
# # Test (freecodecamp)

# %%
def predict_message(text):
    """
    function to predict messages based on model

    (should return list containing prediction and label, ex. [0.008318834938108921, 'ham'])
    """
    prediction = []
    features = pipeline('models/manual-bow_vocabulary-dict.pkl', [text])
    ### Get class probability
    model = log_clf
    probabilities = model.predict_proba(features)
    max_index = np.argmax(probabilities)
    prediction.append(probabilities[0][max_index])
    ### Get predicted class
    pred_class = model.predict(features)
    prediction.append(pred_class[0])
    return prediction

pred_text = "how are you doing today?"
prediction = predict_message(pred_text)
print(prediction)

pred_text = "You have just won a lottery!!! Collect your prize now"
prediction = predict_message(pred_text)
print(prediction)
# Out:
# [0.9864917926891434, 'ham']
# [0.8670216570022804, 'spam']

# %%
# Run this cell to test your function and model. Do not modify contents.
def test_predictions():
  test_messages = ["how are you doing today",
                   "sale today! to stop texts call 98912460324",
                   "i dont want to go. can we try it a different day? available sat",
                   "our new mobile video service is live. just install on your phone to start watching.",
                   "you have won £1000 cash! call to claim your prize.",
                   "i'll bring it tomorrow. don't forget the milk.",
                   "wow, is your arm alright. that happened to me one time too"
                  ]

  test_answers = ["ham", "spam", "ham", "spam", "spam", "ham", "ham"]
  passed = True

  for msg, ans in zip(test_messages, test_answers):
    prediction = predict_message(msg)
    if prediction[1] != ans:
      passed = False

  if passed:
    print("You passed the challenge. Great job!")
  else:
    print("You haven't passed yet. Keep trying.")

test_predictions()
# Out:
# You passed the challenge. Great job!
